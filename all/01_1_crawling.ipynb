# %%
import requests
import pandas as pd
import time
import os

# ==========================================
# 만족도 파싱 함수
# ==========================================
def parse_satisfaction(survey):
    if not survey:
        return ""
    questions = survey.get("questions", [])
    parts = []
    for q in questions:
        attribute = q.get("attribute", "")
        answers = q.get("answers", [])
        answer_text = ", ".join([a.get("answerShortText", "") for a in answers])
        parts.append(f"{attribute}: {answer_text}")
    return " / ".join(parts)

# ==========================================
# 리뷰 수집 함수 (새로운 리뷰만 수집)
# ==========================================
def get_reviews(goods_no, target_count, collected_ids, max_pages=9999):
    reviews = []
    stop_crawling = False # 크롤링 중단 플래그

    for page in range(max_pages):
        if len(reviews) >= target_count or stop_crawling:
            break
        
        # 리뷰 요청 보내기
        url = "https://goods.musinsa.com/api2/review/v1/view/list"
        params = {
            "page":              page,
            "pageSize":          10,
            "goodsNo":           goods_no,
            "sort":              "new", # 최신순 정렬
            "selectedSimilarNo": goods_no,
            "myFilter":          "false",
            "hasPhoto":          "false",
            "isExperience":      "false",
        }
        try:
            json_data, status_code = request_json(url, params=params, timeout=10, retry=3)
            if not json_data:
                print(f"  상태코드 {status_code} -> 중단")
                break
                
            data = json_data.get("data", {})
            review_list = data.get("list", [])
            
            if not review_list:
                break
                
            for review in review_list:
                review_no = str(review.get("no", ""))
                
                # 핵심 로직: 이미 수집된 리뷰 번호를 만나면 더 이상 과거 리뷰를 탐색할 필요가 없음
                if review_no in collected_ids:
                    stop_crawling = True
                    break 
                
                profile = review.get("userProfileInfo") or {}
                images  = review.get("images") or []
                reviews.append({
                    "goodsNo":  str(goods_no),
                    "리뷰번호": review_no, # 이 값이 중복 체크의 기준이 됩니다
                    "리뷰타입": review.get("type", ""),
                    "작성자":   profile.get("userNickName", ""),
                    "리뷰내용": review.get("content", ""),
                    "평점":     int(review.get("grade", 0)),
                    "체험단":   review.get("type") == "experience",
                    "구매옵션": review.get("goodsOption", ""),
                    "키":       profile.get("userHeight", ""),
                    "몸무게":   profile.get("userWeight", ""),
                    "성별":     profile.get("reviewSex", ""),
                    "작성일":   review.get("createDate", ""),
                    "만족도":   parse_satisfaction(review.get("reviewSurveySatisfaction")),
                    "사진유무": len(images) > 0,
                    "도움돼요": review.get("likeCount", 0),
                })
                
                if len(reviews) >= target_count:
                    break
                    
            total_pages = data.get("page", {}).get("totalPages", 0)
            if page >= total_pages - 1:
                break
                
            if len(reviews) % 100 == 0 and len(reviews) > 0:
                print(f"  새로운 리뷰 {len(reviews)}개 수집 중...")
            time.sleep(2)
            
        except Exception as e:
            print(f"  리뷰 수집 오류: {e}")
            time.sleep(2)
            break
            
    return reviews

# ==========================================
# 상품 통계(조회수, 판매량) 수집 함수
# ==========================================
def get_goods_stats(goods_no):
    url = f"https://goods-detail.musinsa.com/api2/goods/{goods_no}/stat"
    try:
        json_data, status_code = request_json(url, timeout=10, retry=3)
        if json_data:
            sales_count = json_data.get("data", {}).get("purchaseTotal", 0)
            views_count = json_data.get("data", {}).get("pageViewTotal", 0)
            return sales_count, views_count
        else:
            print(f"  통계 수집 실패 ({goods_no}): {status_code}")
    except Exception as e:
        print(f"  통계 수집 오류 ({goods_no}): {e}")
    return 0, 0

# ==========================================
# escape_excel 함수 추가
# ==========================================
def escape_excel(text):
    if isinstance(text, str) and text.startswith(('-', '=', '+', '@', '#')):
        return "'" + text
    return text

# ==========================================
# 중간 저장 함수
# ==========================================
#def save_product(row_dict):
    df_row = pd.DataFrame([row_dict])
    if os.path.exists(PRODUCTS_CSV):
        df_row.to_csv(PRODUCTS_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_row.to_csv(PRODUCTS_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
def save_reviews(reviews):
    if not reviews:
        return
    df_r = pd.DataFrame(reviews)
    
    # 줄바꿈 문자 제거 (CSV 깨짐 방지)
    df_r["리뷰내용"] = df_r["리뷰내용"].astype(str).str.replace(r'[\n\r\t]', ' ', regex=True)

    # 엑셀 오류 방지 처리
    for col in ['리뷰내용', '작성자']:
        if col in df_r.columns:
            df_r[col] = df_r[col].apply(escape_excel)
    
    if os.path.exists(REVIEWS_CSV):
        df_r.to_csv(REVIEWS_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_r.to_csv(REVIEWS_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
def save_error(goods_no, error_type, message):
    df_e = pd.DataFrame([{
        "goodsNo":    goods_no,
        "error_type": error_type,
        "message":    message,
        "time":       pd.Timestamp.now().strftime("%Y-%m-%d %H:%M:%S"),
    }])
    if os.path.exists(ERRORS_CSV):
        df_e.to_csv(ERRORS_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_e.to_csv(ERRORS_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
        

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36",
    "Referer": "https://www.musinsa.com/",
    "Origin": "https://www.musinsa.com",
}

BRAND         = "travel"
CATEGORIES = {
    "001": "상의",
    "002": "아우터",
    #"003": "하의",
}
PAGE_SIZE     = 30 # 추측 최대 상한선이 100
#001 : 상의, 002 : 아우터, 003 : 하의

session = requests.Session()
session.headers.update(headers)
session.headers["Referer"] = f"https://www.musinsa.com/brand/{BRAND}"

def request_json(url, params=None, timeout=10, retry=3):
    last_status = None
    last_error = None
    for attempt in range(1, retry + 1):
        try:
            response = session.get(url, params=params, timeout=timeout)
            last_status = response.status_code
            if response.status_code == 200:
                return response.json(), response.status_code
            print(f"요청 실패 ({response.status_code}) -> 재시도 {attempt}/{retry}")
        except Exception as e:
            last_error = e
            print(f"요청 오류 -> 재시도 {attempt}/{retry}: {e}")
        time.sleep(2 * attempt)
    if last_error is not None:
        print(f"최종 요청 오류: {last_error}")
    return None, last_status

for CATEGORY, CATEGORY_NAME in CATEGORIES.items():
    # CSV 경로를 카테고리마다 새로 설정
    PRODUCTS_CSV = f"{BRAND}_products_{CATEGORY}.csv"
    REVIEWS_CSV  = f"{BRAND}_reviews_{CATEGORY}.csv"
    ERRORS_CSV   = f"{BRAND}_errors_{CATEGORY}.csv"

    print(f"\n{'='*50}")
    print(f"▶ 카테고리 [{CATEGORY}] {CATEGORY_NAME} 수집 시작")
    print(f"{'='*50}")
    
    # ==========================================
    # 브랜드 전체 상품 수집
    # ==========================================
    all_data = []
    page = 1
    next_page_url = None  # 다음 페이지 URL (hmacId 포함)

    while True:
        try:
            if next_page_url:
                # 2페이지부터: nextPageUrl을 그대로 사용 (hmacId 포함)
                json_data, status_code = request_json(next_page_url, timeout=10, retry=3)
            else:
                # 1페이지: 기존 방식으로 요청
                url = "https://api.musinsa.com/api2/dp/v2/plp/goods"
                params = {
                    "gf":       "A",
                    "isSoldOut": "true", # 추가
                    "sortCode": "REVIEW",
                    "category": CATEGORY,
                    "brand":    BRAND,
                    "size":     PAGE_SIZE,
                    "caller":   "FLAGSHIP",
                    "page":     page,
                }
                json_data, status_code = request_json(url, params=params, timeout=10, retry=3)
            
            if not json_data: # 데이터가 비어있다면 무한루프 탈출
                print(f"상품 수집 실패 (page {page}): {status_code}")
                break
            
            data = json_data.get("data", {})
            goods_list = data.get("list", [])
            if not goods_list:# 상품 리스트가 비어있다면 더 이상 수집할 데이터가 없다고 판단하여 반복 종료
                break
            
            for item in goods_list:
                is_sold_out = item.get("isSoldOut", False)
                all_data.append({
                    "플랫폼":    "무신사",
                    "카테고리":  CATEGORY_NAME,
                    "브랜드":    item.get("brandName", ""),
                    "goodsNo":  str(item.get("goodsNo", "")),
                    "상품명":    item.get("goodsName", ""),
                    "정가":      item.get("normalPrice", 0),
                    "판매가":    item.get("price", 0),
                    "할인율": item.get("saleRate", 0),
                    "리뷰수":    item.get("reviewCount", 0),
                    "리뷰점수":  item.get("reviewScore", 0),
                    "판매상태":  "SOLD_OUT" if is_sold_out else "SALE",

                })

            pagination = data.get("pagination", {})
            total_pages = pagination.get("totalPages", 1)
            print(f"상품 수집 중... {page}/{total_pages} 페이지 (누적 {len(all_data)}개)")
            
            # 다음 페이지 URL 추출 (hmacId 포함)
            next_page_url = pagination.get("nextPageUrl")
            
            if not pagination.get("hasNext", False) or page >= total_pages:
                break
            page += 1
            time.sleep(2)

        except Exception as e:
            print(f"상품 수집 오류 (page {page}): {e}")
            time.sleep(2)
            break

    # 리뷰 많은 순으로 정렬 (전체)
    df = pd.DataFrame(all_data)
    df = df.sort_values("리뷰수", ascending=False).reset_index(drop=True)
    df["조회수"] = 0
    df["누적판매수"] = 0
    print(f"\n상품 총 {len(df)}개 수집 완료 (리뷰 많은 순)")
    print(df[["카테고리", "브랜드", "상품명", "리뷰수"]].to_string(index=False))

    # ==========================================
    # 재시작 로직 - 이미 수집된 goodsNo 및 리뷰번호 확인
    # ==========================================
    collected_review_ids = set()

    if os.path.exists(PRODUCTS_CSV): # products csv 파일 존재시
        df_existing = pd.read_csv(PRODUCTS_CSV)
        df_existing["goodsNo"] = df_existing["goodsNo"].astype(str)
        df_existing.set_index("goodsNo", inplace=True)
        print(f"\n기존 수집된 상품 {len(df_existing)}개 확인 -> 기존 정보 최신화 및 신규 리뷰 수집 예정")
    else:
        df_existing = pd.DataFrame() # 빈 데이터프레임 생성
        print("\n기존 수집 상품 파일 없음 -> 처음부터 수집 시작")

    if os.path.exists(REVIEWS_CSV): # reviews csv 파일 존재시
        df_existing_reviews = pd.read_csv(REVIEWS_CSV)
        collected_review_ids = set(df_existing_reviews["리뷰번호"].astype(str).tolist())
        print(f"기존 수집된 개별 리뷰 {len(collected_review_ids)}개 확인 -> 중복 리뷰 스킵 예정")

    # ==========================================
    # 전체 상품 리뷰 및 통계 수집
    # ==========================================
    total_items = len(df)

    for idx, row in df.iterrows():
        goods_no     = row["goodsNo"]
        target_count = int(row["리뷰수"])
        current_item = idx + 1
        
        is_new_product = df_existing.empty or goods_no not in df_existing.index # 상품번호가 기존에 없는 번호라면 True(신규 상품)
        print(f"\n[{current_item}/{total_items}] 처리 중: {str(row['상품명'])[:25]} (총 리뷰 수: {target_count}개)")

        # 1. 통계 수집 (기존/신규 상관없이 무조건 수집하여 최신화)
        try:
            sales, views = get_goods_stats(goods_no)
        except Exception as e:
            print(f"  통계 수집 실패: {e}")
            save_error(goods_no, "stats", str(e))
            # API 오류 시 기존 데이터가 있다면 유지, 없다면 0으로 처리
            if not is_new_product:
                sales = df_existing.at[goods_no, "누적판매수"]
                views = df_existing.at[goods_no, "조회수"]
            else:
                sales, views = 0, 0
        time.sleep(2)

        # # 2. Survey 수집 (신규 상품일 경우에만 진행하도록 권장. 필요시 무조건 수집으로 변경 가능)
        # # 신규 상품인 경우만 진행하도록 설계되어 있음.
        # if is_new_product:
        #     try:
        #         survey_rows = get_survey(goods_no)
        #         save_survey(survey_rows)
        #         print(f"  survey {len(survey_rows)}행 저장 완료 (신규)")
        #     except Exception as e:
        #         print(f"  survey 수집 실패: {e}")
        #         save_error(goods_no, "survey", str(e))
        #     time.sleep(2)

        # 3. 데이터프레임(df_existing)에 최신 정보 업데이트 또는 추가
        updated_info = {
            "플랫폼":    row["플랫폼"],
            "카테고리":  row["카테고리"],
            "브랜드":    row["브랜드"],
            "상품명":    row["상품명"],
            "정가":      row["정가"],
            "판매가":    row["판매가"],
            "할인율": row["할인율"],
            "조회수":    views,
            "누적판매수": sales,
            "리뷰수":    row["리뷰수"],
            "리뷰점수":  row["리뷰점수"],
            "판매상태":  row["판매상태"],
        }
        
        # Pandas를 이용해 해당 goods_no 행을 최신 정보로 덮어쓰기 (없으면 새로 생성됨)
        for key, value in updated_info.items():
            df_existing.at[goods_no, key] = value
            
        if is_new_product:
            print(f"  -> 신규 상품 저장 완료 (누적판매: {sales} | 조회수: {views})")
        else:
            print(f"  -> 기존 상품 정보 최신화 완료 (누적판매: {sales} | 조회수: {views})")

        # 4. 리뷰 수집 로직 (기존 코드와 동일)
        if not goods_no or target_count == 0:
            print(f"  [스킵] 리뷰 없음")
        else:
            print(f"  새로운 리뷰 수집 확인 중...")
            try:
                reviews = get_reviews(goods_no, target_count=target_count, collected_ids=collected_review_ids)
                if len(reviews) > 0:
                    save_reviews(reviews)
                    collected_review_ids.update([str(r["리뷰번호"]) for r in reviews])
                    print(f"  -> 새로운 리뷰 {len(reviews)}개 수집 및 추가 완료!")
                else:
                    print(f"  -> 추가된 새로운 리뷰가 없습니다.")
            except Exception as e:
                print(f"  리뷰 수집 실패: {e}")
                save_error(goods_no, "review", str(e))
                
        time.sleep(2)

    # ==========================================
    # 최종 최신화된 상품 데이터를 CSV에 덮어쓰기
    # ==========================================
    df_existing.reset_index(inplace=True)

    if 'index' in df_existing.columns:
        df_existing.rename(columns={'index': 'goodsNo'}, inplace=True)
    df_existing.to_csv(PRODUCTS_CSV, index=False, encoding="utf-8-sig")
    print("\n모든 상품 정보 최신화 및 CSV 저장 완료!")
# Out:
# c:\Users\Minsoo\anaconda3\Lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.20) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# ==================================================
# ▶ 카테고리 [001] 상의 수집 시작
# ==================================================
# 상품 수집 중... 1/11 페이지 (누적 30개)
# 상품 수집 중... 2/11 페이지 (누적 60개)
# 상품 수집 중... 3/11 페이지 (누적 90개)
# 상품 수집 중... 4/11 페이지 (누적 120개)
# 상품 수집 중... 5/11 페이지 (누적 150개)
# 상품 수집 중... 6/11 페이지 (누적 180개)
# 상품 수집 중... 7/11 페이지 (누적 210개)
# 상품 수집 중... 8/11 페이지 (누적 240개)
# 상품 수집 중... 9/11 페이지 (누적 270개)
# 상품 수집 중... 10/11 페이지 (누적 300개)
# 상품 수집 중... 11/11 페이지 (누적 322개)
#
# 상품 총 322개 수집 완료 (리뷰 많은 순)
# 카테고리 브랜드                            상품명   리뷰수
#   상의 트래블         미시간 울버린 피그먼트 반팔티 블랙 차콜 26657
#   상의 트래블       캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우 16635
#   상의 트래블         미시간 울버린 피그먼트 후드티 블랙 차콜 12905
#   상의 트래블            액티비티 클럽 피그먼트 반팔티 크림 10745
#   상의 트래블          리즌 트레일 피그먼트 반팔티 블랙 차콜  8194
#   상의 트래블         워크샵 디비전 피그먼트 후드티 블랙 차콜  5253
#   상의 트래블        리즌 트레일 피그먼트 반팔티 고스트 그레이  3198
#   상의 트래블            미시간 울버린 피그먼트 반팔티 크림  3079
#   상의 트래블          야숙 바시티 피그먼트 반팔티 블랙 차콜  2735
#   상의 트래블         미시간 울버린 피그먼트 후드티 다크 블루  2623
#   상의 트래블         액티비티 클럽 피그먼트 반팔티 블랙 차콜  2593
#   상의 트래블           워크샵 스탠다드 피그먼트 반팔티 크림  2407
#   상의 트래블            리즌 트레일 피그먼트 반팔티 베이지  2255
#   상의 트래블       미시간 울버린 피그먼트 스웨트셔츠 블랙 차콜  2189
#   상의 트래블      캠프 바시티 피그먼트 오버핏 반팔티 블랙 차콜  1802
#   상의 트래블           리즌 트레일 피그먼트 롱 슬리브 크림  1528
#   상의 트래블            리즌 트레일 피그먼트 반팔티 마젠타  1442
#   상의 트래블       로케이티드 마운틴 피그먼트 반팔티 블랙 차콜  1380
#   상의 트래블        미시간 울버린 피그먼트 반팔티 블루 섀도우  1291
#   상의 트래블    2023 아카이브 로고 피그먼트 반팔티 블랙 차콜  1281
#   상의 트래블            디스페어 피그먼트 반팔티 블랙 차콜  1247
#   상의 트래블                   코스모스 반팔티 화이트   757
#   상의 트래블             세인트 피그먼트 반팔티 블랙 차콜   702
#   상의 트래블        리즌 트레일 피그먼트 롱 슬리브 블랙 차콜   685
#   상의 트래블         워크샵 디비전 피그먼트 후드티 다크 블루   679
#   상의 트래블       캠프 바시티 피그먼트 스웨트셔츠 세이지 그린   671
#   상의 트래블                 스프레이 체크 셔츠 베이지   499
#   상의 트래블       캠프 바시티 피그먼트 스웨트셔츠 애쉬 그레이   494
#   상의 트래블            로고 라인업 피그먼트 반팔티 마젠타   464
#   상의 트래블        스프레이 스타 래글런 반팔티 라이트 베이지   432
#   상의 트래블          워크샵 스탠다드 피그먼트 반팔티 베이지   427
#   상의 트래블                    코스모스 반팔티 블랙   415
#   상의 트래블                세인트 피그먼트 반팔티 크림   398
#   상의 트래블        미시간 울버린 아플리케 후드티 헤더 그레이   368
#   상의 트래블       워크샵 디비전 피그먼트 후드티 고스트 그레이   345
#   상의 트래블       미시간 울버린 피그먼트 후드티 고스트 그레이   338
#   상의 트래블               디스코 피그먼트 반팔티 마젠타   331
#   상의 트래블          리즌 트레일 피그먼트 롱 슬리브 마젠타   331
#   상의 트래블             야숙 바시티 피그먼트 반팔티 크림   323
#   상의 트래블           미시간 울버린 아플리케 후드티 그레이   318
#   상의 트래블        야숙 바시티 피그먼트 반팔티 고스트 그레이   317
#   상의 트래블            미시간 울버린 피그먼트 후드티 크림   305
#   상의 트래블          리즌 트레일 피그먼트 롱 슬리브 베이지   301
#   상의 트래블      리즌 트레일 피그먼트 롱 슬리브 고스트 그레이   301
#   상의 트래블         캠프 바시티 피그먼트 오버핏 반팔티 크림   274
#   상의 트래블           미시간 울버린 아플리케 후드티 네이비   264
#   상의 트래블         스프레이 스타 래글런 반팔티 라이트 핑크   244
#   상의 트래블             수페리어 피그먼트 롱 슬리브 크림   183
#   상의 트래블                코스모스 반팔티 그루미 핑크   170
#   상의 트래블          세인트 스프레이 워시드 반팔티 딥 블루   164
#   상의 트래블              수페리어 피그먼트 반팔티 베이지   156
#   상의 트래블           비전 아트 피그먼트 반팔티 블랙 차콜   155
#   상의 트래블                  클럽 래글런 반팔티 블랙   139
#   상의 트래블             미러볼 피그먼트 반팔티 블랙 차콜   138
#   상의 트래블            리틀 비 슬럽 피그먼트 반팔티 크림   132
#   상의 트래블                 클럽 래글런 반팔티 화이트   131
#   상의 트래블                빅 아르떼 롱 슬리브 화이트   128
#   상의 트래블                 엠보 스타 롱 슬리브 차콜   123
#   상의 트래블            워크샵 디비전 피그먼트 후드티 크림   122
#   상의 트래블     미시간 울버린 피그먼트 스웨트셔츠 더플 백 카키   120
#   상의 트래블           아르떼 스트라이프 롱 슬리브 아이보리   115
#   상의 트래블           포커스 온 피그먼트 반팔티 블랙 차콜   113
#   상의 트래블                 미시간 울버린 반팔티 블랙    96
#   상의 트래블         스프레이 스타 래글런 반팔티 라이트 블루    95
#   상의 트래블             세인트 피그먼트 반팔티 데저트 팜    92
#   상의 트래블     미시간 울버린 피그먼트 스웨트셔츠 버리디안 그린    89
#   상의 트래블             미시간 울버린 반팔티 헤더 그레이    82
#   상의 트래블     미시간 울버린 피그먼트 스웨트셔츠 고스트 그레이    79
#   상의 트래블     로케이티드 마운틴 피그먼트 반팔티 아일랜드 그린    78
#   상의 트래블       미시간 울버린 피그먼트 후드티 더플 백 카키    77
#   상의 트래블             아르떼 스트라이프 롱 슬리브 블랙    76
#   상의 트래블            인사이트 피그먼트 반팔티 블랙 차콜    76
#   상의 트래블          포커스 온 피그먼트 반팔티 블루 섀도우    70
#   상의 트래블             세인트 피그먼트 반팔티 페일 핑크    70
#   상의 트래블               져지 파이핑 롱 슬리브 화이트    67
#   상의 트래블             페이드 피그먼트 반팔티 페일 핑크    61
#   상의 트래블     스프레이 스타 스트라이프 래글런 롱 슬리브 차콜    60
#   상의 트래블             스프레이 스타 래글런 반팔티 차콜    58
#   상의 트래블            컬러 블록 나일론 스웨트셔츠 버건디    57
#   상의 트래블                 스프레이 체크 셔츠 네이비    53
#   상의 트래블                져지 파이핑 롱 슬리브 블랙    53
#   상의 트래블         져지 유니폼 베이스볼 자켓 라이트 그레이    50
#   상의 트래블         로케이티드 마운틴 피그먼트 반팔티 옐로우    49
#   상의 트래블              게이트웨이 피그먼트 반팔티 크림    43
#   상의 트래블     스프레이 스타 스트라이프 래글런 롱 슬리브 블루    42
#   상의 트래블                져지 파이핑 롱 슬리브 핑크    40
#   상의 트래블      워크샵 라인 래글런 나일론 믹스 후드티 그레이    40
#   상의 트래블                 리틀 비 롱 슬리브 화이트    38
#   상의 트래블              아르떼 래글런 롱 슬리브 화이트    38
#   상의 트래블                아르떼 피그먼트 반팔티 크림    36
#   상의 트래블                 빅 아르떼 롱 슬리브 블랙    34
#   상의 트래블                  스프레이 체크 셔츠 레드    34
#   상의 트래블 스프레이 워싱 콤비네이션 래글런 롱 슬리브 라이트 블루    29
#   상의 트래블    스프레이 워싱 콤비네이션 래글런 롱 슬리브 버건디    28
#   상의 트래블             체크 빅 아르떼 롱 슬리브 그레이    25
#   상의 트래블          [2-PACK] 시그니처 그래픽 반팔티    24
#   상의 트래블          디스페어 피그먼트 후드티 고스트 그레이    23
#   상의 트래블          컬러 블록 나일론 스웨트셔츠 콘 플라워    22
#   상의 트래블            디스페어 피그먼트 후드티 블랙 차콜    22
#   상의 트래블               져지 파이핑 롱 슬리브 네이비    22
#   상의 트래블       스프레이 워싱 칼라드 롱 슬리브 라이트 블루    21
#   상의 트래블               트웬티 나일론 풀오버 아이보리    21
#   상의 트래블       미시간 울버린 피그먼트 스웨트셔츠 마울 블루    21
#   상의 트래블         스프레이 스타 피그먼트 후드티 블랙 차콜    21
#   상의 트래블       스프레이 스타피쉬 피그먼트 후드티 블랙 차콜    20
#   상의 트래블            트웬티 콤비네이션 져지 반팔티 블랙    19
#   상의 트래블               워크샵 져지 롱 슬리브 화이트    19
#   상의 트래블          트웬티 콤비네이션 져지 반팔티 아이보리    18
#   상의 트래블           벨루어 라인 테이프 링거 반팔티 블랙    17
#   상의 트래블  워크샵 라인 래글런 나일론 믹스 후드티 라이트 베이지    17
#   상의 트래블                워크샵 져지 롱 슬리브 핑크    17
#   상의 트래블          디스페어 피그먼트 후드티 상그리아 레드    16
#   상의 트래블         리틀 비 슬럽 피그먼트 반팔티 블랙 차콜    14
#   상의 트래블        스프레이 스타 피그먼트 후드티 블루 섀도우    14
#   상의 트래블                트웬티 나일론 풀오버 네이비    14
#   상의 트래블        트웬티 유니폼 피그먼트 반팔티 블루 섀도우    14
#   상의 트래블                  리틀 비 롱 슬리브 블랙    14
#   상의 트래블     글리치드 보야지 피그먼트 링거 반팔티 블랙 차콜    13
#   상의 트래블        트웬티 스트라이프 져지 파이핑 반팔티 블루    13
#   상의 트래블        벨루어 라인 테이프 롱 슬리브 오프 화이트    13
#   상의 트래블             엠보 스타 롱 슬리브 그루미 핑크    13
#   상의 트래블               워크샵 져지 롱 슬리브 옐로우    13
#   상의 트래블           디스페어 피그먼트 후드티 블루 섀도우    12
#   상의 트래블            스타 하트 피그먼트 반팔티 데저트팜    12
#   상의 트래블       스프레이 스타 피그먼트 후드티 고스트 그레이    12
#   상의 트래블            트웬티 유니폼 피그먼트 반팔티 크림    12
#   상의 트래블               프렌드쉽 피그먼트 반팔티 크림    12
#   상의 트래블             트웬티 피그먼트 반팔티 블랙 차콜    12
#   상의 트래블         트웬티 유니폼 피그먼트 반팔티 블랙 차콜    12
#   상의 트래블          엣지 피그먼트 롱 슬리브 더플 백 카키    11
#   상의 트래블               아르떼 래글런 롱 슬리브 차콜    11
#   상의 트래블                캑터스 피그먼트 반팔티 크림    11
#   상의 트래블             캑터스 피그먼트 반팔티 블랙 차콜    11
#   상의 트래블          코스모스  피그먼트 후드티 블루 섀도우    11
#   상의 트래블           페이드 피그먼트 롱 슬리브 페일 핑크    11
#   상의 트래블           코스모스  피그먼트 후드티 블랙 차콜    10
#   상의 트래블               코스모스 롱 슬리브 엔젤 펄스    10
#   상의 트래블            엣지 피그먼트 롱 슬리브 블랙 차콜    10
#   상의 트래블            프렌드쉽 피그먼트 반팔티 블랙 차콜    10
#   상의 트래블      워크샵 라인 래글런 나일론 믹스 후드티 버건디    10
#   상의 트래블                 프로토타입 후드티 아이보리    10
#   상의 트래블           제로쓰리 래글런 반팔티 라이트 베이지    10
#   상의 트래블             체크 빅 아르떼 롱 슬리브 화이트    10
#   상의 트래블      리즌 트레일 슬럽 피그먼트 반팔티 블루 섀도우     9
#   상의 트래블             페이드 피그먼트 롱 슬리브 베이지     9
#   상의 트래블           스프레이 워싱 칼라드 롱 슬리브 와인     9
#   상의 트래블                트웬티 피그먼트 반팔티 크림     9
#   상의 트래블          오버랩 슬럽 피그먼트 반팔티 블랙 차콜     9
#   상의 트래블           언아이덴티파이드 피그먼트 반팔티 크림     9
#   상의 트래블                   큐빅 져지 반팔티 핑크     9
#   상의 트래블                도트 트웬티 롱 슬리브 블랙     9
#   상의 트래블               도트 트웬티 롱 슬리브 화이트     8
#   상의 트래블       브랜드워시드 피그먼트 링거 반팔티 블랙 차콜     8
#   상의 트래블              레코드샵 래글런 반팔티 아이보리     8
#   상의 트래블             아르떼 피그먼트 반팔티 페일 핑크     8
#   상의 트래블                칵테일 피그먼트 반팔티 크림     8
#   상의 트래블          포커스 온 피그먼트 후드티 블루 섀도우     8
#   상의 트래블           포커스 온 피그먼트 후드티 블랙 차콜     8
#   상의 트래블            페이드 피그먼트 후드티 블루 섀도우     8
#   상의 트래블               엣지 피그먼트 롱 슬리브 크림     7
#   상의 트래블             스파인 피그먼트 롱 슬리브 마젠타     7
#   상의 트래블                  젬라이프 후드티 아이보리     7
#   상의 트래블                    젬라이프 후드티 차콜     7
#   상의 트래블               티알에스 피그먼트 반팔티 크림     7
#   상의 트래블            벨루어 라인 테이프 롱 슬리브 핑크     7
#   상의 트래블       트웬티 스트라이프 져지 파이핑 반팔티 그레이     7
#   상의 트래블              레스트 메쉬 져지 반팔티 네이비     7
#   상의 트래블           벨루어 라인 테이프 링거 반팔티 핑크     7
#   상의 트래블                팝핑 래글런 반팔티 아이보리     6
#   상의 트래블                클럽 로고 믹스 후드티 블랙     6
#   상의 트래블                워크샵 져지 롱 슬리브 블루     6
#   상의 트래블                트웬티 스타 후드티 아이보리     6
#   상의 트래블            라인 테이프 트랙 져지 풀오버 핑크     6
#   상의 트래블             오버랩 슬럽 피그먼트 반팔티 크림     6
#   상의 트래블          오버랩 슬럽 피그먼트 반팔티 페일 핑크     6
#   상의 트래블            티알에스 피그먼트 반팔티 블랙 차콜     6
#   상의 트래블             트웬티 피그먼트 반팔티 페일 핑크     6
#   상의 트래블             스텔라 피그먼트 반팔티 블랙 차콜     6
#   상의 트래블    글리치드 보야지 피그먼트 링거 반팔티 블루 섀도우     6
#   상의 트래블            리틀 코드 래글런 롱 슬리브 화이트     6
#   상의 트래블         스프레이 하트 스트라이프 롱 슬리브 블랙     6
#   상의 트래블            제로쓰리 래글런 반팔티 라이트 핑크     5
#   상의 트래블        미시간 울버린 피그먼트 반팔티 클리어 워터     5
#   상의 트래블           스프레이 스타 피그먼트 후드티 마젠타     5
#   상의 트래블                 트웬티 스타 후드티 버건디     5
#   상의 트래블            벨루어 라인 테이프 롱 슬리브 블랙     5
#   상의 트래블     리즌 트레일 슬럽 피그먼트 반팔티 더플 백 카키     5
#   상의 트래블              스타 하트 피그먼트 반팔티 크림     5
#   상의 트래블               안투라지 피그먼트 반팔티 크림     5
#   상의 트래블                   코하쿠토 반팔티 화이트     5
#   상의 트래블              제로쓰리 래글런 반팔티 아이보리     5
#   상의 트래블          트웬티 스타 피그먼트 반팔티 블랙 차콜     5
#   상의 트래블          트웬티 스타 피그먼트 반팔티 페일 핑크     5
#   상의 트래블        트웬티 스트라이프 져지 파이핑 반팔티 핑크     5
#   상의 트래블         이더리얼 피그먼트 링거 반팔티 블랙 차콜     5
#   상의 트래블            유피 피그먼트 반팔티 더플 백 카키     5
#   상의 트래블           팔레트 플라워 스트라이프 반팔티 블랙     5
#   상의 트래블            안투라지 피그먼트 반팔티 블랙 차콜     4
#   상의 트래블              클럽 로고 믹스 후드티 딥 블루     4
#   상의 트래블       스프레이 워싱 칼라드 롱 슬리브 라이트 그린     4
#   상의 트래블       어트랙트 비 슬럽 피그먼트 반팔티 블랙 차콜     4
#   상의 트래블             칵테일 피그먼트 반팔티 블랙 차콜     4
#   상의 트래블                     스텔라 후드티 블랙     4
#   상의 트래블          티알에스 피그먼트 반팔티 고스트 그레이     4
#   상의 트래블                 큐빅 피그먼트 반팔티 크림     4
#   상의 트래블         트리플 플라워 피그먼트 반팔티 블랙 차콜     4
#   상의 트래블        글리치드 보야지 피그먼트 링거 반팔티 크림     4
#   상의 트래블                스텔라 피그먼트 반팔티 크림     4
#   상의 트래블       스프레이 하트 스트라이프 롱 슬리브 아이보리     4
#   상의 트래블              팝핑 래글런 반팔티 그루미 핑크     3
#   상의 트래블               넘버세븐 믹스 후드티 딥 블루     3
#   상의 트래블                    스텔라 후드티 버건디     3
#   상의 트래블                  유스드림 후드티 아이보리     3
#   상의 트래블                 프로토타입 후드티 딥 블루     3
#   상의 트래블        리틀 비 슬럽 피그먼트 반팔티 블루 섀도우     3
#   상의 트래블          어트랙트 비 슬럽 피그먼트 반팔티 크림     3
#   상의 트래블            레코드샵 래글런 반팔티 그루미 핑크     3
#   상의 트래블             트웬티 스타 피그먼트 반팔티 크림     3
#   상의 트래블              큐빅 피그먼트 반팔티 페일 핑크     3
#   상의 트래블                  큐빅 져지 반팔티 화이트     3
#   상의 트래블             스태틱 피그먼트 반팔티 블랙 차콜     3
#   상의 트래블               아르떼 스트라이프 반팔티 블랙     3
#   상의 트래블        언아이덴티파이드 피그먼트 반팔티 페일 핑크     3
#   상의 트래블           실버 스퍼 클럽 피그먼트 반팔티 크림     3
#   상의 트래블                   프로토타입 후드티 블랙     2
#   상의 트래블            스태틱 피그먼트 반팔티 블루 섀도우     2
#   상의 트래블               젬라이프 피그먼트 반팔티 크림     2
#   상의 트래블           스타 하트 피그먼트 반팔티 블랙 차콜     2
#   상의 트래블                  트웬티 스타 후드티 블랙     2
#   상의 트래블                    유스드림 후드티 차콜     2
#   상의 트래블                   스텔라 후드티 아이보리     2
#   상의 트래블                플레임 피그먼트 반팔티 크림     2
#   상의 트래블                  드림핀 슬럽 반팔티 차콜     2
#   상의 트래블        실버 스퍼 클럽 피그먼트 반팔티 블랙 차콜     2
#   상의 트래블          헬릭스 래글런 롱 슬리브 멜란지 그레이     2
#   상의 트래블        리틀 코드 래글런 롱 슬리브 멜란지 그레이     2
#   상의 트래블       스타 헬릭스 래글런 롱 슬리브 멜란지 그레이     2
#   상의 트래블                플럼피 로고 롱 슬리브 블랙     2
#   상의 트래블                컬쳐 하우스 롱 슬리브 블랙     2
#   상의 트래블               컬쳐 하우스 롱 슬리브 화이트     2
#   상의 트래블            스트라이프 레이어드 롱 슬리브 차콜     2
#   상의 트래블               제네시스 피그먼트 반팔티 크림     2
#   상의 트래블             카운티 플라워 크롭 반팔티 그레이     2
#   상의 트래블           스타 헬릭스 래글런 롱 슬리브 화이트     1
#   상의 트래블             넘버세븐 믹스 후드티 헤더 그레이     1
#   상의 트래블             팝핑 래글런 반팔티 라이트 베이지     1
#   상의 트래블             플레임 피그먼트 반팔티 페일 핑크     1
#   상의 트래블              헬릭스 래글런 롱 슬리브 화이트     1
#   상의 트래블               하트 리스 크롭 반팔티 그레이     1
#   상의 트래블               플럼피 로고 롱 슬리브 화이트     1
#   상의 트래블            트리플 플라워 피그먼트 반팔티 크림     1
#   상의 트래블             헬릭스 피그먼트 반팔티 블랙 차콜     1
#   상의 트래블                헬릭스 피그먼트 반팔티 크림     1
#   상의 트래블         팔레트 플라워 스트라이프 반팔티 아이보리     1
#   상의 트래블            데님 크로스 체크 하프 셔츠  블랙     0
#   상의 트래블          컬쳐 하우스 피그먼트 반팔티 블랙 차콜     0
#   상의 트래블             컬쳐 하우스 피그먼트 반팔티 크림     0
#   상의 트래블                   빅 아르떼 반팔티 블랙     0
#   상의 트래블                  빅 아르떼 반팔티 화이트     0
#   상의 트래블               투 포켓 데님 하프 셔츠 블랙     0
#   상의 트래블              투 포켓 데님 하프 셔츠 인디고     0
#   상의 트래블                하트 리스 크롭 반팔티 블랙     0
#   상의 트래블           데님 크로스 체크 하프 셔츠  네이비     0
#   상의 트래블            임페리얼 피그먼트 반팔티 블랙 차콜     0
#   상의 트래블                  포티스 크롭 반팔티 블랙     0
#   상의 트래블                 포티스 크롭 반팔티 그레이     0
#   상의 트래블              카운티 플라워 크롭 반팔티 블랙     0
#   상의 트래블                  가디안 크롭 반팔티 블랙     0
#   상의 트래블               임페리얼 피그먼트 반팔티 크림     0
#   상의 트래블             뱅가드 피그먼트 반팔티 블랙 차콜     0
#   상의 트래블                뱅가드 피그먼트 반팔티 크림     0
#   상의 트래블           스프레이 체크 숏 슬리브 셔츠 베이지     0
#   상의 트래블                넘버세븐 믹스 후드티 오트밀     0
#   상의 트래블                    젬라이프 후드티 퍼플     0
#   상의 트래블            젬라이프 피그먼트 반팔티 블랙 차콜     0
#   상의 트래블                스태틱 피그먼트 반팔티 크림     0
#   상의 트래블              유피 피그먼트 반팔티 블랙 차콜     0
#   상의 트래블           스프레이 체크 숏 슬리브 셔츠 네이비     0
#   상의 트래블               스트라이프 슬리브 후드티 차콜     0
#   상의 트래블          포티스 호스 피그먼트 반팔티 블랙 차콜     0
#   상의 트래블              스트라이프 슬리브 후드티 그레이     0
#   상의 트래블           데님 패치 아르떼 워시드 후드티 블랙     0
#   상의 트래블          데님 패치 아르떼 워시드 후드티 네이비     0
#   상의 트래블           스트라이프 레이어드 롱 슬리브 그레이     0
#   상의 트래블             아르떼 스트라이프 반팔티 아이보리     0
#   상의 트래블            제네시스 피그먼트 반팔티 블랙 차콜     0
#   상의 트래블                 가디안 크롭 반팔티 그레이     0
#   상의 트래블             캘리그라피 피그먼트 반팔티  크림     0
#   상의 트래블            포티스 호스 피그먼트 반팔티  크림     0
#   상의 트래블       글로리 리메인스 피그먼트 헨리넥 반팔티 크림     0
#   상의 트래블                  데님 크로스 반팔티 블랙     0
#   상의 트래블                 데님 크로스 반팔티 화이트     0
#   상의 트래블                   체크 스타 반팔티 블랙     0
#   상의 트래블                  체크 스타 반팔티 화이트     0
#   상의 트래블                트리니티 워시드 반팔티 블랙     0
#   상의 트래블    글로리 리메인스 피그먼트 헨리넥 반팔티 블랙 차콜     0
#   상의 트래블        임페리얼 피그먼트 헨리넥 반팔티 블랙 차콜     0
#   상의 트래블           캘리그라피 피그먼트 반팔티 블랙 차콜     0
#   상의 트래블           임페리얼 피그먼트 헨리넥 반팔티 크림     0
#   상의 트래블               카오스 래글런 반팔티 아이보리     0
#   상의 트래블                  레이서 메쉬 반팔티 레드     0
#   상의 트래블                  레이서 메쉬 반팔티 블루     0
#   상의 트래블                 스트라이프 반팔 폴로 블랙     0
#   상의 트래블               스트라이프 반팔 폴로 아이보리     0
#   상의 트래블             필드 스탬프 피그먼트 반팔티 크림     0
#   상의 트래블          필드 스탬프 피그먼트 반팔티 블랙 차콜     0
#   상의 트래블                엠블럼 피그먼트 반팔티 크림     0
#   상의 트래블             엠블럼 피그먼트 반팔티 블랙 차콜     0
#   상의 트래블               아카이브 피그먼트 반팔티 크림     0
#   상의 트래블            아카이브 피그먼트 반팔티 블랙 차콜     0
#   상의 트래블                    스쿠바 반팔티 화이트     0
#   상의 트래블                     스쿠바 반팔티 블랙     0
#   상의 트래블             멜팅 체크 아플리케 반팔티 화이트     0
#   상의 트래블              멜팅 체크 아플리케 반팔티 블랙     0
#   상의 트래블             스타 헬릭스 래글런 반팔티 그레이     0
#   상의 트래블                  테이크 미 반팔티 화이트     0
#   상의 트래블                   테이크 미 반팔티 블랙     0
#   상의 트래블                 크로스 코드 반팔티 화이트     0
#   상의 트래블                  크로스 코드 반팔티 블랙     0
#   상의 트래블                레이서 피그먼트 반팔티 크림     0
#   상의 트래블             레이서 피그먼트 반팔티 블랙 차콜     0
#   상의 트래블            클럽 로고 믹스 후드티 헤더 그레이     0
#
# 기존 수집 상품 파일 없음 -> 처음부터 수집 시작
# 기존 수집된 개별 리뷰 80387개 확인 -> 중복 리뷰 스킵 예정
#
# [1/322] 처리 중: 미시간 울버린 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 26657개)
#   -> 신규 상품 저장 완료 (누적판매: 148775 | 조회수: 15445)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [2/322] 처리 중: 캠프 바시티 피그먼트 스웨트셔츠 블루 섀도우 (총 리뷰 수: 16635개)
#   -> 신규 상품 저장 완료 (누적판매: 92418 | 조회수: 186)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [3/322] 처리 중: 미시간 울버린 피그먼트 후드티 블랙 차콜 (총 리뷰 수: 12905개)
#   -> 신규 상품 저장 완료 (누적판매: 60017 | 조회수: 2151)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [4/322] 처리 중: 액티비티 클럽 피그먼트 반팔티 크림 (총 리뷰 수: 10745개)
#   -> 신규 상품 저장 완료 (누적판매: 64601 | 조회수: 3885)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [5/322] 처리 중: 리즌 트레일 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 8194개)
#   -> 신규 상품 저장 완료 (누적판매: 50831 | 조회수: 9874)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [6/322] 처리 중: 워크샵 디비전 피그먼트 후드티 블랙 차콜 (총 리뷰 수: 5253개)
#   -> 신규 상품 저장 완료 (누적판매: 33447 | 조회수: 2880)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [7/322] 처리 중: 리즌 트레일 피그먼트 반팔티 고스트 그레이 (총 리뷰 수: 3198개)
#   -> 신규 상품 저장 완료 (누적판매: 14961 | 조회수: 4777)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   새로운 리뷰 2600개 수집 중...
#   새로운 리뷰 2700개 수집 중...
#   새로운 리뷰 2800개 수집 중...
#   새로운 리뷰 2900개 수집 중...
#   새로운 리뷰 3000개 수집 중...
#   새로운 리뷰 3100개 수집 중...
#   -> 새로운 리뷰 3198개 수집 및 추가 완료!
#
# [8/322] 처리 중: 미시간 울버린 피그먼트 반팔티 크림 (총 리뷰 수: 3079개)
#   -> 신규 상품 저장 완료 (누적판매: 15728 | 조회수: 1958)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   새로운 리뷰 2600개 수집 중...
#   새로운 리뷰 2700개 수집 중...
#   새로운 리뷰 2800개 수집 중...
#   새로운 리뷰 2900개 수집 중...
#   새로운 리뷰 3000개 수집 중...
#   -> 새로운 리뷰 3079개 수집 및 추가 완료!
#
# [9/322] 처리 중: 야숙 바시티 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 2735개)
#   -> 신규 상품 저장 완료 (누적판매: 11707 | 조회수: 221)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   새로운 리뷰 2600개 수집 중...
#   새로운 리뷰 2700개 수집 중...
#   -> 새로운 리뷰 2735개 수집 및 추가 완료!
#
# [10/322] 처리 중: 미시간 울버린 피그먼트 후드티 다크 블루 (총 리뷰 수: 2623개)
#   -> 신규 상품 저장 완료 (누적판매: 10486 | 조회수: 735)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   새로운 리뷰 2600개 수집 중...
#   -> 새로운 리뷰 2623개 수집 및 추가 완료!
#
# [11/322] 처리 중: 액티비티 클럽 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 2593개)
#   -> 신규 상품 저장 완료 (누적판매: 14057 | 조회수: 2073)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   -> 새로운 리뷰 2593개 수집 및 추가 완료!
#
# [12/322] 처리 중: 워크샵 스탠다드 피그먼트 반팔티 크림 (총 리뷰 수: 2407개)
#   -> 신규 상품 저장 완료 (누적판매: 12873 | 조회수: 3881)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   -> 새로운 리뷰 2407개 수집 및 추가 완료!
#
# [13/322] 처리 중: 리즌 트레일 피그먼트 반팔티 베이지 (총 리뷰 수: 2255개)
#   -> 신규 상품 저장 완료 (누적판매: 9943 | 조회수: 1983)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   -> 새로운 리뷰 2255개 수집 및 추가 완료!
#
# [14/322] 처리 중: 미시간 울버린 피그먼트 스웨트셔츠 블랙 차콜 (총 리뷰 수: 2189개)
#   -> 신규 상품 저장 완료 (누적판매: 8471 | 조회수: 102)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   -> 새로운 리뷰 2189개 수집 및 추가 완료!
#
# [15/322] 처리 중: 캠프 바시티 피그먼트 오버핏 반팔티 블랙 차콜 (총 리뷰 수: 1802개)
#   -> 신규 상품 저장 완료 (누적판매: 8072 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   -> 새로운 리뷰 1802개 수집 및 추가 완료!
#
# [16/322] 처리 중: 리즌 트레일 피그먼트 롱 슬리브 크림 (총 리뷰 수: 1528개)
#   -> 신규 상품 저장 완료 (누적판매: 10647 | 조회수: 6469)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   -> 새로운 리뷰 1528개 수집 및 추가 완료!
#
# [17/322] 처리 중: 리즌 트레일 피그먼트 반팔티 마젠타 (총 리뷰 수: 1442개)
#   -> 신규 상품 저장 완료 (누적판매: 6038 | 조회수: 1257)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   -> 새로운 리뷰 1442개 수집 및 추가 완료!
#
# [18/322] 처리 중: 로케이티드 마운틴 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 1380개)
#   -> 신규 상품 저장 완료 (누적판매: 5913 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   -> 새로운 리뷰 1380개 수집 및 추가 완료!
#
# [19/322] 처리 중: 미시간 울버린 피그먼트 반팔티 블루 섀도우 (총 리뷰 수: 1291개)
#   -> 신규 상품 저장 완료 (누적판매: 6293 | 조회수: 1666)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   -> 새로운 리뷰 1291개 수집 및 추가 완료!
#
# [20/322] 처리 중: 2023 아카이브 로고 피그먼트 반팔티 블랙  (총 리뷰 수: 1281개)
#   -> 신규 상품 저장 완료 (누적판매: 7035 | 조회수: 1726)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   -> 새로운 리뷰 1281개 수집 및 추가 완료!
#
# [21/322] 처리 중: 디스페어 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 1247개)
#   -> 신규 상품 저장 완료 (누적판매: 11152 | 조회수: 7020)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   -> 새로운 리뷰 1247개 수집 및 추가 완료!
#
# [22/322] 처리 중: 코스모스 반팔티 화이트 (총 리뷰 수: 757개)
#   -> 신규 상품 저장 완료 (누적판매: 6645 | 조회수: 8052)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   -> 새로운 리뷰 757개 수집 및 추가 완료!
#
# [23/322] 처리 중: 세인트 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 702개)
#   -> 신규 상품 저장 완료 (누적판매: 4778 | 조회수: 6928)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   -> 새로운 리뷰 702개 수집 및 추가 완료!
#
# [24/322] 처리 중: 리즌 트레일 피그먼트 롱 슬리브 블랙 차콜 (총 리뷰 수: 685개)
#   -> 신규 상품 저장 완료 (누적판매: 3883 | 조회수: 1850)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   -> 새로운 리뷰 685개 수집 및 추가 완료!
#
# [25/322] 처리 중: 워크샵 디비전 피그먼트 후드티 다크 블루 (총 리뷰 수: 679개)
#   -> 신규 상품 저장 완료 (누적판매: 3563 | 조회수: 628)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   -> 새로운 리뷰 679개 수집 및 추가 완료!
#
# [26/322] 처리 중: 캠프 바시티 피그먼트 스웨트셔츠 세이지 그린 (총 리뷰 수: 671개)
#   -> 신규 상품 저장 완료 (누적판매: 2869 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   -> 새로운 리뷰 671개 수집 및 추가 완료!
#
# [27/322] 처리 중: 스프레이 체크 셔츠 베이지 (총 리뷰 수: 499개)
#   -> 신규 상품 저장 완료 (누적판매: 4219 | 조회수: 2226)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   -> 새로운 리뷰 499개 수집 및 추가 완료!
#
# [28/322] 처리 중: 캠프 바시티 피그먼트 스웨트셔츠 애쉬 그레이 (총 리뷰 수: 494개)
#   -> 신규 상품 저장 완료 (누적판매: 1824 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   -> 새로운 리뷰 494개 수집 및 추가 완료!
#
# [29/322] 처리 중: 로고 라인업 피그먼트 반팔티 마젠타 (총 리뷰 수: 464개)
#   -> 신규 상품 저장 완료 (누적판매: 2553 | 조회수: 1065)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   -> 새로운 리뷰 464개 수집 및 추가 완료!
#
# [30/322] 처리 중: 스프레이 스타 래글런 반팔티 라이트 베이지 (총 리뷰 수: 432개)
#   -> 신규 상품 저장 완료 (누적판매: 3444 | 조회수: 4019)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   -> 새로운 리뷰 432개 수집 및 추가 완료!
#
# [31/322] 처리 중: 워크샵 스탠다드 피그먼트 반팔티 베이지 (총 리뷰 수: 427개)
#   -> 신규 상품 저장 완료 (누적판매: 1965 | 조회수: 278)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   -> 새로운 리뷰 427개 수집 및 추가 완료!
#
# [32/322] 처리 중: 코스모스 반팔티 블랙 (총 리뷰 수: 415개)
#   -> 신규 상품 저장 완료 (누적판매: 3107 | 조회수: 2409)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   -> 새로운 리뷰 415개 수집 및 추가 완료!
#
# [33/322] 처리 중: 세인트 피그먼트 반팔티 크림 (총 리뷰 수: 398개)
#   -> 신규 상품 저장 완료 (누적판매: 2497 | 조회수: 1788)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   -> 새로운 리뷰 398개 수집 및 추가 완료!
#
# [34/322] 처리 중: 미시간 울버린 아플리케 후드티 헤더 그레이 (총 리뷰 수: 368개)
#   -> 신규 상품 저장 완료 (누적판매: 977 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   -> 새로운 리뷰 368개 수집 및 추가 완료!
#
# [35/322] 처리 중: 워크샵 디비전 피그먼트 후드티 고스트 그레이 (총 리뷰 수: 345개)
#   -> 신규 상품 저장 완료 (누적판매: 1924 | 조회수: 592)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   -> 새로운 리뷰 345개 수집 및 추가 완료!
#
# [36/322] 처리 중: 미시간 울버린 피그먼트 후드티 고스트 그레이 (총 리뷰 수: 338개)
#   -> 신규 상품 저장 완료 (누적판매: 1761 | 조회수: 472)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   -> 새로운 리뷰 338개 수집 및 추가 완료!
#
# [37/322] 처리 중: 디스코 피그먼트 반팔티 마젠타 (총 리뷰 수: 331개)
#   -> 신규 상품 저장 완료 (누적판매: 1653 | 조회수: 131)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   -> 새로운 리뷰 331개 수집 및 추가 완료!
#
# [38/322] 처리 중: 리즌 트레일 피그먼트 롱 슬리브 마젠타 (총 리뷰 수: 331개)
#   -> 신규 상품 저장 완료 (누적판매: 1184 | 조회수: 486)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   -> 새로운 리뷰 331개 수집 및 추가 완료!
#
# [39/322] 처리 중: 야숙 바시티 피그먼트 반팔티 크림 (총 리뷰 수: 323개)
#   -> 신규 상품 저장 완료 (누적판매: 1440 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   -> 새로운 리뷰 323개 수집 및 추가 완료!
#
# [40/322] 처리 중: 미시간 울버린 아플리케 후드티 그레이 (총 리뷰 수: 318개)
#   -> 신규 상품 저장 완료 (누적판매: 963 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   -> 새로운 리뷰 318개 수집 및 추가 완료!
#
# [41/322] 처리 중: 야숙 바시티 피그먼트 반팔티 고스트 그레이 (총 리뷰 수: 317개)
#   -> 신규 상품 저장 완료 (누적판매: 1164 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   -> 새로운 리뷰 317개 수집 및 추가 완료!
#
# [42/322] 처리 중: 미시간 울버린 피그먼트 후드티 크림 (총 리뷰 수: 305개)
#   -> 신규 상품 저장 완료 (누적판매: 1463 | 조회수: 315)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   -> 새로운 리뷰 305개 수집 및 추가 완료!
#
# [43/322] 처리 중: 리즌 트레일 피그먼트 롱 슬리브 베이지 (총 리뷰 수: 301개)
#   -> 신규 상품 저장 완료 (누적판매: 1317 | 조회수: 788)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   -> 새로운 리뷰 301개 수집 및 추가 완료!
#
# [44/322] 처리 중: 리즌 트레일 피그먼트 롱 슬리브 고스트 그레이 (총 리뷰 수: 301개)
#   -> 신규 상품 저장 완료 (누적판매: 1922 | 조회수: 1757)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   -> 새로운 리뷰 301개 수집 및 추가 완료!
#
# [45/322] 처리 중: 캠프 바시티 피그먼트 오버핏 반팔티 크림 (총 리뷰 수: 274개)
#   -> 신규 상품 저장 완료 (누적판매: 1381 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   -> 새로운 리뷰 274개 수집 및 추가 완료!
#
# [46/322] 처리 중: 미시간 울버린 아플리케 후드티 네이비 (총 리뷰 수: 264개)
#   -> 신규 상품 저장 완료 (누적판매: 813 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   -> 새로운 리뷰 264개 수집 및 추가 완료!
#
# [47/322] 처리 중: 스프레이 스타 래글런 반팔티 라이트 핑크 (총 리뷰 수: 244개)
#   -> 신규 상품 저장 완료 (누적판매: 1472 | 조회수: 1177)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   -> 새로운 리뷰 244개 수집 및 추가 완료!
#
# [48/322] 처리 중: 수페리어 피그먼트 롱 슬리브 크림 (총 리뷰 수: 183개)
#   -> 신규 상품 저장 완료 (누적판매: 1091 | 조회수: 115)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 183개 수집 및 추가 완료!
#
# [49/322] 처리 중: 코스모스 반팔티 그루미 핑크 (총 리뷰 수: 170개)
#   -> 신규 상품 저장 완료 (누적판매: 1204 | 조회수: 1878)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 170개 수집 및 추가 완료!
#
# [50/322] 처리 중: 세인트 스프레이 워시드 반팔티 딥 블루 (총 리뷰 수: 164개)
#   -> 신규 상품 저장 완료 (누적판매: 1148 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 164개 수집 및 추가 완료!
#
# [51/322] 처리 중: 수페리어 피그먼트 반팔티 베이지 (총 리뷰 수: 156개)
#   -> 신규 상품 저장 완료 (누적판매: 839 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 156개 수집 및 추가 완료!
#
# [52/322] 처리 중: 비전 아트 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 155개)
#   -> 신규 상품 저장 완료 (누적판매: 1222 | 조회수: 1747)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 155개 수집 및 추가 완료!
#
# [53/322] 처리 중: 클럽 래글런 반팔티 블랙 (총 리뷰 수: 139개)
#   -> 신규 상품 저장 완료 (누적판매: 1488 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 139개 수집 및 추가 완료!
#
# [54/322] 처리 중: 미러볼 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 138개)
#   -> 신규 상품 저장 완료 (누적판매: 1197 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 138개 수집 및 추가 완료!
#
# [55/322] 처리 중: 리틀 비 슬럽 피그먼트 반팔티 크림 (총 리뷰 수: 132개)
#   -> 신규 상품 저장 완료 (누적판매: 2230 | 조회수: 5248)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 132개 수집 및 추가 완료!
#
# [56/322] 처리 중: 클럽 래글런 반팔티 화이트 (총 리뷰 수: 131개)
#   -> 신규 상품 저장 완료 (누적판매: 883 | 조회수: 350)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 131개 수집 및 추가 완료!
#
# [57/322] 처리 중: 빅 아르떼 롱 슬리브 화이트 (총 리뷰 수: 128개)
#   -> 신규 상품 저장 완료 (누적판매: 1350 | 조회수: 251)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 128개 수집 및 추가 완료!
#
# [58/322] 처리 중: 엠보 스타 롱 슬리브 차콜 (총 리뷰 수: 123개)
#   -> 신규 상품 저장 완료 (누적판매: 1049 | 조회수: 1523)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 123개 수집 및 추가 완료!
#
# [59/322] 처리 중: 워크샵 디비전 피그먼트 후드티 크림 (총 리뷰 수: 122개)
#   -> 신규 상품 저장 완료 (누적판매: 958 | 조회수: 516)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 122개 수집 및 추가 완료!
#
# [60/322] 처리 중: 미시간 울버린 피그먼트 스웨트셔츠 더플 백 카 (총 리뷰 수: 120개)
#   -> 신규 상품 저장 완료 (누적판매: 401 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 120개 수집 및 추가 완료!
#
# [61/322] 처리 중: 아르떼 스트라이프 롱 슬리브 아이보리 (총 리뷰 수: 115개)
#   -> 신규 상품 저장 완료 (누적판매: 1393 | 조회수: 337)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 115개 수집 및 추가 완료!
#
# [62/322] 처리 중: 포커스 온 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 113개)
#   -> 신규 상품 저장 완료 (누적판매: 649 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 113개 수집 및 추가 완료!
#
# [63/322] 처리 중: 미시간 울버린 반팔티 블랙 (총 리뷰 수: 96개)
#   -> 신규 상품 저장 완료 (누적판매: 341 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 96개 수집 및 추가 완료!
#
# [64/322] 처리 중: 스프레이 스타 래글런 반팔티 라이트 블루 (총 리뷰 수: 95개)
#   -> 신규 상품 저장 완료 (누적판매: 494 | 조회수: 1269)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 95개 수집 및 추가 완료!
#
# [65/322] 처리 중: 세인트 피그먼트 반팔티 데저트 팜 (총 리뷰 수: 92개)
#   -> 신규 상품 저장 완료 (누적판매: 447 | 조회수: 922)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 92개 수집 및 추가 완료!
#
# [66/322] 처리 중: 미시간 울버린 피그먼트 스웨트셔츠 버리디안 그 (총 리뷰 수: 89개)
#   -> 신규 상품 저장 완료 (누적판매: 281 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 89개 수집 및 추가 완료!
#
# [67/322] 처리 중: 미시간 울버린 반팔티 헤더 그레이 (총 리뷰 수: 82개)
#   -> 신규 상품 저장 완료 (누적판매: 250 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 82개 수집 및 추가 완료!
#
# [68/322] 처리 중: 미시간 울버린 피그먼트 스웨트셔츠 고스트 그레 (총 리뷰 수: 79개)
#   -> 신규 상품 저장 완료 (누적판매: 320 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 79개 수집 및 추가 완료!
#
# [69/322] 처리 중: 로케이티드 마운틴 피그먼트 반팔티 아일랜드 그 (총 리뷰 수: 78개)
#   -> 신규 상품 저장 완료 (누적판매: 334 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 78개 수집 및 추가 완료!
#
# [70/322] 처리 중: 미시간 울버린 피그먼트 후드티 더플 백 카키 (총 리뷰 수: 77개)
#   -> 신규 상품 저장 완료 (누적판매: 273 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 77개 수집 및 추가 완료!
#
# [71/322] 처리 중: 아르떼 스트라이프 롱 슬리브 블랙 (총 리뷰 수: 76개)
#   -> 신규 상품 저장 완료 (누적판매: 877 | 조회수: 676)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 76개 수집 및 추가 완료!
#
# [72/322] 처리 중: 인사이트 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 76개)
#   -> 신규 상품 저장 완료 (누적판매: 531 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 76개 수집 및 추가 완료!
#
# [73/322] 처리 중: 포커스 온 피그먼트 반팔티 블루 섀도우 (총 리뷰 수: 70개)
#   -> 신규 상품 저장 완료 (누적판매: 420 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 70개 수집 및 추가 완료!
#
# [74/322] 처리 중: 세인트 피그먼트 반팔티 페일 핑크 (총 리뷰 수: 70개)
#   -> 신규 상품 저장 완료 (누적판매: 508 | 조회수: 3185)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 70개 수집 및 추가 완료!
#
# [75/322] 처리 중: 져지 파이핑 롱 슬리브 화이트 (총 리뷰 수: 67개)
#   -> 신규 상품 저장 완료 (누적판매: 549 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 67개 수집 및 추가 완료!
#
# [76/322] 처리 중: 페이드 피그먼트 반팔티 페일 핑크 (총 리뷰 수: 61개)
#   -> 신규 상품 저장 완료 (누적판매: 411 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 61개 수집 및 추가 완료!
#
# [77/322] 처리 중: 스프레이 스타 스트라이프 래글런 롱 슬리브 차 (총 리뷰 수: 60개)
#   -> 신규 상품 저장 완료 (누적판매: 409 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 60개 수집 및 추가 완료!
#
# [78/322] 처리 중: 스프레이 스타 래글런 반팔티 차콜 (총 리뷰 수: 58개)
#   -> 신규 상품 저장 완료 (누적판매: 394 | 조회수: 856)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 58개 수집 및 추가 완료!
#
# [79/322] 처리 중: 컬러 블록 나일론 스웨트셔츠 버건디 (총 리뷰 수: 57개)
#   -> 신규 상품 저장 완료 (누적판매: 304 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 57개 수집 및 추가 완료!
#
# [80/322] 처리 중: 스프레이 체크 셔츠 네이비 (총 리뷰 수: 53개)
#   -> 신규 상품 저장 완료 (누적판매: 512 | 조회수: 812)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 53개 수집 및 추가 완료!
#
# [81/322] 처리 중: 져지 파이핑 롱 슬리브 블랙 (총 리뷰 수: 53개)
#   -> 신규 상품 저장 완료 (누적판매: 551 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 53개 수집 및 추가 완료!
#
# [82/322] 처리 중: 져지 유니폼 베이스볼 자켓 라이트 그레이 (총 리뷰 수: 50개)
#   -> 신규 상품 저장 완료 (누적판매: 266 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 50개 수집 및 추가 완료!
#
# [83/322] 처리 중: 로케이티드 마운틴 피그먼트 반팔티 옐로우 (총 리뷰 수: 49개)
#   -> 신규 상품 저장 완료 (누적판매: 182 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 49개 수집 및 추가 완료!
#
# [84/322] 처리 중: 게이트웨이 피그먼트 반팔티 크림 (총 리뷰 수: 43개)
#   -> 신규 상품 저장 완료 (누적판매: 352 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 43개 수집 및 추가 완료!
#
# [85/322] 처리 중: 스프레이 스타 스트라이프 래글런 롱 슬리브 블 (총 리뷰 수: 42개)
#   -> 신규 상품 저장 완료 (누적판매: 301 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 42개 수집 및 추가 완료!
#
# [86/322] 처리 중: 져지 파이핑 롱 슬리브 핑크 (총 리뷰 수: 40개)
#   -> 신규 상품 저장 완료 (누적판매: 432 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 40개 수집 및 추가 완료!
#
# [87/322] 처리 중: 워크샵 라인 래글런 나일론 믹스 후드티 그레이 (총 리뷰 수: 40개)
#   -> 신규 상품 저장 완료 (누적판매: 316 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 40개 수집 및 추가 완료!
#
# [88/322] 처리 중: 리틀 비 롱 슬리브 화이트 (총 리뷰 수: 38개)
#   -> 신규 상품 저장 완료 (누적판매: 463 | 조회수: 106)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 38개 수집 및 추가 완료!
#
# [89/322] 처리 중: 아르떼 래글런 롱 슬리브 화이트 (총 리뷰 수: 38개)
#   -> 신규 상품 저장 완료 (누적판매: 467 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 38개 수집 및 추가 완료!
#
# [90/322] 처리 중: 아르떼 피그먼트 반팔티 크림 (총 리뷰 수: 36개)
#   -> 신규 상품 저장 완료 (누적판매: 573 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 36개 수집 및 추가 완료!
#
# [91/322] 처리 중: 빅 아르떼 롱 슬리브 블랙 (총 리뷰 수: 34개)
#   -> 신규 상품 저장 완료 (누적판매: 270 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 34개 수집 및 추가 완료!
#
# [92/322] 처리 중: 스프레이 체크 셔츠 레드 (총 리뷰 수: 34개)
#   -> 신규 상품 저장 완료 (누적판매: 289 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 34개 수집 및 추가 완료!
#
# [93/322] 처리 중: 스프레이 워싱 콤비네이션 래글런 롱 슬리브 라 (총 리뷰 수: 29개)
#   -> 신규 상품 저장 완료 (누적판매: 265 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 29개 수집 및 추가 완료!
#
# [94/322] 처리 중: 스프레이 워싱 콤비네이션 래글런 롱 슬리브 버 (총 리뷰 수: 28개)
#   -> 신규 상품 저장 완료 (누적판매: 253 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 28개 수집 및 추가 완료!
#
# [95/322] 처리 중: 체크 빅 아르떼 롱 슬리브 그레이 (총 리뷰 수: 25개)
#   -> 신규 상품 저장 완료 (누적판매: 281 | 조회수: 4404)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 25개 수집 및 추가 완료!
#
# [96/322] 처리 중: [2-PACK] 시그니처 그래픽 반팔티 (총 리뷰 수: 24개)
#   -> 신규 상품 저장 완료 (누적판매: 763 | 조회수: 9077)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 24개 수집 및 추가 완료!
#
# [97/322] 처리 중: 디스페어 피그먼트 후드티 고스트 그레이 (총 리뷰 수: 23개)
#   -> 신규 상품 저장 완료 (누적판매: 155 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 23개 수집 및 추가 완료!
#
# [98/322] 처리 중: 컬러 블록 나일론 스웨트셔츠 콘 플라워 (총 리뷰 수: 22개)
#   -> 신규 상품 저장 완료 (누적판매: 123 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 22개 수집 및 추가 완료!
#
# [99/322] 처리 중: 디스페어 피그먼트 후드티 블랙 차콜 (총 리뷰 수: 22개)
#   -> 신규 상품 저장 완료 (누적판매: 305 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 22개 수집 및 추가 완료!
#
# [100/322] 처리 중: 져지 파이핑 롱 슬리브 네이비 (총 리뷰 수: 22개)
#   -> 신규 상품 저장 완료 (누적판매: 241 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 22개 수집 및 추가 완료!
#
# [101/322] 처리 중: 스프레이 워싱 칼라드 롱 슬리브 라이트 블루 (총 리뷰 수: 21개)
#   -> 신규 상품 저장 완료 (누적판매: 186 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 21개 수집 및 추가 완료!
#
# [102/322] 처리 중: 트웬티 나일론 풀오버 아이보리 (총 리뷰 수: 21개)
#   -> 신규 상품 저장 완료 (누적판매: 212 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 21개 수집 및 추가 완료!
#
# [103/322] 처리 중: 미시간 울버린 피그먼트 스웨트셔츠 마울 블루 (총 리뷰 수: 21개)
#   -> 신규 상품 저장 완료 (누적판매: 84 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 21개 수집 및 추가 완료!
#
# [104/322] 처리 중: 스프레이 스타 피그먼트 후드티 블랙 차콜 (총 리뷰 수: 21개)
#   -> 신규 상품 저장 완료 (누적판매: 115 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 21개 수집 및 추가 완료!
#
# [105/322] 처리 중: 스프레이 스타피쉬 피그먼트 후드티 블랙 차콜 (총 리뷰 수: 20개)
#   -> 신규 상품 저장 완료 (누적판매: 111 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 20개 수집 및 추가 완료!
#
# [106/322] 처리 중: 트웬티 콤비네이션 져지 반팔티 블랙 (총 리뷰 수: 19개)
#   -> 신규 상품 저장 완료 (누적판매: 206 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 19개 수집 및 추가 완료!
#
# [107/322] 처리 중: 워크샵 져지 롱 슬리브 화이트 (총 리뷰 수: 19개)
#   -> 신규 상품 저장 완료 (누적판매: 195 | 조회수: 477)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 19개 수집 및 추가 완료!
#
# [108/322] 처리 중: 트웬티 콤비네이션 져지 반팔티 아이보리 (총 리뷰 수: 18개)
#   -> 신규 상품 저장 완료 (누적판매: 180 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 18개 수집 및 추가 완료!
#
# [109/322] 처리 중: 벨루어 라인 테이프 링거 반팔티 블랙 (총 리뷰 수: 17개)
#   -> 신규 상품 저장 완료 (누적판매: 152 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 17개 수집 및 추가 완료!
#
# [110/322] 처리 중: 워크샵 라인 래글런 나일론 믹스 후드티 라이트 (총 리뷰 수: 17개)
#   -> 신규 상품 저장 완료 (누적판매: 116 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 17개 수집 및 추가 완료!
#
# [111/322] 처리 중: 워크샵 져지 롱 슬리브 핑크 (총 리뷰 수: 17개)
#   -> 신규 상품 저장 완료 (누적판매: 218 | 조회수: 229)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 17개 수집 및 추가 완료!
#
# [112/322] 처리 중: 디스페어 피그먼트 후드티 상그리아 레드 (총 리뷰 수: 16개)
#   -> 신규 상품 저장 완료 (누적판매: 125 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 16개 수집 및 추가 완료!
#
# [113/322] 처리 중: 리틀 비 슬럽 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 14개)
#   -> 신규 상품 저장 완료 (누적판매: 177 | 조회수: 243)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 14개 수집 및 추가 완료!
#
# [114/322] 처리 중: 스프레이 스타 피그먼트 후드티 블루 섀도우 (총 리뷰 수: 14개)
#   -> 신규 상품 저장 완료 (누적판매: 127 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 14개 수집 및 추가 완료!
#
# [115/322] 처리 중: 트웬티 나일론 풀오버 네이비 (총 리뷰 수: 14개)
#   -> 신규 상품 저장 완료 (누적판매: 194 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 14개 수집 및 추가 완료!
#
# [116/322] 처리 중: 트웬티 유니폼 피그먼트 반팔티 블루 섀도우 (총 리뷰 수: 14개)
#   -> 신규 상품 저장 완료 (누적판매: 69 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 14개 수집 및 추가 완료!
#
# [117/322] 처리 중: 리틀 비 롱 슬리브 블랙 (총 리뷰 수: 14개)
#   -> 신규 상품 저장 완료 (누적판매: 124 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 14개 수집 및 추가 완료!
#
# [118/322] 처리 중: 글리치드 보야지 피그먼트 링거 반팔티 블랙 차 (총 리뷰 수: 13개)
#   -> 신규 상품 저장 완료 (누적판매: 53 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 13개 수집 및 추가 완료!
#
# [119/322] 처리 중: 트웬티 스트라이프 져지 파이핑 반팔티 블루 (총 리뷰 수: 13개)
#   -> 신규 상품 저장 완료 (누적판매: 109 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 13개 수집 및 추가 완료!
#
# [120/322] 처리 중: 벨루어 라인 테이프 롱 슬리브 오프 화이트 (총 리뷰 수: 13개)
#   -> 신규 상품 저장 완료 (누적판매: 99 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 13개 수집 및 추가 완료!
#
# [121/322] 처리 중: 엠보 스타 롱 슬리브 그루미 핑크 (총 리뷰 수: 13개)
#   -> 신규 상품 저장 완료 (누적판매: 99 | 조회수: 444)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 13개 수집 및 추가 완료!
#
# [122/322] 처리 중: 워크샵 져지 롱 슬리브 옐로우 (총 리뷰 수: 13개)
#   -> 신규 상품 저장 완료 (누적판매: 184 | 조회수: 230)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 13개 수집 및 추가 완료!
#
# [123/322] 처리 중: 디스페어 피그먼트 후드티 블루 섀도우 (총 리뷰 수: 12개)
#   -> 신규 상품 저장 완료 (누적판매: 181 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 12개 수집 및 추가 완료!
#
# [124/322] 처리 중: 스타 하트 피그먼트 반팔티 데저트팜 (총 리뷰 수: 12개)
#   -> 신규 상품 저장 완료 (누적판매: 64 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 12개 수집 및 추가 완료!
#
# [125/322] 처리 중: 스프레이 스타 피그먼트 후드티 고스트 그레이 (총 리뷰 수: 12개)
#   -> 신규 상품 저장 완료 (누적판매: 81 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 12개 수집 및 추가 완료!
#
# [126/322] 처리 중: 트웬티 유니폼 피그먼트 반팔티 크림 (총 리뷰 수: 12개)
#   -> 신규 상품 저장 완료 (누적판매: 74 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 12개 수집 및 추가 완료!
#
# [127/322] 처리 중: 프렌드쉽 피그먼트 반팔티 크림 (총 리뷰 수: 12개)
#   -> 신규 상품 저장 완료 (누적판매: 92 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 12개 수집 및 추가 완료!
#
# [128/322] 처리 중: 트웬티 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 12개)
#   -> 신규 상품 저장 완료 (누적판매: 77 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 12개 수집 및 추가 완료!
#
# [129/322] 처리 중: 트웬티 유니폼 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 12개)
#   -> 신규 상품 저장 완료 (누적판매: 86 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 12개 수집 및 추가 완료!
#
# [130/322] 처리 중: 엣지 피그먼트 롱 슬리브 더플 백 카키 (총 리뷰 수: 11개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 11개 수집 및 추가 완료!
#
# [131/322] 처리 중: 아르떼 래글런 롱 슬리브 차콜 (총 리뷰 수: 11개)
#   -> 신규 상품 저장 완료 (누적판매: 207 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 11개 수집 및 추가 완료!
#
# [132/322] 처리 중: 캑터스 피그먼트 반팔티 크림 (총 리뷰 수: 11개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 11개 수집 및 추가 완료!
#
# [133/322] 처리 중: 캑터스 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 11개)
#   -> 신규 상품 저장 완료 (누적판매: 67 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 11개 수집 및 추가 완료!
#
# [134/322] 처리 중: 코스모스  피그먼트 후드티 블루 섀도우 (총 리뷰 수: 11개)
#   -> 신규 상품 저장 완료 (누적판매: 130 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 11개 수집 및 추가 완료!
#
# [135/322] 처리 중: 페이드 피그먼트 롱 슬리브 페일 핑크 (총 리뷰 수: 11개)
#   -> 신규 상품 저장 완료 (누적판매: 50 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 11개 수집 및 추가 완료!
#
# [136/322] 처리 중: 코스모스  피그먼트 후드티 블랙 차콜 (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 174 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [137/322] 처리 중: 코스모스 롱 슬리브 엔젤 펄스 (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 61 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [138/322] 처리 중: 엣지 피그먼트 롱 슬리브 블랙 차콜 (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 95 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [139/322] 처리 중: 프렌드쉽 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 89 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [140/322] 처리 중: 워크샵 라인 래글런 나일론 믹스 후드티 버건디 (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 138 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [141/322] 처리 중: 프로토타입 후드티 아이보리 (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 52 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [142/322] 처리 중: 제로쓰리 래글런 반팔티 라이트 베이지 (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 71 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [143/322] 처리 중: 체크 빅 아르떼 롱 슬리브 화이트 (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 197 | 조회수: 4661)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [144/322] 처리 중: 리즌 트레일 슬럽 피그먼트 반팔티 블루 섀도우 (총 리뷰 수: 9개)
#   -> 신규 상품 저장 완료 (누적판매: 75 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 9개 수집 및 추가 완료!
#
# [145/322] 처리 중: 페이드 피그먼트 롱 슬리브 베이지 (총 리뷰 수: 9개)
#   -> 신규 상품 저장 완료 (누적판매: 75 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 9개 수집 및 추가 완료!
#
# [146/322] 처리 중: 스프레이 워싱 칼라드 롱 슬리브 와인 (총 리뷰 수: 9개)
#   -> 신규 상품 저장 완료 (누적판매: 132 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 9개 수집 및 추가 완료!
#
# [147/322] 처리 중: 트웬티 피그먼트 반팔티 크림 (총 리뷰 수: 9개)
#   -> 신규 상품 저장 완료 (누적판매: 75 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 9개 수집 및 추가 완료!
#
# [148/322] 처리 중: 오버랩 슬럽 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 9개)
#   -> 신규 상품 저장 완료 (누적판매: 68 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 9개 수집 및 추가 완료!
#
# [149/322] 처리 중: 언아이덴티파이드 피그먼트 반팔티 크림 (총 리뷰 수: 9개)
#   -> 신규 상품 저장 완료 (누적판매: 79 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 9개 수집 및 추가 완료!
#
# [150/322] 처리 중: 큐빅 져지 반팔티 핑크 (총 리뷰 수: 9개)
#   -> 신규 상품 저장 완료 (누적판매: 155 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 9개 수집 및 추가 완료!
#
# [151/322] 처리 중: 도트 트웬티 롱 슬리브 블랙 (총 리뷰 수: 9개)
#   -> 신규 상품 저장 완료 (누적판매: 105 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 9개 수집 및 추가 완료!
#
# [152/322] 처리 중: 도트 트웬티 롱 슬리브 화이트 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 67 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [153/322] 처리 중: 브랜드워시드 피그먼트 링거 반팔티 블랙 차콜 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 82 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [154/322] 처리 중: 레코드샵 래글런 반팔티 아이보리 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 74 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [155/322] 처리 중: 아르떼 피그먼트 반팔티 페일 핑크 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 87 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [156/322] 처리 중: 칵테일 피그먼트 반팔티 크림 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 71 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [157/322] 처리 중: 포커스 온 피그먼트 후드티 블루 섀도우 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [158/322] 처리 중: 포커스 온 피그먼트 후드티 블랙 차콜 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [159/322] 처리 중: 페이드 피그먼트 후드티 블루 섀도우 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [160/322] 처리 중: 엣지 피그먼트 롱 슬리브 크림 (총 리뷰 수: 7개)
#   -> 신규 상품 저장 완료 (누적판매: 67 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 7개 수집 및 추가 완료!
#
# [161/322] 처리 중: 스파인 피그먼트 롱 슬리브 마젠타 (총 리뷰 수: 7개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 7개 수집 및 추가 완료!
#
# [162/322] 처리 중: 젬라이프 후드티 아이보리 (총 리뷰 수: 7개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 7개 수집 및 추가 완료!
#
# [163/322] 처리 중: 젬라이프 후드티 차콜 (총 리뷰 수: 7개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 7개 수집 및 추가 완료!
#
# [164/322] 처리 중: 티알에스 피그먼트 반팔티 크림 (총 리뷰 수: 7개)
#   -> 신규 상품 저장 완료 (누적판매: 59 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 7개 수집 및 추가 완료!
#
# [165/322] 처리 중: 벨루어 라인 테이프 롱 슬리브 핑크 (총 리뷰 수: 7개)
#   -> 신규 상품 저장 완료 (누적판매: 50 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 7개 수집 및 추가 완료!
#
# [166/322] 처리 중: 트웬티 스트라이프 져지 파이핑 반팔티 그레이 (총 리뷰 수: 7개)
#   -> 신규 상품 저장 완료 (누적판매: 107 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 7개 수집 및 추가 완료!
#
# [167/322] 처리 중: 레스트 메쉬 져지 반팔티 네이비 (총 리뷰 수: 7개)
# ...
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 2개 수집 및 추가 완료!
#
# [244/322] 처리 중: 스타 헬릭스 래글런 롱 슬리브 화이트 (총 리뷰 수: 1개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [245/322] 처리 중: 넘버세븐 믹스 후드티 헤더 그레이 (총 리뷰 수: 1개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [246/322] 처리 중: 팝핑 래글런 반팔티 라이트 베이지 (총 리뷰 수: 1개)
#   -> 신규 상품 저장 완료 (누적판매: 78 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [247/322] 처리 중: 플레임 피그먼트 반팔티 페일 핑크 (총 리뷰 수: 1개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [248/322] 처리 중: 헬릭스 래글런 롱 슬리브 화이트 (총 리뷰 수: 1개)
#   -> 신규 상품 저장 완료 (누적판매: 61 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [249/322] 처리 중: 하트 리스 크롭 반팔티 그레이 (총 리뷰 수: 1개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 292)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [250/322] 처리 중: 플럼피 로고 롱 슬리브 화이트 (총 리뷰 수: 1개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [251/322] 처리 중: 트리플 플라워 피그먼트 반팔티 크림 (총 리뷰 수: 1개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 687)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [252/322] 처리 중: 헬릭스 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 1개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 500)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [253/322] 처리 중: 헬릭스 피그먼트 반팔티 크림 (총 리뷰 수: 1개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 646)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [254/322] 처리 중: 팔레트 플라워 스트라이프 반팔티 아이보리 (총 리뷰 수: 1개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 673)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [255/322] 처리 중: 데님 크로스 체크 하프 셔츠  블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 342)
#   [스킵] 리뷰 없음
#
# [256/322] 처리 중: 컬쳐 하우스 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 378)
#   [스킵] 리뷰 없음
#
# [257/322] 처리 중: 컬쳐 하우스 피그먼트 반팔티 크림 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 427)
#   [스킵] 리뷰 없음
#
# [258/322] 처리 중: 빅 아르떼 반팔티 블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 550)
#   [스킵] 리뷰 없음
#
# [259/322] 처리 중: 빅 아르떼 반팔티 화이트 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 856)
#   [스킵] 리뷰 없음
#
# [260/322] 처리 중: 투 포켓 데님 하프 셔츠 블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 244)
#   [스킵] 리뷰 없음
#
# [261/322] 처리 중: 투 포켓 데님 하프 셔츠 인디고 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 229)
#   [스킵] 리뷰 없음
#
# [262/322] 처리 중: 하트 리스 크롭 반팔티 블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 224)
#   [스킵] 리뷰 없음
#
# [263/322] 처리 중: 데님 크로스 체크 하프 셔츠  네이비 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 250)
#   [스킵] 리뷰 없음
#
# [264/322] 처리 중: 임페리얼 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 400)
#   [스킵] 리뷰 없음
#
# [265/322] 처리 중: 포티스 크롭 반팔티 블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 502)
#   [스킵] 리뷰 없음
#
# [266/322] 처리 중: 포티스 크롭 반팔티 그레이 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 58 | 조회수: 1451)
#   [스킵] 리뷰 없음
#
# [267/322] 처리 중: 카운티 플라워 크롭 반팔티 블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 511)
#   [스킵] 리뷰 없음
#
# [268/322] 처리 중: 가디안 크롭 반팔티 블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 509)
#   [스킵] 리뷰 없음
#
# [269/322] 처리 중: 임페리얼 피그먼트 반팔티 크림 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 498)
#   [스킵] 리뷰 없음
#
# [270/322] 처리 중: 뱅가드 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 398)
#   [스킵] 리뷰 없음
#
# [271/322] 처리 중: 뱅가드 피그먼트 반팔티 크림 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 364)
#   [스킵] 리뷰 없음
#
# [272/322] 처리 중: 스프레이 체크 숏 슬리브 셔츠 베이지 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 681)
#   [스킵] 리뷰 없음
#
# [273/322] 처리 중: 넘버세븐 믹스 후드티 오트밀 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 72 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# [274/322] 처리 중: 젬라이프 후드티 퍼플 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# [275/322] 처리 중: 젬라이프 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# [276/322] 처리 중: 스태틱 피그먼트 반팔티 크림 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# [277/322] 처리 중: 유피 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# [278/322] 처리 중: 스프레이 체크 숏 슬리브 셔츠 네이비 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 489)
#   [스킵] 리뷰 없음
#
# [279/322] 처리 중: 스트라이프 슬리브 후드티 차콜 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 319)
#   [스킵] 리뷰 없음
#
# [280/322] 처리 중: 포티스 호스 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 270)
#   [스킵] 리뷰 없음
#
# [281/322] 처리 중: 스트라이프 슬리브 후드티 그레이 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 368)
#   [스킵] 리뷰 없음
#
# [282/322] 처리 중: 데님 패치 아르떼 워시드 후드티 블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 432)
#   [스킵] 리뷰 없음
#
# [283/322] 처리 중: 데님 패치 아르떼 워시드 후드티 네이비 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 415)
#   [스킵] 리뷰 없음
#
# [284/322] 처리 중: 스트라이프 레이어드 롱 슬리브 그레이 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 453)
#   [스킵] 리뷰 없음
#
# [285/322] 처리 중: 아르떼 스트라이프 반팔티 아이보리 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 847)
#   [스킵] 리뷰 없음
#
# [286/322] 처리 중: 제네시스 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 617)
#   [스킵] 리뷰 없음
#
# [287/322] 처리 중: 가디안 크롭 반팔티 그레이 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 267)
#   [스킵] 리뷰 없음
#
# [288/322] 처리 중: 캘리그라피 피그먼트 반팔티  크림 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 367)
#   [스킵] 리뷰 없음
#
# [289/322] 처리 중: 포티스 호스 피그먼트 반팔티  크림 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 230)
#   [스킵] 리뷰 없음
#
# [290/322] 처리 중: 글로리 리메인스 피그먼트 헨리넥 반팔티 크림 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 676)
#   [스킵] 리뷰 없음
#
# [291/322] 처리 중: 데님 크로스 반팔티 블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# [292/322] 처리 중: 데님 크로스 반팔티 화이트 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# [293/322] 처리 중: 체크 스타 반팔티 블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 654)
#   [스킵] 리뷰 없음
#
# [294/322] 처리 중: 체크 스타 반팔티 화이트 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 363)
#   [스킵] 리뷰 없음
#
# [295/322] 처리 중: 트리니티 워시드 반팔티 블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 159)
#   [스킵] 리뷰 없음
#
# [296/322] 처리 중: 글로리 리메인스 피그먼트 헨리넥 반팔티 블랙  (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 606)
#   [스킵] 리뷰 없음
#
# [297/322] 처리 중: 임페리얼 피그먼트 헨리넥 반팔티 블랙 차콜 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 963)
#   [스킵] 리뷰 없음
#
# [298/322] 처리 중: 캘리그라피 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 229)
#   [스킵] 리뷰 없음
#
# [299/322] 처리 중: 임페리얼 피그먼트 헨리넥 반팔티 크림 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 285)
#   [스킵] 리뷰 없음
#
# [300/322] 처리 중: 카오스 래글런 반팔티 아이보리 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 233)
#   [스킵] 리뷰 없음
#
# [301/322] 처리 중: 레이서 메쉬 반팔티 레드 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 204)
#   [스킵] 리뷰 없음
#
# [302/322] 처리 중: 레이서 메쉬 반팔티 블루 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 101)
#   [스킵] 리뷰 없음
#
# [303/322] 처리 중: 스트라이프 반팔 폴로 블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 221)
#   [스킵] 리뷰 없음
#
# [304/322] 처리 중: 스트라이프 반팔 폴로 아이보리 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 384)
#   [스킵] 리뷰 없음
#
# [305/322] 처리 중: 필드 스탬프 피그먼트 반팔티 크림 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 191)
#   [스킵] 리뷰 없음
#
# [306/322] 처리 중: 필드 스탬프 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 252)
#   [스킵] 리뷰 없음
#
# [307/322] 처리 중: 엠블럼 피그먼트 반팔티 크림 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 196)
#   [스킵] 리뷰 없음
#
# [308/322] 처리 중: 엠블럼 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 160)
#   [스킵] 리뷰 없음
#
# [309/322] 처리 중: 아카이브 피그먼트 반팔티 크림 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 286)
#   [스킵] 리뷰 없음
#
# [310/322] 처리 중: 아카이브 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 260)
#   [스킵] 리뷰 없음
#
# [311/322] 처리 중: 스쿠바 반팔티 화이트 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 137)
#   [스킵] 리뷰 없음
#
# [312/322] 처리 중: 스쿠바 반팔티 블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 100)
#   [스킵] 리뷰 없음
#
# [313/322] 처리 중: 멜팅 체크 아플리케 반팔티 화이트 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 231)
#   [스킵] 리뷰 없음
#
# [314/322] 처리 중: 멜팅 체크 아플리케 반팔티 블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 276)
#   [스킵] 리뷰 없음
#
# [315/322] 처리 중: 스타 헬릭스 래글런 반팔티 그레이 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 804)
#   [스킵] 리뷰 없음
#
# [316/322] 처리 중: 테이크 미 반팔티 화이트 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 118)
#   [스킵] 리뷰 없음
#
# [317/322] 처리 중: 테이크 미 반팔티 블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 112)
#   [스킵] 리뷰 없음
#
# [318/322] 처리 중: 크로스 코드 반팔티 화이트 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 180)
#   [스킵] 리뷰 없음
#
# [319/322] 처리 중: 크로스 코드 반팔티 블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 106)
#   [스킵] 리뷰 없음
#
# [320/322] 처리 중: 레이서 피그먼트 반팔티 크림 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 175)
#   [스킵] 리뷰 없음
#
# [321/322] 처리 중: 레이서 피그먼트 반팔티 블랙 차콜 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 612)
#   [스킵] 리뷰 없음
#
# [322/322] 처리 중: 클럽 로고 믹스 후드티 헤더 그레이 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# 모든 상품 정보 최신화 및 CSV 저장 완료!
#
# ==================================================
# ▶ 카테고리 [002] 아우터 수집 시작
# ==================================================
# 상품 수집 중... 1/5 페이지 (누적 30개)
# 상품 수집 중... 2/5 페이지 (누적 60개)
# 상품 수집 중... 3/5 페이지 (누적 90개)
# 상품 수집 중... 4/5 페이지 (누적 120개)
# 상품 수집 중... 5/5 페이지 (누적 149개)
#
# 상품 총 149개 수집 완료 (리뷰 많은 순)
# 카테고리 브랜드                            상품명  리뷰수
#  아우터 트래블             어프로칭 후드 윈드 브레이커 블랙 4979
#  아우터 트래블                   크런치 집업 자켓 블랙 3205
#  아우터 트래블               고프 후드 윈드 브레이커 블랙 2753
#  아우터 트래블                트래블러 버튼 아노락 네이비 2350
#  아우터 트래블          고프 후드 윈드 브레이커 사파이어 블루 1890
#  아우터 트래블                  져지 트랙 자켓 아이보리 1676
#  아우터 트래블             스카우트 바시티 스웨트-자켓 블랙 1566
#  아우터 트래블                윙 오픈 윈드 브레이커 블랙 1312
#  아우터 트래블              고프 후드 윈드 브레이커 그레이 1295
#  아우터 트래블            스카우트 퀼티드 윈드 브레이커 블랙  886
#  아우터 트래블                   져지 트랙 자켓 네이비  867
#  아우터 트래블                  크런치 집업 자켓 그레이  763
#  아우터 트래블                 트래블러 버튼 아노락 헌터  718
#  아우터 트래블                 트래블러 버튼 아노락 블랙  714
#  아우터 트래블            스카우트 바시티 스웨트-자켓 네이비  623
#  아우터 트래블           고프 후드 윈드 브레이커 오프 화이트  616
#  아우터 트래블            트래블러 버튼 아노락 바이올렛 핑크  611
#  아우터 트래블                   져지 트랙 자켓 브라운  602
#  아우터 트래블                  벌룬 윈드 브레이커 블랙  588
#  아우터 트래블                트래블러 버튼 아노락 그레이  557
#  아우터 트래블         3M 신슐레이트 패딩 윈드 브레이커 블랙  426
#  아우터 트래블                 벌룬 윈드 브레이커 네이비  371
#  아우터 트래블                   크런치 집업 자켓 차콜  350
#  아우터 트래블            스카우트 바시티 스웨트-자켓 그레이  239
#  아우터 트래블                    져지 트랙 자켓 블랙  234
#  아우터 트래블         3M 신슐레이트 패딩 윈드 브레이커 카키  187
#  아우터 트래블        스카우트 퀼티드 윈드 브레이커 오프 화이트  179
#  아우터 트래블      스미스 피그먼트 후드 집업 자켓 스카이 그레이  166
#  아우터 트래블       스미스 피그먼트 후드 집업 자켓 클로버 핑크  152
#  아우터 트래블                    져지 트랙 자켓 블루  147
#  아우터 트래블         스카우트 바시티 스웨트-자켓 헤더 그레이  123
#  아우터 트래블                라인 테이프 집업 자켓 블랙  116
#  아우터 트래블                    져지 트랙 자켓 핑크  101
#  아우터 트래블             컬러 블록 포켓 아노락 콘 플라워   91
#  아우터 트래블                    져지 트랙 자켓 퍼플   82
#  아우터 트래블        콤비네이션 테이프 져지 트랙 자켓 아이보리   78
#  아우터 트래블              벌룬 윈드 브레이커 더스티 핑크   75
#  아우터 트래블       컬러 매치 나일론 메탈 윈드 브레이커 네이비   73
#  아우터 트래블            윙 오픈 윈드 브레이커 옐로우 그린   70
#  아우터 트래블           고프 후드 윈드 브레이커 옐로우 그린   68
#  아우터 트래블               윙 오픈 져지 트랙 자켓 블랙   58
#  아우터 트래블                파이핑 트랙 집업 자켓 블랙   52
#  아우터 트래블                    후드 다운 점퍼 블랙   50
#  아우터 트래블           컴포터 라이트 퀼팅 자켓 오프 화이트   49
#  아우터 트래블                풋볼 져지 트랙 자켓 네이비   48
#  아우터 트래블        콤비네이션 래글런 져지 트랙 자켓 아이보리   45
#  아우터 트래블            풋볼 져지 트랙 자켓 라이트 그레이   43
#  아우터 트래블             벌룬 윈드 브레이커 그레이스 그린   42
#  아우터 트래블           라인 테이프 집업 자켓 사파이어 블루   41
#  아우터 트래블                 카모 져지 트랙 자켓 그린   39
#  아우터 트래블         콤비네이션 래글런 져지 트랙 자켓 브라운   39
#  아우터 트래블                  와플 트랙 자켓 아이보리   36
#  아우터 트래블               컴포터 라이트 퀼팅 자켓 블랙   35
#  아우터 트래블                져지 파이핑 트랙 자켓 블랙   35
#  아우터 트래블         [SET]라인 테이프 트레이닝 셋업 블랙   31
#  아우터 트래블              컴포터 라이트 퀼팅 베스트 블랙   29
#  아우터 트래블              플럼피 후드 집업 멜란지 그레이   29
#  아우터 트래블    [SET]라인 테이프 트레이닝 셋업 사파이어 블루   28
#  아우터 트래블                플럼피 후드 집업 블랙 차콜   26
#  아우터 트래블         콤비네이션 테이프 져지 트랙 자켓 버건디   26
#  아우터 트래블                  하이넥 다운 베스트 그린   26
#  아우터 트래블                벌룬 윈드 브레이커 풀 블루   25
#  아우터 트래블           스타 헬릭스 후드 집업 멜란지 그레이   24
#  아우터 트래블           스프레이 라인 테이프 후드 집업 블랙   24
#  아우터 트래블        프레스코 피그먼트 후드 집업 고스트 그레이   22
#  아우터 트래블                라인 테이프 집업 자켓 그린   21
#  아우터 트래블         콤비네이션 테이프 져지 트랙 자켓 네이비   21
#  아우터 트래블          프레스코 피그먼트 후드 집업 블랙 차콜   20
#  아우터 트래블          스프레이 체크 라이트 패딩 자켓 네이비   19
#  아우터 트래블                져지 트랙 반팔 자켓 버건디   19
#  아우터 트래블            아뜰리에 데님 믹스 후드 집업 블랙   19
#  아우터 트래블              워싱 와플 믹스 후드 집업 블랙   18
#  아우터 트래블              워싱 포켓 캔버스 자켓 아이보리   17
#  아우터 트래블           버터플라이 본 워시드 후드 집업 블랙   16
#  아우터 트래블                 엠보 스타 후드 집업 차콜   16
#  아우터 트래블                데님 테리 트랙 자켓 인디고   16
#  아우터 트래블           스프레이 체크 라이트 패딩 자켓 그린   16
#  아우터 트래블              체크 파이핑 후드 베스트 그레이   15
#  아우터 트래블        스프레이 라인 테이프 후드 집업 스틸 블루   15
#  아우터 트래블            멜팅 스타 후드 집업 멜란지 그레이   15
#  아우터 트래블                 카모 져지 트랙 자켓 블루   15
#  아우터 트래블             컬쳐 하우스 후드 집업 블랙 차콜   15
#  아우터 트래블               헬릭스 후드 집업 블루 섀도우   14
#  아우터 트래블               카모 라이트 퀼팅 자켓 그레이   14
#  아우터 트래블                    와플 트랙 자켓 블랙   14
#  아우터 트래블 워크샵 라인 래글런 나일론 믹스 반팔 후드 집업 네이비   14
#  아우터 트래블              엣지 워시드 후드 집업 딥 카키   14
#  아우터 트래블             빈티지 워싱 스웻 트랙 자켓 블랙   13
#  아우터 트래블                카모 라이트 퀼팅 자켓 그린   13
#  아우터 트래블           클럽 로고 워시드 후드 집업 딥 블루   13
#  아우터 트래블             클럽 로고 워시드 후드 집업 블랙   13
#  아우터 트래블                 데님 테리 트랙 자켓 블랙   12
#  아우터 트래블                워싱 포켓 캔버스 자켓 퍼플   12
#  아우터 트래블             새틴 트랙 라이트 패딩 자켓 블랙   12
#  아우터 트래블              스트라이프 저지 트랙 자켓 블랙   12
#  아우터 트래블              멜팅 스타 후드 집업 블랙 차콜   12
#  아우터 트래블            스타 헬릭스 후드 집업 블루 섀도우   11
#  아우터 트래블              헬릭스 후드 집업 멜란지 그레이   11
#  아우터 트래블                링클 라이트 패딩 자켓 카키   10
#  아우터 트래블             리틀 비 피그먼트 후드 집업 크림   10
#  아우터 트래블         버터플라이 본 워시드 후드 집업 딥 카키   10
#  아우터 트래블           워크샵 디비전 워시드 후드 집업 블랙    9
#  아우터 트래블         [SET]라인 테이프 트레이닝 셋업 그린    9
#  아우터 트래블            새틴 트랙 라이트 패딩 자켓 네이비    9
#  아우터 트래블           스프레이 스타 래글런 후드 집업 차콜    9
#  아우터 트래블               파이핑 라이트 패딩 자켓 블랙    9
#  아우터 트래블       로고 아플리케 피그먼트 후드 집업 블랙 차콜    8
#  아우터 트래블            링클 라이트 패딩 자켓 블루 그레이    8
#  아우터 트래블               파이핑 라이트 패딩 자켓 차콜    8
#  아우터 트래블      워크샵 디비전 워시드 후드 집업 라이트 그레이    7
#  아우터 트래블            리즌 트레일 워시드 후드 집업 블랙    7
#  아우터 트래블                엣지 워시드 후드 집업 블랙    7
#  아우터 트래블          리틀 비 피그먼트 후드 집업 블랙 차콜    7
#  아우터 트래블              아르떼 피그먼트 후드 집업 크림    7
#  아우터 트래블            빈티지 워싱 스웻 트랙 자켓 그레이    6
#  아우터 트래블           컬쳐 하우스 후드 집업 멜란지 그레이    6
#  아우터 트래블        리틀 비 스트라이프 플리스 후드 집업 그린    6
#  아우터 트래블           엣지 워시드 후드 집업 라이트 그레이    6
#  아우터 트래블             스트라이프 저지 트랙 자켓 그레이    5
#  아우터 트래블            아뜰리에 데님 믹스 후드 집업 블루    5
#  아우터 트래블                빈티지 워싱 후드 집업 핑크    5
#  아우터 트래블           스타 콤비네이션 체크 후드 집업 블랙    4
#  아우터 트래블              엠보 스타 후드 집업 다크 블루    4
#  아우터 트래블           아르떼 피그먼트 후드 집업 블랙 차콜    4
#  아우터 트래블          컴포터 라이트 퀼팅 베스트 오프 화이트    3
#  아우터 트래블        멜팅 체크 라이트 패딩 자켓 그레이시 블루    3
#  아우터 트래블          스프레이 스타 래글런 후드 집업 베이지    3
#  아우터 트래블                링클 라이트 후드 집업 차콜    2
#  아우터 트래블            데님 라이트 퀼팅 자켓 인디고 블루    2
#  아우터 트래블                체크 파이핑 트랙 자켓 블루    2
#  아우터 트래블               스티치 래글런 후드 집업 차콜    2
#  아우터 트래블              재기드 리틀 비 후드 집업 와인    2
#  아우터 트래블          스타 콤비네이션 체크 후드 집업 화이트    1
#  아우터 트래블      로고 아플리케 피그먼트 후드 집업 블루 섀도우    1
#  아우터 트래블             재기드 리틀 비 후드 집업 네이비    1
#  아우터 트래블              스티치 래글런 후드 집업 그레이    1
#  아우터 트래블         나일론 바인딩 테이프 자켓 라이트 그레이    1
#  아우터 트래블          그레인 체크 후드 집업 자켓 다크 블루    1
#  아우터 트래블             워싱 와플 믹스 후드 집업 버건디    1
#  아우터 트래블           그레인 체크 후드 집업 자켓 아이보리    0
#  아우터 트래블                데님 라이트 퀼팅 자켓 블랙    0
#  아우터 트래블               체크 파이핑 트랙 자켓 브라운    0
#  아우터 트래블                링클 라이트 후드 집업 블루    0
#  아우터 트래블             베이스볼 래글런 후드 집업 그레이    0
#  아우터 트래블            스타 슬리브 신세틱 레더 자켓 블랙    0
#  아우터 트래블           스타 슬리브 신세틱 레더 자켓 브라운    0
#  아우터 트래블              나일론 바인딩 테이프 자켓 블랙    0
#  아우터 트래블              베이스볼 래글런 후드 집업 블랙    0
#  아우터 트래블         멜팅 체크 라이트 패딩 자켓 민트 그레이    0
#
# 기존 수집 상품 파일 없음 -> 처음부터 수집 시작
#
# [1/149] 처리 중: 어프로칭 후드 윈드 브레이커 블랙 (총 리뷰 수: 4979개)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 335
#     333     else:
#     334         sales, views = 0, 0
# --> 335 time.sleep(2)
#     337 # # 2. Survey 수집 (신규 상품일 경우에만 진행하도록 권장. 필요시 무조건 수집으로 변경 가능)
#     338 # # 신규 상품인 경우만 진행하도록 설계되어 있음.
#     339 # if is_new_product:
#    (...)    348
#     349 # 3. 데이터프레임(df_existing)에 최신 정보 업데이트 또는 추가
#     350 updated_info = {
#     351     "플랫폼":    row["플랫폼"],
#     352     "카테고리":  row["카테고리"],
#    (...)    362     "판매상태":  row["판매상태"],
#     363 }
#
# KeyboardInterrupt:

# %%
import pandas as pd

file_names = [
    "filluminate_products_001.csv",
    "filluminate_products_002.csv",
    "filluminate_products_003.csv",
    "travel_products_001.csv",
    "travel_products_002.csv",
    "travel_products_003.csv",
    "jemut_products_001.csv",
    "jemut_products_002.csv",
    "filluminate_reviews_001.csv",
    "filluminate_reviews_002.csv",
    "filluminate_reviews_003.csv",
    "travel_reviews_001.csv",
    "travel_reviews_002.csv",
    "travel_reviews_003.csv",
    "jemut_reviews_001.csv",
    "jemut_reviews_002.csv"
]

for file in file_names:
    try:
        # 파일 읽기
        df = pd.read_csv(file)
        
        # 이전 행 개수 확인 (진행 상황 확인용)
        before_count = len(df)
        
        # 완전 중복 제거 (모든 컬럼의 값이 동일한 행 중 하나만 남김)
        df.drop_duplicates(inplace=True)
        
        # 삭제 후 행 개수 확인
        after_count = len(df)
        
        # 중복이 제거된 데이터프레임을 원본 파일에 덮어쓰기
        df.to_csv(file, index=False)
        print(f"✅ {file} 완료 (중복 {before_count - after_count}개 제거됨)")
        
    except FileNotFoundError:
        print(f"{file} 파일을 찾을 수 없습니다. 경로를 확인해 주세요.")
    except Exception as e:
        print(f"{file} 처리 중 에러 발생: {e}")

print("모든 파일의 중복 제거 및 업데이트 완료")
# Out:
# ✅ filluminate_products_001.csv 완료 (중복 0개 제거됨)
# ✅ filluminate_products_002.csv 완료 (중복 0개 제거됨)
# ✅ filluminate_products_003.csv 완료 (중복 0개 제거됨)
# ✅ travel_products_001.csv 완료 (중복 0개 제거됨)
# ✅ travel_products_002.csv 완료 (중복 0개 제거됨)
# ✅ travel_products_003.csv 완료 (중복 0개 제거됨)
# ✅ jemut_products_001.csv 완료 (중복 0개 제거됨)
# ✅ jemut_products_002.csv 완료 (중복 0개 제거됨)
# ✅ filluminate_reviews_001.csv 완료 (중복 0개 제거됨)
# ✅ filluminate_reviews_002.csv 완료 (중복 0개 제거됨)
# ✅ filluminate_reviews_003.csv 완료 (중복 0개 제거됨)
# ✅ travel_reviews_001.csv 완료 (중복 0개 제거됨)
# ✅ travel_reviews_002.csv 완료 (중복 0개 제거됨)
# ✅ travel_reviews_003.csv 완료 (중복 0개 제거됨)
# ✅ jemut_reviews_001.csv 완료 (중복 0개 제거됨)
# ✅ jemut_reviews_002.csv 완료 (중복 0개 제거됨)
# 모든 파일의 중복 제거 및 업데이트 완료
