# %%
import pandas as pd

df_r = pd.read_csv('./cleaned_reviews.csv', dtype=str)
df_p = pd.read_csv('./cleaned_products.csv', dtype=str)

df_r.to_csv('./cleaned_reviews.csv.gz',index=False, compression='gzip', encoding='utf-8-sig')
df_p.to_csv('./cleaned_products.csv.gz',index=False, compression='gzip', encoding='utf-8-sig')
