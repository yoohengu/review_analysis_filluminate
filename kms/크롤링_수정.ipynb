# %%
import requests
import pandas as pd
import time
import os

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36",
    "Referer": "https://www.musinsa.com/",
    "Origin": "https://www.musinsa.com",
}

BRAND         = "jemut" #filluminate
CATEGORY      = "002"
CATEGORY_NAME = "아우터"
PAGE_SIZE     = 30 # 추측 최대 상한선이 100
#001 : 상의, 002 : 아우터, 003 : 하의

# CSV 파일 경로
PRODUCTS_CSV = f"{BRAND}_products_{CATEGORY}.csv"
REVIEWS_CSV  = f"{BRAND}_reviews_{CATEGORY}.csv"
# SURVEY_CSV   = f"{BRAND}_survey_{CATEGORY}.csv"
ERRORS_CSV   = f"{BRAND}_errors_{CATEGORY}.csv"

session = requests.Session()
session.headers.update(headers)
session.headers["Referer"] = f"https://www.musinsa.com/brand/{BRAND}"

def request_json(url, params=None, timeout=10, retry=3):
    last_status = None
    last_error = None
    for attempt in range(1, retry + 1):
        try:
            response = session.get(url, params=params, timeout=timeout)
            last_status = response.status_code
            if response.status_code == 200:
                return response.json(), response.status_code
            print(f"요청 실패 ({response.status_code}) -> 재시도 {attempt}/{retry}")
        except Exception as e:
            last_error = e
            print(f"요청 오류 -> 재시도 {attempt}/{retry}: {e}")
        time.sleep(2 * attempt)
    if last_error is not None:
        print(f"최종 요청 오류: {last_error}")
    return None, last_status

# ==========================================
# Step 1: 브랜드 전체 상품 수집
# ==========================================
all_data = []
page = 1
next_page_url = None  # 다음 페이지 URL (hmacId 포함)

while True:
    try:
        if next_page_url:
            # 2페이지부터: nextPageUrl을 그대로 사용 (hmacId 포함)
            json_data, status_code = request_json(next_page_url, timeout=10, retry=3)
        else:
            # 1페이지: 기존 방식으로 요청
            url = "https://api.musinsa.com/api2/dp/v2/plp/goods"
            params = {
                "gf":       "A",
                "sortCode": "REVIEW",
                "category": CATEGORY,
                "brand":    BRAND,
                "size":     PAGE_SIZE,
                "caller":   "FLAGSHIP",
                "page":     page,
            }
            json_data, status_code = request_json(url, params=params, timeout=10, retry=3)
        
        if not json_data: # 데이터가 비어있다면 무한루프 탈출
            print(f"상품 수집 실패 (page {page}): {status_code}")
            break
        
        data = json_data.get("data", {})
        goods_list = data.get("list", [])
        if not goods_list:# 상품 리스트가 비어있다면 더 이상 수집할 데이터가 없다고 판단하여 반복 종료
            break
        
        for item in goods_list:
            all_data.append({
                "플랫폼":    "무신사",
                "카테고리":  CATEGORY_NAME,
                "브랜드":    item.get("brandName", ""),
                "goodsNo":  str(item.get("goodsNo", "")),
                "상품명":    item.get("goodsName", ""),
                "정가":      item.get("normalPrice", 0),
                "판매가":    item.get("price", 0),
                "할인율": item.get("saleRate", 0),
                "리뷰수":    item.get("reviewCount", 0),
                "리뷰점수":  item.get("reviewScore", 0),
            })

        pagination = data.get("pagination", {})
        total_pages = pagination.get("totalPages", 1)
        print(f"상품 수집 중... {page}/{total_pages} 페이지 (누적 {len(all_data)}개)")
        
        # 다음 페이지 URL 추출 (hmacId 포함)
        next_page_url = pagination.get("nextPageUrl")
        
        if not pagination.get("hasNext", False) or page >= total_pages:
            break
        page += 1
        time.sleep(2)

    except Exception as e:
        print(f"상품 수집 오류 (page {page}): {e}")
        time.sleep(2)
        break

# 리뷰 많은 순으로 정렬 (전체)
df = pd.DataFrame(all_data)
df = df.sort_values("리뷰수", ascending=False).reset_index(drop=True)
df["조회수"] = 0
df["누적판매수"] = 0
print(f"\n상품 총 {len(df)}개 수집 완료 (리뷰 많은 순)")
print(df[["카테고리", "브랜드", "상품명", "리뷰수"]].to_string(index=False))

# ==========================================
# Step 2: 재시작 로직 - 이미 수집된 goodsNo 및 리뷰번호 확인
# ==========================================
collected_review_ids = set()

if os.path.exists(PRODUCTS_CSV): # products csv 파일 존재시
    df_existing = pd.read_csv(PRODUCTS_CSV)
    df_existing["goodsNo"] = df_existing["goodsNo"].astype(str)
    df_existing.set_index("goodsNo", inplace=True)
    print(f"\n기존 수집된 상품 {len(df_existing)}개 확인 -> 기존 정보 최신화 및 신규 리뷰 수집 예정")
else:
    df_existing = pd.DataFrame() # 빈 데이터프레임 생성
    print("\n기존 수집 상품 파일 없음 -> 처음부터 수집 시작")

if os.path.exists(REVIEWS_CSV): # reviews csv 파일 존재시
    df_existing_reviews = pd.read_csv(REVIEWS_CSV)
    collected_review_ids = set(df_existing_reviews["리뷰번호"].astype(str).tolist())
    print(f"기존 수집된 개별 리뷰 {len(collected_review_ids)}개 확인 -> 중복 리뷰 스킵 예정")

# ==========================================
# Step 3: 만족도 파싱 함수
# ==========================================
def parse_satisfaction(survey):
    if not survey:
        return ""
    questions = survey.get("questions", [])
    parts = []
    for q in questions:
        attribute = q.get("attribute", "")
        answers = q.get("answers", [])
        answer_text = ", ".join([a.get("answerShortText", "") for a in answers])
        parts.append(f"{attribute}: {answer_text}")
    return " / ".join(parts)

# ==========================================
# Step 4: 리뷰 수집 함수 (새로운 리뷰만 수집)
# ==========================================
def get_reviews(goods_no, target_count, collected_ids, max_pages=9999):
    reviews = []
    stop_crawling = False # 크롤링 중단 플래그

    for page in range(max_pages):
        if len(reviews) >= target_count or stop_crawling:
            break
        
        # 리뷰 요청 보내기
        url = "https://goods.musinsa.com/api2/review/v1/view/list"
        params = {
            "page":              page,
            "pageSize":          10,
            "goodsNo":           goods_no,
            "sort":              "new", # 최신순 정렬
            "selectedSimilarNo": goods_no,
            "myFilter":          "false",
            "hasPhoto":          "false",
            "isExperience":      "false",
        }
        try:
            json_data, status_code = request_json(url, params=params, timeout=10, retry=3)
            if not json_data:
                print(f"  상태코드 {status_code} -> 중단")
                break
                
            data = json_data.get("data", {})
            review_list = data.get("list", [])
            
            if not review_list:
                break
                
            for review in review_list:
                review_no = str(review.get("no", ""))
                
                # 핵심 로직: 이미 수집된 리뷰 번호를 만나면 더 이상 과거 리뷰를 탐색할 필요가 없음
                if review_no in collected_ids:
                    stop_crawling = True
                    break 
                
                profile = review.get("userProfileInfo") or {}
                images  = review.get("images") or []
                reviews.append({
                    "goodsNo":  str(goods_no),
                    "리뷰번호": review_no, # 이 값이 중복 체크의 기준이 됩니다
                    "작성자":   profile.get("userNickName", ""),
                    "리뷰내용": review.get("content", ""),
                    "평점":     int(review.get("grade", 0)),
                    "체험단":   review.get("type") == "experience",
                    "구매옵션": review.get("goodsOption", ""),
                    "키":       profile.get("userHeight", ""),
                    "몸무게":   profile.get("userWeight", ""),
                    "성별":     profile.get("reviewSex", ""),
                    "작성일":   review.get("createDate", ""),
                    "만족도":   parse_satisfaction(review.get("reviewSurveySatisfaction")),
                    "사진유무": len(images) > 0,
                    "도움돼요": review.get("likeCount", 0),
                })
                
                if len(reviews) >= target_count:
                    break
                    
            total_pages = data.get("page", {}).get("totalPages", 0)
            if page >= total_pages - 1:
                break
                
            if len(reviews) % 100 == 0 and len(reviews) > 0:
                print(f"  새로운 리뷰 {len(reviews)}개 수집 중...")
            time.sleep(2)
            
        except Exception as e:
            print(f"  리뷰 수집 오류: {e}")
            time.sleep(2)
            break
            
    return reviews

# ==========================================
# Step 5: 상품 통계(조회수, 판매량) 수집 함수
# ==========================================
def get_goods_stats(goods_no):
    url = f"https://goods-detail.musinsa.com/api2/goods/{goods_no}/stat"
    try:
        json_data, status_code = request_json(url, timeout=10, retry=3)
        if json_data:
            sales_count = json_data.get("data", {}).get("purchaseTotal", 0)
            views_count = json_data.get("data", {}).get("pageViewTotal", 0)
            return sales_count, views_count
        else:
            print(f"  통계 수집 실패 ({goods_no}): {status_code}")
    except Exception as e:
        print(f"  통계 수집 오류 ({goods_no}): {e}")
    return 0, 0

# ==========================================
# Step 6: survey 수집 함수
# ==========================================
# def get_survey(goods_no):
#     url = f"https://goods.musinsa.com/api2/review/v1/view/survey/{goods_no}/summary"
#     try:
#         json_data, status_code = request_json(url, timeout=10, retry=3)
#         if json_data:
#             questions = json_data.get("data", {}).get("questions", [])
#             rows = []
#             for q in questions:
#                 attribute = q.get("attribute", "")
#                 for answer in q.get("answers", []):
#                     rows.append({
#                         "goodsNo": str(goods_no),
#                         "항목":    attribute,
#                         "답변":    answer.get("answerShortText", ""),
#                         "비율(%)": answer.get("percentage", 0),
#                         "응답수":  answer.get("count", 0),
#                     })
#             return rows
#         else:
#             print(f"  survey 수집 실패 ({goods_no}): {status_code}")
#     except Exception as e:
#         print(f"  survey 수집 오류 ({goods_no}): {e}")
#     return []


# ==========================================
# Step 7: 중간 저장 함수
# ==========================================
#def save_product(row_dict):
    df_row = pd.DataFrame([row_dict])
    if os.path.exists(PRODUCTS_CSV):
        df_row.to_csv(PRODUCTS_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_row.to_csv(PRODUCTS_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
def save_reviews(reviews):
    if not reviews:
        return
    df_r = pd.DataFrame(reviews)
    if os.path.exists(REVIEWS_CSV):
        df_r.to_csv(REVIEWS_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_r.to_csv(REVIEWS_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
def save_survey(survey_rows):
    if not survey_rows:
        return
    df_s = pd.DataFrame(survey_rows)
    if os.path.exists(SURVEY_CSV):
        df_s.to_csv(SURVEY_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_s.to_csv(SURVEY_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
def save_error(goods_no, error_type, message):
    df_e = pd.DataFrame([{
        "goodsNo":    goods_no,
        "error_type": error_type,
        "message":    message,
        "time":       pd.Timestamp.now().strftime("%Y-%m-%d %H:%M:%S"),
    }])
    if os.path.exists(ERRORS_CSV):
        df_e.to_csv(ERRORS_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_e.to_csv(ERRORS_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
        
# ==========================================
# Step 8: 전체 상품 리뷰 및 통계 수집
# ==========================================
total_items = len(df)

for idx, row in df.iterrows():
    goods_no     = row["goodsNo"]
    target_count = int(row["리뷰수"])
    current_item = idx + 1
    
    is_new_product = df_existing.empty or goods_no not in df_existing.index # 상품번호가 기존에 없는 번호라면 True(신규 상품)
    print(f"\n[{current_item}/{total_items}] 처리 중: {str(row['상품명'])[:25]} (총 리뷰 수: {target_count}개)")

    # 1. 통계 수집 (기존/신규 상관없이 무조건 수집하여 최신화)
    try:
        sales, views = get_goods_stats(goods_no)
    except Exception as e:
        print(f"  통계 수집 실패: {e}")
        save_error(goods_no, "stats", str(e))
        # API 오류 시 기존 데이터가 있다면 유지, 없다면 0으로 처리
        if not is_new_product:
            sales = df_existing.at[goods_no, "누적판매수"]
            views = df_existing.at[goods_no, "조회수"]
        else:
            sales, views = 0, 0
    time.sleep(2)

    # # 2. Survey 수집 (신규 상품일 경우에만 진행하도록 권장. 필요시 무조건 수집으로 변경 가능)
    # # 신규 상품인 경우만 진행하도록 설계되어 있음.
    # if is_new_product:
    #     try:
    #         survey_rows = get_survey(goods_no)
    #         save_survey(survey_rows)
    #         print(f"  survey {len(survey_rows)}행 저장 완료 (신규)")
    #     except Exception as e:
    #         print(f"  survey 수집 실패: {e}")
    #         save_error(goods_no, "survey", str(e))
    #     time.sleep(2)

    # 3. 데이터프레임(df_existing)에 최신 정보 업데이트 또는 추가
    updated_info = {
        "플랫폼":    row["플랫폼"],
        "카테고리":  row["카테고리"],
        "브랜드":    row["브랜드"],
        "상품명":    row["상품명"],
        "정가":      row["정가"],
        "판매가":    row["판매가"],
        "할인율": row["할인율"],
        "조회수":    views,
        "누적판매수": sales,
        "리뷰수":    row["리뷰수"],
        "리뷰점수":  row["리뷰점수"],
    }
    
    # Pandas를 이용해 해당 goods_no 행을 최신 정보로 덮어쓰기 (없으면 새로 생성됨)
    for key, value in updated_info.items():
        df_existing.at[goods_no, key] = value
        
    if is_new_product:
        print(f"  -> 신규 상품 저장 완료 (누적판매: {sales} | 조회수: {views})")
    else:
        print(f"  -> 기존 상품 정보 최신화 완료 (누적판매: {sales} | 조회수: {views})")

    # 4. 리뷰 수집 로직 (기존 코드와 동일)
    if not goods_no or target_count == 0:
        print(f"  [스킵] 리뷰 없음")
    else:
        print(f"  새로운 리뷰 수집 확인 중...")
        try:
            reviews = get_reviews(goods_no, target_count=target_count, collected_ids=collected_review_ids)
            if len(reviews) > 0:
                save_reviews(reviews)
                collected_review_ids.update([str(r["리뷰번호"]) for r in reviews])
                print(f"  -> 새로운 리뷰 {len(reviews)}개 수집 및 추가 완료!")
            else:
                print(f"  -> 추가된 새로운 리뷰가 없습니다.")
        except Exception as e:
            print(f"  리뷰 수집 실패: {e}")
            save_error(goods_no, "review", str(e))
            
    time.sleep(2)

# ==========================================
# Step 9: 최종 최신화된 상품 데이터를 CSV에 덮어쓰기
# ==========================================
df_existing.reset_index(inplace=True)

if 'index' in df_existing.columns:
    df_existing.rename(columns={'index': 'goodsNo'}, inplace=True)
df_existing.to_csv(PRODUCTS_CSV, index=False, encoding="utf-8-sig")
print("\n모든 상품 정보 최신화 및 CSV 저장 완료!")
# Out:
# 상품 수집 중... 1/4 페이지 (누적 30개)
# 상품 수집 중... 2/4 페이지 (누적 60개)
# 상품 수집 중... 3/4 페이지 (누적 90개)
# 상품 수집 중... 4/4 페이지 (누적 108개)
#
# 상품 총 108개 수집 완료 (리뷰 많은 순)
# 카테고리 브랜드                                                       상품명   리뷰수
#  아우터  제멋                                 리치 오버 MA-1 자켓 블랙 YHJK2269 17291
#  아우터  제멋                                 리치 오버 MA-1 자켓 카키 YHJK2269  2718
#  아우터  제멋                                카디 오버핏 MA-1 자켓 블랙 YHJK2319  1909
#  아우터  제멋                              카디 오버핏 MA-1 자켓 딥그레이 YHJK2319  1613
#  아우터  제멋                                  엔트 투웨이 후드집업 그레이 KJHD2272  1560
#  아우터  제멋                            헤븐 투웨이 테리 후드집업 8종
#  아우터  제멋                             헤븐 피그먼트 투웨이 후드집업 브라운 KJHD2540    39
#  아우터  제멋                         [2PACK] 와이즈 오버핏 투웨이 후드집업 KJHD2594    38
#  아우터  제멋                              와이즈 오버핏 투웨이 후드집업 블랙 KJHD2594    32
#  아우터  제멋                                네트로 오버핏 후드 집업 그레이 ISHD2682    31
#  아우터  제멋                       로그 오버핏 투웨이 기모 후드집업 6종 백오트밀 YHHD2462    30
#  아우터  제멋                      로그 오버핏 투웨이 기모 후드집업 6종 달리아퍼플 YHHD2462    24
#  아우터  제멋                              헤븐 피그먼트 투웨이 후드집업 카키 KJHD2540    22
#  아우터  제멋                         블렌드 커브 오버핏 헤비 후드집업 5종 블랙 SOHD2478    22
#  아우터  제멋                          스톤 헤비웨이트 투웨이 후드집업 6종 블랙 KJHD2474    21
#  아우터  제멋                              와이즈 오버핏 투웨이 후드집업 차콜 KJHD2594    21
#  아우터  제멋                             헤븐 피그먼트 투웨이 후드집업 버건디 KJHD2540    19
#  아우터  제멋               [2PACK] 스톤 헤비웨이트 투웨이 후드집업 6종 2PACK KJHD2474    19
#  아우터  제멋                        블렌드 커브 오버핏 헤비 후드집업 5종 그레이 SOHD2478    18
#  아우터  제멋                        [2PACK] 사이드 트랙 후드집업 2PACK OYHD2546    17
#  아우터  제멋                              데이컷 크롭 오버핏 후드집업 브라운 KJHD2650    17
#  아우터  제멋                              데이컷 크롭 오버핏 후드집업 네이비 KJHD2650    17
#  아우터  제멋                                   사이드 트랙 후드집업 블랙 OYHD2546    16
#  아우터  제멋                             헤븐 피그먼트 투웨이 후드집업 네이비 KJHD2540    16
#  아우터  제멋                             와이즈 오버핏 투웨이 후드집업 네이비 KJHD2594    16
#  아우터  제멋                                   사이드 트랙 후드집업 카키 OYHD2546    16
#  아우터  제멋                                  플라이트 후디 봄버자켓 블랙 MMOT2669    14
#  아우터  제멋                                 네트로 오버핏 후드 집업 블랙 ISHD2682    13
#  아우터  제멋                                 데이브 테리 풀집업 자켓 블랙 SJOT2675    13
#  아우터  제멋                                데이브 테리 풀집업 자켓 브라운 SJOT2675    13
#  아우터  제멋                               데이컷 크롭 오버핏 후드집업 블랙 KJHD2650    13
#  아우터  제멋                          [2PACK] 데이컷 크롭 오버핏 후드집업 KJHD2650    11
#  아우터  제멋                       스톤 헤비웨이트 투웨이 후드집업 6종 달리아퍼플 KJHD2474    11
#  아우터  제멋                               네트로 오버핏 후드 집업 다크카키 ISHD2682    11
#  아우터  제멋                                리치 오버 MA-1 자켓 건메탈 YHJK2269    11
#  아우터  제멋                             데이컷 크롭 오버핏 후드집업 브릭레드 KJHD2650    10
#  아우터  제멋                        스톤 헤비웨이트 투웨이 후드집업 6종 다크모카 KJHD2474    10
#  아우터  제멋                                데이브 테리 풀집업 자켓 네이비 SJOT2675     9
#  아우터  제멋                                  플라이트 후디 봄버자켓 카키 MMOT2669     8
#  아우터  제멋                                데이브 테리 풀집업 자켓 그레이 SJOT2675     7
#  아우터  제멋                                 플라이트 후디 봄버자켓 그레이 MMOT2669     7
#  아우터  제멋                              데이컷 크롭 오버핏 후드집업 그레이 KJHD2650     7
#  아우터  제멋                               워크맨 클래식 헤링턴 자켓 브라운 SOJK2605     7
#  아우터  제멋                                워크맨 클래식 헤링턴 자켓 블랙 SOJK2605     7
#  아우터  제멋                               루나 레글런 벌룬 후드집업 그레이 KJHD2613     6
#  아우터  제멋                           와이즈 오버핏 투웨이 후드집업 크림그레이 KJHD2594     6
#  아우터  제멋                               데이컷 크롭 오버핏 후드집업 차콜 KJHD2650     5
#  아우터  제멋                         블렌드 커브 오버핏 헤비 후드집업 5종 카키 SOHD2478     5
#  아우터  제멋                                 플라이트 후디 봄버자켓 버건디 MMOT2669     5
#  아우터  제멋                            [2PACK] 네트로 오버핏 후드 집업 ISHD2682     5
#  아우터  제멋 [SETUP] 데이컷 셋업 (후드 or 집업 + 팬츠) KJHD2649+KJHD2650+ISLP2662     3
#  아우터  제멋                                러쉬 하이넥 크롭 블루종 네이비 NSOT2609     3
#  아우터  제멋                            워크맨 클래식 헤링턴 자켓 라이트베이지 SOJK2605     3
#  아우터  제멋                                리테인 MA-1 봄버 자켓 카키 OYJK2598     3
#  아우터  제멋                                    테넌 라이트 블루종 블랙 JUOT2696     3
#  아우터  제멋                          아워 루즈핏 모헤어 가디건 4종 샌드베이지 SOKN2604     2
#  아우터  제멋                         블렌드 커브 오버핏 헤비 후드집업 5종 퍼플 SOHD2478     2
#  아우터  제멋                                  크리스 워크 헌팅 자켓 그린 KJJK2581     2
#  아우터  제멋                         스톤 헤비웨이트 투웨이 후드집업 6종 틸블루 KJHD2474     2
#  아우터  제멋                                루나 레글런 벌룬 후드집업 블랙 KJHD2613     2
#  아우터  제멋                               루나 레글런 벌룬 후드집업 네이비 KJHD2613     2
#  아우터  제멋                               루나 레글런 벌룬 후드집업 브라운 KJHD2613     2
#  아우터  제멋                              노바 오버핏 레글런 후드집업 브라운 SOHD2608     1
#  아우터  제멋                                 크리스 워크 헌팅 자켓 베이지 KJJK2581     1
#  아우터  제멋                                   테넌 라이트 블루종 네이비 JUOT2696     0
#  아우터  제멋                                      온오프 트랙자켓 블랙 JJOT2694     0
#  아우터  제멋                                     온오프 트랙자켓 브라운 JJOT2694     0
#  아우터  제멋                                     온오프 트랙자켓 네이비 JJOT2694     0
#  아우터  제멋                                     온오프 트랙자켓 그레이 JJOT2694     0
#  아우터  제멋                                    테넌 라이트 블루종 카키 JUOT2696     0
#  아우터  제멋                               루나 레글런 벌룬 후드집업 오트밀 KJHD2613     0
#  아우터  제멋                             노바 오버핏 레글런 후드집업 딥그레이 SOHD2608     0
#  아우터  제멋                              노바 오버핏 레글런 후드집업 네이비 SOHD2608     0
#
# 기존 수집된 상품 108개 확인 -> 기존 정보 최신화 및 신규 리뷰 수집 예정
# 기존 수집된 개별 리뷰 34243개 확인 -> 중복 리뷰 스킵 예정
#
# [1/108] 처리 중: 리치 오버 MA-1 자켓 블랙 YHJK2269 (총 리뷰 수: 17291개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 87980 | 조회수: 21893)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [2/108] 처리 중: 리치 오버 MA-1 자켓 카키 YHJK2269 (총 리뷰 수: 2718개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 10318 | 조회수: 4901)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [3/108] 처리 중: 카디 오버핏 MA-1 자켓 블랙 YHJK231 (총 리뷰 수: 1909개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 8271 | 조회수: 453)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [4/108] 처리 중: 카디 오버핏 MA-1 자켓 딥그레이 YHJK2 (총 리뷰 수: 1613개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 5795 | 조회수: 399)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [5/108] 처리 중: 엔트 투웨이 후드집업 그레이 KJHD2272 (총 리뷰 수: 1560개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 5518 | 조회수: 337)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [6/108] 처리 중: 헤븐 투웨이 테리 후드집업 8종 그레이 KJH (총 리뷰 수: 1056개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 7549 | 조회수: 6598)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [7/108] 처리 중: 레더 레글런 바시티 자켓 4종 다크그린 YHO (총 리뷰 수: 972개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 4086 | 조회수: 1222)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [8/108] 처리 중: 로그 오버핏 투웨이 기모 후드집업 6종 그레이 (총 리뷰 수: 689개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 5245 | 조회수: 2424)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [9/108] 처리 중: 헤븐 투웨이 테리 후드집업 8종 버건디 KJH (총 리뷰 수: 618개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 3857 | 조회수: 3570)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [10/108] 처리 중: 파일 오버핏 투웨이 후드집업 6종 그레이 KJ (총 리뷰 수: 441개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1897 | 조회수: 301)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [11/108] 처리 중: 엔트 투웨이 후드집업 블랙 KJHD2272 (총 리뷰 수: 429개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1980 | 조회수: 216)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [12/108] 처리 중: 레더 레글런 바시티 자켓 4종 네이비 YHOT (총 리뷰 수: 389개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1909 | 조회수: 950)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [13/108] 처리 중: 헤븐 투웨이 테리 후드집업 8종 블랙 KJHD (총 리뷰 수: 301개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1995 | 조회수: 1254)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [14/108] 처리 중: [2PACK] 헤븐 투웨이 테리 후드집업 8종 (총 리뷰 수: 292개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1578 | 조회수: 692)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [15/108] 처리 중: 레더 레글런 바시티 자켓 4종 퍼플 YHOT2 (총 리뷰 수: 230개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 920 | 조회수: 292)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [16/108] 처리 중: 하이 양기모 후드 집업 다크그레이 HJHD20 (총 리뷰 수: 216개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 917 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [17/108] 처리 중: 로그 오버핏 투웨이 기모 후드집업 6종 블랙  (총 리뷰 수: 216개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1667 | 조회수: 754)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [18/108] 처리 중: 레더 레글런 바시티 자켓 4종 블랙 YHOT2 (총 리뷰 수: 213개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1116 | 조회수: 575)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [19/108] 처리 중: 엔트 투웨이 후드집업 차콜 KJHD2272 (총 리뷰 수: 184개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 857 | 조회수: 135)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [20/108] 처리 중: 파일 오버핏 투웨이 후드집업 6종 블랙 KJH (총 리뷰 수: 179개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 945 | 조회수: 224)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [21/108] 처리 중: 헤븐 투웨이 테리 후드집업 8종 네이비 KJH (총 리뷰 수: 169개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1561 | 조회수: 2769)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [22/108] 처리 중: [2PACK] 엔트 투웨이 후드집업  KJHD (총 리뷰 수: 166개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 586 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [23/108] 처리 중: [2PACK] 파일 오버핏 투웨이 후드집업 6 (총 리뷰 수: 158개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 585 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [24/108] 처리 중: [2PACK] 로그 오버핏 투웨이 기모 후드집 (총 리뷰 수: 147개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 837 | 조회수: 214)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [25/108] 처리 중: 하이 양기모 후드 집업 크림 HJHD2082 (총 리뷰 수: 137개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 699 | 조회수: 142)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [26/108] 처리 중: 로그 오버핏 투웨이 기모 후드집업 6종 다크네 (총 리뷰 수: 136개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 891 | 조회수: 946)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
#
총 리뷰 수: 5개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [85/108] 처리 중: [2PACK] 네트로 오버핏 후드 집업 ISH (총 리뷰 수: 5개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 142)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [86/108] 처리 중: [SETUP] 데이컷 셋업 (후드 or 집업  (총 리뷰 수: 3개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 108)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [87/108] 처리 중: 러쉬 하이넥 크롭 블루종 네이비 NSOT260 (총 리뷰 수: 3개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [88/108] 처리 중: 워크맨 클래식 헤링턴 자켓 라이트베이지 SOJ (총 리뷰 수: 3개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 220)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [89/108] 처리 중: 리테인 MA-1 봄버 자켓 카키 OYJK259 (총 리뷰 수: 3개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 330)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [90/108] 처리 중: 테넌 라이트 블루종 블랙 JUOT2696 (총 리뷰 수: 3개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 485)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [91/108] 처리 중: 아워 루즈핏 모헤어 가디건 4종 샌드베이지 S (총 리뷰 수: 2개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 189)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [92/108] 처리 중: 블렌드 커브 오버핏 헤비 후드집업 5종 퍼플  (총 리뷰 수: 2개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [93/108] 처리 중: 크리스 워크 헌팅 자켓 그린 KJJK2581 (총 리뷰 수: 2개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 217)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [94/108] 처리 중: 스톤 헤비웨이트 투웨이 후드집업 6종 틸블루  (총 리뷰 수: 2개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 125)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [95/108] 처리 중: 루나 레글런 벌룬 후드집업 블랙 KJHD261 (총 리뷰 수: 2개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 60 | 조회수: 584)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [96/108] 처리 중: 루나 레글런 벌룬 후드집업 네이비 KJHD26 (총 리뷰 수: 2개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 53 | 조회수: 571)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [97/108] 처리 중: 루나 레글런 벌룬 후드집업 브라운 KJHD26 (총 리뷰 수: 2개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 59 | 조회수: 307)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [98/108] 처리 중: 노바 오버핏 레글런 후드집업 브라운 SOHD2 (총 리뷰 수: 1개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [99/108] 처리 중: 크리스 워크 헌팅 자켓 베이지 KJJK2581 (총 리뷰 수: 1개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 417)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [100/108] 처리 중: 테넌 라이트 블루종 네이비 JUOT2696 (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 376)
#   [스킵] 리뷰 없음
#
# [101/108] 처리 중: 온오프 트랙자켓 블랙 JJOT2694 (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 317)
#   [스킵] 리뷰 없음
#
# [102/108] 처리 중: 온오프 트랙자켓 브라운 JJOT2694 (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 104)
#   [스킵] 리뷰 없음
#
# [103/108] 처리 중: 온오프 트랙자켓 네이비 JJOT2694 (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 150)
#   [스킵] 리뷰 없음
#
# [104/108] 처리 중: 온오프 트랙자켓 그레이 JJOT2694 (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 109)
#   [스킵] 리뷰 없음
#
# [105/108] 처리 중: 테넌 라이트 블루종 카키 JUOT2696 (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 585)
#   [스킵] 리뷰 없음
#
# [106/108] 처리 중: 루나 레글런 벌룬 후드집업 오트밀 KJHD26 (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 178)
#   [스킵] 리뷰 없음
#
# [107/108] 처리 중: 노바 오버핏 레글런 후드집업 딥그레이 SOHD (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# [108/108] 처리 중: 노바 오버핏 레글런 후드집업 네이비 SOHD2 (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# 모든 상품 정보 최신화 및 CSV 저장 완료!

# %%
# CSV 파일 불러오기
df_reviews = pd.read_csv(f"{BRAND}_reviews_{CATEGORY}.csv")
df_products = pd.read_csv(f"{BRAND}_products_{CATEGORY}.csv")

# goodsNo별로 몇 개의 리뷰(행)가 있는지 카운트 (내림차순 자동 정렬)
review_counts = df_reviews["goodsNo"].value_counts()

# 결과 출력
print(review_counts)

# 작성일 최근 일자 확인
print(df_reviews['작성일'].max())
# Out:
# goodsNo
# 1291017    17291
# 1291016     2718
# 1617883     1909
# 1617884     1613
# 1280017     1560
#            ...
# 4926928        2
# 4926930        2
# 4926932        2
# 4834188        1
# 4412160        1
# Name: count, Length: 99, dtype: int64
# 2026-04-20T23:31:31.000+09:00
