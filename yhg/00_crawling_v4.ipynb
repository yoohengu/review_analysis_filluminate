# %%
import requests
import pandas as pd
import time
import os

os.makedirs("data", exist_ok=True)

# ==========================================
# 만족도 파싱 함수
# ==========================================
def parse_satisfaction(survey):
    if not survey:
        return ""
    questions = survey.get("questions", [])
    parts = []
    for q in questions:
        attribute = q.get("attribute", "")
        answers = q.get("answers", [])
        answer_text = ", ".join([a.get("answerShortText", "") for a in answers])
        parts.append(f"{attribute}: {answer_text}")
    return " / ".join(parts)
# ==========================================
# 리뷰 수집 함수 (새로운 리뷰만 수집)
# ==========================================
def get_reviews(goods_no, target_count, collected_ids, max_pages=9999):
    reviews = []
    stop_crawling = False # 크롤링 중단 플래그
    for page in range(max_pages):
        if len(reviews) >= target_count or stop_crawling:
            break
        
        # 리뷰 요청 보내기
        url = "https://goods.musinsa.com/api2/review/v1/view/list"
        params = {
            "page":              page,
            "pageSize":          10,
            "goodsNo":           goods_no,
            "sort":              "new", # 최신순 정렬
            "selectedSimilarNo": goods_no,
            "myFilter":          "false",
            "hasPhoto":          "false",
            "isExperience":      "false",
        }
        try:
            json_data, status_code = request_json(url, params=params, timeout=10, retry=3)
            if not json_data:
                print(f"  상태코드 {status_code} -> 중단")
                break
                
            data = json_data.get("data", {})
            review_list = data.get("list", [])
            
            if not review_list:
                break
                
            for review in review_list:
                review_no = str(review.get("no", ""))
                
                # 핵심 로직: 이미 수집된 리뷰 번호를 만나면 더 이상 과거 리뷰를 탐색할 필요가 없음
                if review_no in collected_ids:
                    stop_crawling = True
                    break 
                
                profile = review.get("userProfileInfo") or {}
                images  = review.get("images") or []
                reviews.append({
                    "goodsNo":  str(goods_no),
                    "리뷰번호": review_no, # 이 값이 중복 체크의 기준이 됩니다
                    "리뷰타입": review.get("type", ""),
                    "작성자":   profile.get("userNickName", ""),
                    "리뷰내용": review.get("content", ""),
                    "평점":     int(review.get("grade", 0)),
                    "체험단":   review.get("type") == "experience",
                    "구매옵션": review.get("goodsOption", ""),
                    "키":       profile.get("userHeight", ""),
                    "몸무게":   profile.get("userWeight", ""),
                    "성별":     profile.get("reviewSex", ""),
                    "작성일":   review.get("createDate", ""),
                    "만족도":   parse_satisfaction(review.get("reviewSurveySatisfaction")),
                    "사진유무": len(images) > 0,
                    "도움돼요": review.get("likeCount", 0),
                })
                
                if len(reviews) >= target_count:
                    break
                    
            total_pages = data.get("page", {}).get("totalPages", 0)
            if page >= total_pages - 1:
                break
                
            if len(reviews) % 100 == 0 and len(reviews) > 0:
                print(f"  새로운 리뷰 {len(reviews)}개 수집 중...")
            time.sleep(2)
            
        except Exception as e:
            print(f"  리뷰 수집 오류: {e}")
            time.sleep(2)
            break
            
    return reviews
# ==========================================
# 상품 통계(조회수, 판매량) 수집 함수
# ==========================================
def get_goods_stats(goods_no):
    url = f"https://goods-detail.musinsa.com/api2/goods/{goods_no}/stat"
    try:
        json_data, status_code = request_json(url, timeout=10, retry=3)
        if json_data:
            sales_count = json_data.get("data", {}).get("purchaseTotal", 0)
            views_count = json_data.get("data", {}).get("pageViewTotal", 0)
            return sales_count, views_count
        else:
            print(f"  통계 수집 실패 ({goods_no}): {status_code}")
    except Exception as e:
        print(f"  통계 수집 오류 ({goods_no}): {e}")
    return 0, 0
# ==========================================
# escape_excel 함수 추가
# ==========================================
def escape_excel(text):
    if isinstance(text, str) and text.startswith(('-', '=', '+', '@', '#')):
        return "'" + text
    return text
# ==========================================
# 중간 저장 함수
# ==========================================
#def save_product(row_dict):
    df_row = pd.DataFrame([row_dict])
    if os.path.exists(PRODUCTS_CSV):
        df_row.to_csv(PRODUCTS_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_row.to_csv(PRODUCTS_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
def save_reviews(reviews):
    if not reviews:
        return
    df_r = pd.DataFrame(reviews)
    
    # 줄바꿈 문자 제거 (CSV 깨짐 방지)
    df_r["리뷰내용"] = df_r["리뷰내용"].astype(str).str.replace(r'[\n\r\t]', ' ', regex=True)
    # 엑셀 오류 방지 처리
    for col in ['리뷰내용', '작성자']:
        if col in df_r.columns:
            df_r[col] = df_r[col].apply(escape_excel)
    
    if os.path.exists(REVIEWS_CSV):
        df_r.to_csv(REVIEWS_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_r.to_csv(REVIEWS_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
def save_error(goods_no, error_type, message):
    df_e = pd.DataFrame([{
        "goodsNo":    goods_no,
        "error_type": error_type,
        "message":    message,
        "time":       pd.Timestamp.now().strftime("%Y-%m-%d %H:%M:%S"),
    }])
    if os.path.exists(ERRORS_CSV):
        df_e.to_csv(ERRORS_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_e.to_csv(ERRORS_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
        
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36",
    "Referer": "https://www.musinsa.com/",
    "Origin": "https://www.musinsa.com",
}
BRAND         = "filluminate"
CATEGORIES = {
    "001": "상의",
    "002": "아우터",
    "003": "하의",
}
PAGE_SIZE     = 30 # 추측 최대 상한선이 100
#001 : 상의, 002 : 아우터, 003 : 하의
session = requests.Session()
session.headers.update(headers)
session.headers["Referer"] = f"https://www.musinsa.com/brand/{BRAND}"
def request_json(url, params=None, timeout=10, retry=3):
    last_status = None
    last_error = None
    for attempt in range(1, retry + 1):
        try:
            response = session.get(url, params=params, timeout=timeout)
            last_status = response.status_code
            if response.status_code == 200:
                return response.json(), response.status_code
            print(f"요청 실패 ({response.status_code}) -> 재시도 {attempt}/{retry}")
        except Exception as e:
            last_error = e
            print(f"요청 오류 -> 재시도 {attempt}/{retry}: {e}")
        time.sleep(2 * attempt)
    if last_error is not None:
        print(f"최종 요청 오류: {last_error}")
    return None, last_status
for CATEGORY, CATEGORY_NAME in CATEGORIES.items():
    # CSV 경로를 카테고리마다 새로 설정
    PRODUCTS_CSV = f"data/{BRAND}_products_{CATEGORY}.csv"
    REVIEWS_CSV  = f"data/{BRAND}_reviews_{CATEGORY}.csv"
    ERRORS_CSV   = f"data/{BRAND}_errors_{CATEGORY}.csv"
    print(f"\n{'='*50}")
    print(f"▶ 카테고리 [{CATEGORY}] {CATEGORY_NAME} 수집 시작")
    print(f"{'='*50}")
    
    # ==========================================
    # 브랜드 전체 상품 수집
    # ==========================================
    all_data = []
    page = 1
    next_page_url = None  # 다음 페이지 URL (hmacId 포함)
    while True:
        try:
            if next_page_url:
                # 2페이지부터: nextPageUrl을 그대로 사용 (hmacId 포함)
                json_data, status_code = request_json(next_page_url, timeout=10, retry=3)
            else:
                # 1페이지: 기존 방식으로 요청
                url = "https://api.musinsa.com/api2/dp/v2/plp/goods"
                params = {
                    "gf":       "A",
                    "isSoldOut": "true", # 추가
                    "sortCode": "REVIEW",
                    "category": CATEGORY,
                    "brand":    BRAND,
                    "size":     PAGE_SIZE,
                    "caller":   "FLAGSHIP",
                    "page":     page,
                }
                json_data, status_code = request_json(url, params=params, timeout=10, retry=3)
            
            if not json_data: # 데이터가 비어있다면 무한루프 탈출
                print(f"상품 수집 실패 (page {page}): {status_code}")
                break
            
            data = json_data.get("data", {})
            goods_list = data.get("list", [])
            if not goods_list:# 상품 리스트가 비어있다면 더 이상 수집할 데이터가 없다고 판단하여 반복 종료
                break
            
            for item in goods_list:
                is_sold_out = item.get("isSoldOut", False)
                all_data.append({
                    "플랫폼":    "무신사",
                    "카테고리":  CATEGORY_NAME,
                    "브랜드":    item.get("brandName", ""),
                    "goodsNo":  str(item.get("goodsNo", "")),
                    "상품명":    item.get("goodsName", ""),
                    "정가":      item.get("normalPrice", 0),
                    "판매가":    item.get("price", 0),
                    "할인율": item.get("saleRate", 0),
                    "리뷰수":    item.get("reviewCount", 0),
                    "리뷰점수":  item.get("reviewScore", 0),
                    "판매상태":  "SOLD_OUT" if is_sold_out else "SALE",
                })
            pagination = data.get("pagination", {})
            total_pages = pagination.get("totalPages", 1)
            print(f"상품 수집 중... {page}/{total_pages} 페이지 (누적 {len(all_data)}개)")
            
            # 다음 페이지 URL 추출 (hmacId 포함)
            next_page_url = pagination.get("nextPageUrl")
            
            if not pagination.get("hasNext", False) or page >= total_pages:
                break
            page += 1
            time.sleep(2)
        except Exception as e:
            print(f"상품 수집 오류 (page {page}): {e}")
            time.sleep(2)
            break
    # 리뷰 많은 순으로 정렬 (전체)
    df = pd.DataFrame(all_data)
    df = df.sort_values("리뷰수", ascending=False).reset_index(drop=True)
    df["조회수"] = 0
    df["누적판매수"] = 0
    print(f"\n상품 총 {len(df)}개 수집 완료 (리뷰 많은 순)")
    print(df[["카테고리", "브랜드", "상품명", "리뷰수"]].to_string(index=False))
    # ==========================================
    # 재시작 로직 - 이미 수집된 goodsNo 및 리뷰번호 확인
    # ==========================================
    collected_review_ids = set()
    if os.path.exists(PRODUCTS_CSV): # products csv 파일 존재시
        df_existing = pd.read_csv(PRODUCTS_CSV)
        df_existing["goodsNo"] = df_existing["goodsNo"].astype(str)
        df_existing.set_index("goodsNo", inplace=True)
        print(f"\n기존 수집된 상품 {len(df_existing)}개 확인 -> 기존 정보 최신화 및 신규 리뷰 수집 예정")
    else:
        df_existing = pd.DataFrame() # 빈 데이터프레임 생성
        print("\n기존 수집 상품 파일 없음 -> 처음부터 수집 시작")
    if os.path.exists(REVIEWS_CSV): # reviews csv 파일 존재시
        df_existing_reviews = pd.read_csv(REVIEWS_CSV)
        collected_review_ids = set(df_existing_reviews["리뷰번호"].astype(str).tolist())
        print(f"기존 수집된 개별 리뷰 {len(collected_review_ids)}개 확인 -> 중복 리뷰 스킵 예정")
    # ==========================================
    # 전체 상품 리뷰 및 통계 수집
    # ==========================================
    total_items = len(df)
    for idx, row in df.iterrows():
        goods_no     = row["goodsNo"]
        target_count = int(row["리뷰수"])
        current_item = idx + 1
        
        is_new_product = df_existing.empty or goods_no not in df_existing.index # 상품번호가 기존에 없는 번호라면 True(신규 상품)
        print(f"\n[{current_item}/{total_items}] 처리 중: {str(row['상품명'])[:25]} (총 리뷰 수: {target_count}개)")
        # 1. 통계 수집 (기존/신규 상관없이 무조건 수집하여 최신화)
        try:
            sales, views = get_goods_stats(goods_no)
        except Exception as e:
            print(f"  통계 수집 실패: {e}")
            save_error(goods_no, "stats", str(e))
            # API 오류 시 기존 데이터가 있다면 유지, 없다면 0으로 처리
            if not is_new_product:
                sales = df_existing.at[goods_no, "누적판매수"]
                views = df_existing.at[goods_no, "조회수"]
            else:
                sales, views = 0, 0
        time.sleep(2)
        # # 2. Survey 수집 (신규 상품일 경우에만 진행하도록 권장. 필요시 무조건 수집으로 변경 가능)
        # # 신규 상품인 경우만 진행하도록 설계되어 있음.
        # if is_new_product:
        #     try:
        #         survey_rows = get_survey(goods_no)
        #         save_survey(survey_rows)
        #         print(f"  survey {len(survey_rows)}행 저장 완료 (신규)")
        #     except Exception as e:
        #         print(f"  survey 수집 실패: {e}")
        #         save_error(goods_no, "survey", str(e))
        #     time.sleep(2)
        # 3. 데이터프레임(df_existing)에 최신 정보 업데이트 또는 추가
        updated_info = {
            "플랫폼":    row["플랫폼"],
            "카테고리":  row["카테고리"],
            "브랜드":    row["브랜드"],
            "상품명":    row["상품명"],
            "정가":      row["정가"],
            "판매가":    row["판매가"],
            "할인율": row["할인율"],
            "조회수":    views,
            "누적판매수": sales,
            "리뷰수":    row["리뷰수"],
            "리뷰점수":  row["리뷰점수"],
            "판매상태":  row["판매상태"],
        }
        
        # Pandas를 이용해 해당 goods_no 행을 최신 정보로 덮어쓰기 (없으면 새로 생성됨)
        for key, value in updated_info.items():
            df_existing.at[goods_no, key] = value
            
        if is_new_product:
            print(f"  -> 신규 상품 저장 완료 (누적판매: {sales} | 조회수: {views})")
        else:
            print(f"  -> 기존 상품 정보 최신화 완료 (누적판매: {sales} | 조회수: {views})")
        # 4. 리뷰 수집 로직 (기존 코드와 동일)
        if not goods_no or target_count == 0:
            print(f"  [스킵] 리뷰 없음")
        else:
            print(f"  새로운 리뷰 수집 확인 중...")
            try:
                reviews = get_reviews(goods_no, target_count=target_count, collected_ids=collected_review_ids)
                if len(reviews) > 0:
                    save_reviews(reviews)
                    collected_review_ids.update([str(r["리뷰번호"]) for r in reviews])
                    print(f"  -> 새로운 리뷰 {len(reviews)}개 수집 및 추가 완료!")
                else:
                    print(f"  -> 추가된 새로운 리뷰가 없습니다.")
            except Exception as e:
                print(f"  리뷰 수집 실패: {e}")
                save_error(goods_no, "review", str(e))
                
        time.sleep(2)
    # ==========================================
    # 최종 최신화된 상품 데이터를 CSV에 덮어쓰기
    # ==========================================
    df_existing.reset_index(inplace=True)
    if 'index' in df_existing.columns:
        df_existing.rename(columns={'index': 'goodsNo'}, inplace=True)
    df_existing.to_csv(PRODUCTS_CSV, index=False, encoding="utf-8-sig")
    print("\n모든 상품 정보 최신화 및 CSV 저장 완료!")
# Out:
# ==================================================
# ▶ 카테고리 [001] 상의 수집 시작
# ==================================================
# 상품 수집 중... 1/8 페이지 (누적 30개)
# 상품 수집 중... 2/8 페이지 (누적 60개)
# 상품 수집 중... 3/8 페이지 (누적 90개)
# 상품 수집 중... 4/8 페이지 (누적 120개)
# 상품 수집 중... 5/8 페이지 (누적 150개)
# 상품 수집 중... 6/8 페이지 (누적 180개)
# 상품 수집 중... 7/8 페이지 (누적 210개)
# 상품 수집 중... 8/8 페이지 (누적 214개)
#
# 상품 총 214개 수집 완료 (리뷰 많은 순)
# 카테고리    브랜드                                    상품명   리뷰수
#   상의 필루미네이트             옵티멀 베이직 셔츠-화이트[린넨＆옥스포드 선택] 14475
#   상의 필루미네이트                   [블랙]SET B-스테디 하프 폴라넥 14299
#   상의 필루미네이트           [오정규 PICK] 오버핏 포레스트 체크 셔츠-블랙 11805
#   상의 필루미네이트                    [블랙]B-스테디 하프 폴라넥-블랙  9555
#   상의 필루미네이트                오버핏 아치 로고 스웨트 셔츠-3Color  5260
#   상의 필루미네이트                  오버핏 그래피티 로고 후디-6Color  5135
#   상의 필루미네이트                      오버핏 포레스트 체크 셔츠-핑크  4949
#   상의 필루미네이트                  [블랙]B-스테디 하프 폴라넥-아이보리  3685
#   상의 필루미네이트                     오버핏 그래피티 로고 후디-오트밀  3230
#   상의 필루미네이트                      오버핏 그래피티 로고 후디-블랙  3009
#   상의 필루미네이트             옵티멀 베이직 셔츠-네이비[린넨&옥스포드 선택]  2495
#   상의 필루미네이트                 오버핏 1988 스웨트 셔츠-3Color  2488
#   상의 필루미네이트                     오버핏 그래피티 로고 후디-네이비  1873
#   상의 필루미네이트                      오버핏 포레스트 체크 셔츠-그린  1577
#   상의 필루미네이트                      오버핏 마드라스 체크 셔츠-핑크  1357
#   상의 필루미네이트               FLM 클럽 스포츠 저지 티셔츠-3Color   670
#   상의 필루미네이트                      오버핏 마드라스 체크 셔츠-블랙   658
#   상의 필루미네이트   [스토커즈 pick] 올 데이 린넨 라이크 하프 셔츠-5Color   590
#   상의 필루미네이트                        [SET]썸머 컬렉션 티셔츠   501
#   상의 필루미네이트                       88 피그먼트 후디-오프화이트   431
#   상의 필루미네이트         [너드킹 pick] 올 데이 옥스포드 셔츠-7Color   336
#   상의 필루미네이트                 올 데이 옥스포드 하프 셔츠-5Color   298
#   상의 필루미네이트                      오버핏 마드라스 체크 셔츠-카키   293
#   상의 필루미네이트      [스토커즈 pick] 올 데이 린넨 라이크 셔츠-5Color   248
#   상의 필루미네이트        [해피가이정호 pick] 멀티 스트라이프 롱 슬리브-블랙   247
#   상의 필루미네이트                      시어서커 스트라이프 셔츠-네이비   158
#   상의 필루미네이트                  모던 그래픽 래글런 티셔츠-2Color   152
#   상의 필루미네이트                      88 스프레이 저지 티셔츠-블랙   142
#   상의 필루미네이트                    FLM 스티치 로고 후디-스카이블루   125
#   상의 필루미네이트                          버닝 하트 티셔츠-화이트   113
#   상의 필루미네이트                   [2PACK]스몰 어센틱 로고 티셔츠   105
#   상의 필루미네이트          [너드킹 pick] 멀티 스트라이프 롱 슬리브-브라운   102
#   상의 필루미네이트                     88 스프레이 저지 티셔츠-화이트    75
#   상의 필루미네이트                       스몰 어센틱 로고 티셔츠-블랙    68
#   상의 필루미네이트                           버닝 하트 티셔츠-블랙    58
#   상의 필루미네이트                  시그니처 어센틱 로고 후디-4Color    54
#   상의 필루미네이트                          버닝 하트 티셔츠-브라운    54
#   상의 필루미네이트                       FLM 스티치 로고 후디-차콜    40
#   상의 필루미네이트 [스토커즈 pick] 세미 크롭 톤온톤 스트라이프 티셔츠-3Color    29
#   상의 필루미네이트         [스토커즈 pick] 멀티 스트라이프 롱 슬리브-그레이    28
#   상의 필루미네이트                      스몰 어센틱 로고 티셔츠-화이트    26
#   상의 필루미네이트                    시그니처 어센틱 로고 티셔츠-화이트    24
#   상의 필루미네이트                         코듀로이 포켓 셔츠-베이지    21
#   상의 필루미네이트                       FLM 스티치 로고 후디-블랙    20
#   상의 필루미네이트                      시그니처 어센틱 로고 후디-블랙    19
#   상의 필루미네이트                           심볼 패널드 후디-블랙    18
#   상의 필루미네이트                      DFAO 아플리케 후디-다크그린    18
#   상의 필루미네이트                   FLM 스티치 로고 스웨트 셔츠-블랙    16
#   상의 필루미네이트                      러스틱 빈티지 체크 셔츠-네이비    14
#   상의 필루미네이트                      심볼 스트라이프 롱 슬리브-핑크    14
#   상의 필루미네이트                  시그니처 어센틱 로고 스웨트셔츠-오트밀    14
#   상의 필루미네이트                      갤럭시 심볼 로고 티셔츠-화이트    14
#   상의 필루미네이트                        DFAO 아플리케 후디-블랙    13
#   상의 필루미네이트                       DFAO 아플리케 후디-브라운    13
#   상의 필루미네이트                      FLM 스티치 로고 후디-네이비    13
#   상의 필루미네이트                       갤럭시 심볼 로고 티셔츠-블랙    13
#   상의 필루미네이트                      FLM 스티치 로고 후디-브라운    13
#   상의 필루미네이트                       88 자가드 라운드 니트-블랙    12
#   상의 필루미네이트                      시그니처 어센틱 로고 후디-차콜    12
#   상의 필루미네이트                     시그니처 어센틱 로고 후디-브라운    12
#   상의 필루미네이트                    시어서커 스트라이프 셔츠-스카이블루    12
#   상의 필루미네이트         [스토커즈 pick] 세미 크롭 체크 하프 셔츠-그레이    11
#   상의 필루미네이트                     워시드 패널 롱 슬리브-오프화이트    11
#   상의 필루미네이트                      88 피그먼트 티셔츠-오프화이트    11
#   상의 필루미네이트                 시그니처 어센틱 로고 티셔츠-라이트그레이    11
#   상의 필루미네이트                        롤 업 체크 하프 셔츠-핑크    10
#   상의 필루미네이트                 쿨 코튼 서울 어센틱 티셔츠-2Color    10
#   상의 필루미네이트                       워시드 하찌 라운드 니트-차콜    10
#   상의 필루미네이트                     올드 스쿨 플란넬 체크 셔츠-그린    10
#   상의 필루미네이트                     스트라이프 럭비 롱 슬리브-네이비    10
#   상의 필루미네이트                 (W) 워시드 패널 롱 슬리브-오프화이트    10
#   상의 필루미네이트                 FLM 빈티지 하트 그래픽 티셔츠-화이트    10
#   상의 필루미네이트                     올드 스쿨 플란넬 체크 셔츠-레드     9
#   상의 필루미네이트                      심볼 스트라이프 롱 슬리브-블랙     9
#   상의 필루미네이트                      심볼 스트라이프 롱 슬리브-블루     9
#   상의 필루미네이트                    시그니처 어센틱 로고 티셔츠-네이비     9
#   상의 필루미네이트                   스몰 어센틱 로고 티셔츠-라이트그레이     9
#   상의 필루미네이트                     올드 스쿨 플란넬 체크 셔츠-블랙     8
#   상의 필루미네이트                         코듀로이 포켓 셔츠-브라운     8
#   상의 필루미네이트                           페이드 체크 셔츠-블랙     8
#   상의 필루미네이트                          페이드 체크 셔츠-브라운     8
#   상의 필루미네이트                       DFAO 아플리케 후디-네이비     8
#   상의 필루미네이트                    FLM 부클 로고 스웨트셔츠-네이비     8
#   상의 필루미네이트                    (W) 워시드 패널 롱 슬리브-차콜     8
#   상의 필루미네이트               시그니처 어센틱 로고 스웨트셔츠-멜란지그레이     8
#   상의 필루미네이트         [스토커즈 pick] 세미 크롭 체크 하프 셔츠-네이비     7
#   상의 필루미네이트                     (W) 리브드 버튼 롱슬리브-카키     7
#   상의 필루미네이트                        브리즈 체크 셔츠-스카이블루     7
#   상의 필루미네이트                       브러쉬드 체크 오버 셔츠-핑크     7
#   상의 필루미네이트                      모노 스트라이프 스웨트셔츠-블랙     7
#   상의 필루미네이트                     시그니처 어센틱 로고 티셔츠-핑크     7
#   상의 필루미네이트                  FLM 빈티지 하트 그래픽 티셔츠-블랙     7
#   상의 필루미네이트                         키체인 그래픽 티셔츠-블랙     6
#   상의 필루미네이트                     키체인 그래픽 티셔츠-멜란지그레이     6
#   상의 필루미네이트                   세미 크롭 체크 하프 셔츠-스카이블루     6
#   상의 필루미네이트                      오벌 1988 리그 후디-브라운     6
#   상의 필루미네이트                     FLM 부클 로고 스웨트셔츠-블랙     6
#   상의 필루미네이트                        워시드 패널 롱 슬리브-차콜     6
#   상의 필루미네이트                   시그니처 어센틱 로고 스웨트셔츠-블랙     6
#   상의 필루미네이트         [스토커즈 pick] 파스텔 체크 링클 셔츠-스카이블루     5
#   상의 필루미네이트                     롤 업 체크 하프 셔츠-라이트그린     5
#   상의 필루미네이트                        키체인 그래픽 티셔츠-화이트     5
#   상의 필루미네이트                 FLM 부클 로고 스웨트셔츠-멜란지그레이     5
#   상의 필루미네이트                    스몰 어센틱 스트라이프 후디-브라운     5
#   상의 필루미네이트                     시그니처 어센틱 로고 티셔츠-블랙     5
#   상의 필루미네이트                        롤 업 체크 하프 셔츠-블랙     4
#   상의 필루미네이트                     (W) 리브드 버튼 롱슬리브-차콜     4
#   상의 필루미네이트                     아이덴티티 심볼 후디-멜란지그레이     4
#   상의 필루미네이트                    브러쉬드 체크 오버 셔츠-스카이블루     4
#   상의 필루미네이트                     88 자가드 라운드 니트-아이보리     4
#   상의 필루미네이트                       러스틱 빈티지 체크 셔츠-카키     4
#   상의 필루미네이트                          심볼 패널드 후디-그레이     4
#   상의 필루미네이트                      스트라이프 럭비 롱 슬리브-와인     4
#   상의 필루미네이트                       FLM 스티치 로고 후디-와인     4
#   상의 필루미네이트                  시그니처 어센틱 로고 스웨트셔츠-네이비     4
#   상의 필루미네이트                         88 피그먼트 티셔츠-블랙     4
#   상의 필루미네이트                  시그니처 어센틱 로고 티셔츠-스카이블루     4
#   상의 필루미네이트            [스토커즈 pick] 파스텔 체크 링클 셔츠-블랙     3
#   상의 필루미네이트                        파스텔 체크 링클 셔츠-핑크     3
#   상의 필루미네이트                       (W) 88 링거 티셔츠-차콜     3
#   상의 필루미네이트                   (W) 시어 옴브레 체크 셔츠-베이지     3
#   상의 필루미네이트                   FLM 그래픽 니트 풀오버-스카이블루     3
#   상의 필루미네이트                       워시드 아치 로고 후디-네이비     3
#   상의 필루미네이트                      심볼 자가드 라운드 니트-그레이     3
#   상의 필루미네이트                     스몰 어센틱 스트라이프 후디-카키     3
#   상의 필루미네이트                       워시드 패널 롱 슬리브-베이지     3
#   상의 필루미네이트                (W) FLM 스티치 로고 크롭 후디-와인     3
#   상의 필루미네이트             (W) 하프톤 트랙 크롭 스웨트셔츠-멜란지그레이     2
#   상의 필루미네이트                    (W) 시어 옴브레 체크 셔츠-블랙     2
#   상의 필루미네이트                         심볼 메쉬 니트 집업-블랙     2
#   상의 필루미네이트                          브리즈 체크 셔츠-브라운     2
#   상의 필루미네이트                    심볼 자가드 라운드 니트-스카이블루     2
#   상의 필루미네이트                       오벌 1988 리그 후디-블랙     2
#   상의 필루미네이트                        스몰 캐피탈 로고 후디-블랙     2
#   상의 필루미네이트                     (W) 시스루 루즈핏 셔츠-네이비     2
#   상의 필루미네이트                 쿨 코튼 스몰 어센틱 로고 티셔츠-화이트     1
#   상의 필루미네이트                    FLM 아플리케 티셔츠-라이트그레이     1
#   상의 필루미네이트                    소프트 타탄 체크 링클 셔츠-네이비     1
#   상의 필루미네이트                       어센틱 민트 초코 티셔츠-블랙     1
#   상의 필루미네이트                      어센틱 민트 초코 티셔츠-네이비     1
#   상의 필루미네이트                      (W) 88 링거 티셔츠-마젠타     1
#   상의 필루미네이트                       FLM 아플리케 티셔츠-화이트     1
#   상의 필루미네이트                    (W) 88 링거 티셔츠-라이트블루     1
#   상의 필루미네이트                        플루이드 레터링 티셔츠-블랙     1
#   상의 필루미네이트                         심볼 메쉬 니트 집업-핑크     1
#   상의 필루미네이트                         심볼 메쉬 니트 집업-블루     1
#   상의 필루미네이트                        워시드 아치 로고 후디-차콜     1
#   상의 필루미네이트                        워시드 아치 로고 후디-카키     1
#   상의 필루미네이트                      오벌 1988 리그 후디-오트밀     1
#   상의 필루미네이트                     스몰 캐피탈 로고 후디-라이트카키     1
#   상의 필루미네이트                (W) FLM 스티치 로고 크롭 후디-차콜     1
#   상의 필루미네이트                     멀티 스트라이프 포켓 티셔츠-블랙     0
#   상의 필루미네이트                   멀티 스트라이프 포켓 티셔츠-아이보리     0
#   상의 필루미네이트                오픈 카라 시어서커 체크 하프 셔츠-네이비     0
#   상의 필루미네이트                 오픈 카라 시어서커 체크 하프 셔츠-그린     0
#   상의 필루미네이트                 오픈 카라 시어서커 체크 하프 셔츠-블랙     0
#   상의 필루미네이트                오픈 카라 시어서커 체크 하프 셔츠-브라운     0
#   상의 필루미네이트                         펀칭 카라 하프 니트-블랙     0
#   상의 필루미네이트                       펀칭 카라 하프 니트-아이보리     0
#   상의 필루미네이트                         링클 타탄 체크 셔츠-그린     0
#   상의 필루미네이트                      링클 타탄 체크 셔츠-스카이블루     0
#   상의 필루미네이트                       투 톤 아치 로고 티셔츠-블랙     0
#   상의 필루미네이트                       투 톤 아치 로고 티셔츠-차콜     0
#   상의 필루미네이트                      투 톤 아치 로고 티셔츠-네이비     0
#   상의 필루미네이트                      투 톤 아치 로고 티셔츠-화이트     0
#   상의 필루미네이트                       FLM 스몰 로고 티셔츠-블랙     0
#   상의 필루미네이트                   FLM 스몰 로고 티셔츠-멜란지그레이     0
#   상의 필루미네이트                      FLM 스몰 로고 티셔츠-화이트     0
#   상의 필루미네이트                       풀사이드 스프레이 티셔츠-블랙     0
#   상의 필루미네이트                     풀사이드 스프레이 티셔츠-아이보리     0
#   상의 필루미네이트                  쿨 코튼 스몰 어센틱 로고 티셔츠-블랙     0
#   상의 필루미네이트                        부클 풀오버 하프 니트-블랙     0
#   상의 필루미네이트                      부클 풀오버 하프 니트-아이보리     0
#   상의 필루미네이트                       비디유 나일론 하프 셔츠-차콜     0
#   상의 필루미네이트                    비디유 나일론 하프 셔츠-스카이블루     0
#   상의 필루미네이트                     비디유 나일론 하프 셔츠-아이보리     0
#   상의 필루미네이트                           볼링 하프 셔츠-네이비     0
#   상의 필루미네이트                           볼링 하프 셔츠-베이지     0
#   상의 필루미네이트                    소프트 타탄 체크 링클 셔츠-그레이     0
#   상의 필루미네이트                        FLM 아플리케 티셔츠-블랙     0
#   상의 필루미네이트                      어센틱 민트 초코 티셔츠-화이트     0
#   상의 필루미네이트                      (W) 어센틱 로고 티셔츠-블랙     0
#   상의 필루미네이트                      (W) 어센틱 로고 티셔츠-핑크     0
#   상의 필루미네이트                     (W) 어센틱 로고 티셔츠-화이트     0
#   상의 필루미네이트                       (W) 심볼 셔링 티셔츠-블랙     0
#   상의 필루미네이트                      (W) 심볼 셔링 티셔츠-화이트     0
#   상의 필루미네이트                   (W) 시스루 루즈핏 셔츠-스카이블루     0
#   상의 필루미네이트                    (W) 시스루 루즈핏 셔츠-아이보리     0
#   상의 필루미네이트                    (W) FLM 아플리케 티셔츠-블랙     0
#   상의 필루미네이트                   (W) FLM 아플리케 티셔츠-네이비     0
#   상의 필루미네이트                   (W) FLM 아플리케 티셔츠-화이트     0
#   상의 필루미네이트                (W) 언더워터 DTP 그래픽 티셔츠-블랙     0
#   상의 필루미네이트                (W) 언더워터 DTP 그래픽 티셔츠-레몬     0
#   상의 필루미네이트              (W) 언더워터 DTP 그래픽 티셔츠-아이보리     0
#   상의 필루미네이트                      플루이드 레터링 티셔츠-아이보리     0
#   상의 필루미네이트                   (W) 데미지드 벨벳 크롭 니트-차콜     0
#   상의 필루미네이트                  (W) 데미지드 벨벳 크롭 니트-그레이     0
#   상의 필루미네이트                 (W) 데미지드 벨벳 크롭 니트-아이보리     0
#   상의 필루미네이트                (W) 하프톤 트랙 크롭 스웨트셔츠-네이비     0
#   상의 필루미네이트                (W) 하프톤 트랙 크롭 스웨트셔츠-오트밀     0
#   상의 필루미네이트                       (W) 셔링 디테일 셔츠-차콜     0
#   상의 필루미네이트                    (W) 셔링 디테일 셔츠-스카이블루     0
#   상의 필루미네이트                      (W) 셔링 디테일 셔츠-화이트     0
#   상의 필루미네이트                    FLM 그래픽 니트 풀오버-다크퍼플     0
#   상의 필루미네이트                  FLM 그래픽 니트 풀오버-멜란지그레이     0
#   상의 필루미네이트                         아이덴티티 심볼 후디-블랙     0
#   상의 필루미네이트                      워시드 하찌 라운드 니트-베이지     0
#   상의 필루미네이트                       심볼 자가드 라운드 니트-핑크     0
#   상의 필루미네이트                    스몰 캐피탈 로고 후디-라이트그레이     0
#   상의 필루미네이트                     어센틱 로고 와플 롱 슬리브-블랙     0
#   상의 필루미네이트                    어센틱 로고 와플 롱 슬리브-베이지     0
#   상의 필루미네이트                (W) FLM 스티치 로고 크롭 후디-블랙     0
#   상의 필루미네이트                   (W) 워시드 패널 롱 슬리브-베이지     0
#   상의 필루미네이트                   FLM 스티치 로고 스웨트 셔츠-크림     0
#
# 기존 수집 상품 파일 없음 -> 처음부터 수집 시작
#
# [1/214] 처리 중: 옵티멀 베이직 셔츠-화이트[린넨＆옥스포드 선택 (총 리뷰 수: 14475개)
#   -> 신규 상품 저장 완료 (누적판매: 97419 | 조회수: 21270)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   새로운 리뷰 2600개 수집 중...
#   새로운 리뷰 2700개 수집 중...
#   새로운 리뷰 2800개 수집 중...
#   새로운 리뷰 2900개 수집 중...
#   새로운 리뷰 3000개 수집 중...
#   새로운 리뷰 3100개 수집 중...
#   새로운 리뷰 3200개 수집 중...
#   새로운 리뷰 3300개 수집 중...
#   새로운 리뷰 3400개 수집 중...
#   새로운 리뷰 3500개 수집 중...
#   새로운 리뷰 3600개 수집 중...
#   새로운 리뷰 3700개 수집 중...
#   새로운 리뷰 3800개 수집 중...
#   새로운 리뷰 3900개 수집 중...
#   새로운 리뷰 4000개 수집 중...
#   새로운 리뷰 4100개 수집 중...
#   새로운 리뷰 4200개 수집 중...
#   새로운 리뷰 4300개 수집 중...
#   새로운 리뷰 4400개 수집 중...
#   새로운 리뷰 4500개 수집 중...
#   새로운 리뷰 4600개 수집 중...
#   새로운 리뷰 4700개 수집 중...
#   새로운 리뷰 4800개 수집 중...
#   새로운 리뷰 4900개 수집 중...
#   새로운 리뷰 5000개 수집 중...
#   새로운 리뷰 5100개 수집 중...
#   새로운 리뷰 5200개 수집 중...
#   새로운 리뷰 5300개 수집 중...
#   새로운 리뷰 5400개 수집 중...
#   새로운 리뷰 5500개 수집 중...
#   새로운 리뷰 5600개 수집 중...
#   새로운 리뷰 5700개 수집 중...
#   새로운 리뷰 5800개 수집 중...
#   새로운 리뷰 5900개 수집 중...
#   새로운 리뷰 6000개 수집 중...
#   새로운 리뷰 6100개 수집 중...
#   새로운 리뷰 6200개 수집 중...
#   새로운 리뷰 6300개 수집 중...
#   새로운 리뷰 6400개 수집 중...
#   새로운 리뷰 6500개 수집 중...
#   새로운 리뷰 6600개 수집 중...
#   새로운 리뷰 6700개 수집 중...
#   새로운 리뷰 6800개 수집 중...
#   새로운 리뷰 6900개 수집 중...
#   새로운 리뷰 7000개 수집 중...
#   새로운 리뷰 7100개 수집 중...
#   새로운 리뷰 7200개 수집 중...
#   새로운 리뷰 7300개 수집 중...
#   새로운 리뷰 7400개 수집 중...
#   새로운 리뷰 7500개 수집 중...
#   새로운 리뷰 7600개 수집 중...
#   새로운 리뷰 7700개 수집 중...
#   새로운 리뷰 7800개 수집 중...
#   새로운 리뷰 7900개 수집 중...
#   새로운 리뷰 8000개 수집 중...
#   새로운 리뷰 8100개 수집 중...
#   새로운 리뷰 8200개 수집 중...
#   새로운 리뷰 8300개 수집 중...
#   새로운 리뷰 8400개 수집 중...
#   새로운 리뷰 8500개 수집 중...
#   새로운 리뷰 8600개 수집 중...
#   새로운 리뷰 8700개 수집 중...
#   새로운 리뷰 8800개 수집 중...
#   새로운 리뷰 8900개 수집 중...
#   새로운 리뷰 9000개 수집 중...
#   새로운 리뷰 9100개 수집 중...
#   새로운 리뷰 9200개 수집 중...
#   새로운 리뷰 9300개 수집 중...
#   새로운 리뷰 9400개 수집 중...
#   새로운 리뷰 9500개 수집 중...
#   새로운 리뷰 9600개 수집 중...
#   새로운 리뷰 9700개 수집 중...
#   새로운 리뷰 9800개 수집 중...
#   새로운 리뷰 9900개 수집 중...
#   새로운 리뷰 10000개 수집 중...
#   새로운 리뷰 10100개 수집 중...
#   새로운 리뷰 10200개 수집 중...
#   새로운 리뷰 10300개 수집 중...
#   새로운 리뷰 10400개 수집 중...
#   새로운 리뷰 10500개 수집 중...
#   새로운 리뷰 10600개 수집 중...
#   새로운 리뷰 10700개 수집 중...
#   새로운 리뷰 10800개 수집 중...
#   새로운 리뷰 10900개 수집 중...
#   새로운 리뷰 11000개 수집 중...
#   새로운 리뷰 11100개 수집 중...
#   새로운 리뷰 11200개 수집 중...
#   새로운 리뷰 11300개 수집 중...
#   새로운 리뷰 11400개 수집 중...
#   새로운 리뷰 11500개 수집 중...
#   새로운 리뷰 11600개 수집 중...
#   새로운 리뷰 11700개 수집 중...
#   새로운 리뷰 11800개 수집 중...
#   새로운 리뷰 11900개 수집 중...
#   새로운 리뷰 12000개 수집 중...
#   새로운 리뷰 12100개 수집 중...
#   새로운 리뷰 12200개 수집 중...
#   새로운 리뷰 12300개 수집 중...
#   새로운 리뷰 12400개 수집 중...
#   새로운 리뷰 12500개 수집 중...
#   새로운 리뷰 12600개 수집 중...
#   새로운 리뷰 12700개 수집 중...
#   새로운 리뷰 12800개 수집 중...
#   새로운 리뷰 12900개 수집 중...
#   새로운 리뷰 13000개 수집 중...
#   새로운 리뷰 13100개 수집 중...
#   새로운 리뷰 13200개 수집 중...
#   새로운 리뷰 13300개 수집 중...
#   새로운 리뷰 13400개 수집 중...
#   새로운 리뷰 13500개 수집 중...
#   새로운 리뷰 13600개 수집 중...
#   새로운 리뷰 13700개 수집 중...
#   새로운 리뷰 13800개 수집 중...
#   새로운 리뷰 13900개 수집 중...
#   새로운 리뷰 14000개 수집 중...
#   새로운 리뷰 14100개 수집 중...
#   새로운 리뷰 14200개 수집 중...
#   새로운 리뷰 14300개 수집 중...
#   새로운 리뷰 14400개 수집 중...
#   -> 새로운 리뷰 14475개 수집 및 추가 완료!
#
# [2/214] 처리 중: [블랙]SET B-스테디 하프 폴라넥 (총 리뷰 수: 14299개)
#   -> 신규 상품 저장 완료 (누적판매: 67968 | 조회수: 574)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   새로운 리뷰 2600개 수집 중...
#   새로운 리뷰 2700개 수집 중...
#   새로운 리뷰 2800개 수집 중...
#   새로운 리뷰 2900개 수집 중...
#   새로운 리뷰 3000개 수집 중...
#   새로운 리뷰 3100개 수집 중...
#   새로운 리뷰 3200개 수집 중...
#   새로운 리뷰 3300개 수집 중...
#   새로운 리뷰 3400개 수집 중...
#   새로운 리뷰 3500개 수집 중...
#   새로운 리뷰 3600개 수집 중...
#   새로운 리뷰 3700개 수집 중...
#   새로운 리뷰 3800개 수집 중...
#   새로운 리뷰 3900개 수집 중...
#   새로운 리뷰 4000개 수집 중...
#   새로운 리뷰 4100개 수집 중...
#   새로운 리뷰 4200개 수집 중...
#   새로운 리뷰 4300개 수집 중...
#   새로운 리뷰 4400개 수집 중...
#   새로운 리뷰 4500개 수집 중...
#   새로운 리뷰 4600개 수집 중...
#   새로운 리뷰 4700개 수집 중...
#   새로운 리뷰 4800개 수집 중...
#   새로운 리뷰 4900개 수집 중...
#   새로운 리뷰 5000개 수집 중...
#   새로운 리뷰 5100개 수집 중...
#   새로운 리뷰 5200개 수집 중...
#   새로운 리뷰 5300개 수집 중...
#   새로운 리뷰 5400개 수집 중...
#   새로운 리뷰 5500개 수집 중...
#   새로운 리뷰 5600개 수집 중...
#   새로운 리뷰 5700개 수집 중...
#   새로운 리뷰 5800개 수집 중...
#   새로운 리뷰 5900개 수집 중...
#   새로운 리뷰 6000개 수집 중...
#   새로운 리뷰 6100개 수집 중...
#   새로운 리뷰 6200개 수집 중...
#   새로운 리뷰 6300개 수집 중...
#   새로운 리뷰 6400개 수집 중...
#   새로운 리뷰 6500개 수집 중...
#   새로운 리뷰 6600개 수집 중...
#   새로운 리뷰 6700개 수집 중...
#   새로운 리뷰 6800개 수집 중...
#   새로운 리뷰 6900개 수집 중...
#   새로운 리뷰 7000개 수집 중...
#   새로운 리뷰 7100개 수집 중...
#   새로운 리뷰 7200개 수집 중...
#   새로운 리뷰 7300개 수집 중...
#   새로운 리뷰 7400개 수집 중...
#   새로운 리뷰 7500개 수집 중...
#   새로운 리뷰 7600개 수집 중...
#   새로운 리뷰 7700개 수집 중...
#   새로운 리뷰 7800개 수집 중...
#   새로운 리뷰 7900개 수집 중...
#   새로운 리뷰 8000개 수집 중...
#   새로운 리뷰 8100개 수집 중...
#   새로운 리뷰 8200개 수집 중...
#   새로운 리뷰 8300개 수집 중...
#   새로운 리뷰 8400개 수집 중...
#   새로운 리뷰 8500개 수집 중...
#   새로운 리뷰 8600개 수집 중...
#   새로운 리뷰 8700개 수집 중...
#   새로운 리뷰 8800개 수집 중...
#   새로운 리뷰 8900개 수집 중...
#   새로운 리뷰 9000개 수집 중...
#   새로운 리뷰 9100개 수집 중...
#   새로운 리뷰 9200개 수집 중...
#   새로운 리뷰 9300개 수집 중...
#   새로운 리뷰 9400개 수집 중...
#   새로운 리뷰 9500개 수집 중...
#   새로운 리뷰 9600개 수집 중...
#   새로운 리뷰 9700개 수집 중...
#   새로운 리뷰 9800개 수집 중...
#   새로운 리뷰 9900개 수집 중...
#   새로운 리뷰 10000개 수집 중...
#   새로운 리뷰 10100개 수집 중...
#   새로운 리뷰 10200개 수집 중...
#   새로운 리뷰 10300개 수집 중...
#   새로운 리뷰 10400개 수집 중...
#   새로운 리뷰 10500개 수집 중...
#   새로운 리뷰 10600개 수집 중...
#   새로운 리뷰 10700개 수집 중...
#   새로운 리뷰 10800개 수집 중...
#   새로운 리뷰 10900개 수집 중...
#   새로운 리뷰 11000개 수집 중...
#   새로운 리뷰 11100개 수집 중...
#   새로운 리뷰 11200개 수집 중...
#   새로운 리뷰 11300개 수집 중...
#   새로운 리뷰 11400개 수집 중...
#   새로운 리뷰 11500개 수집 중...
#   새로운 리뷰 11600개 수집 중...
#   새로운 리뷰 11700개 수집 중...
#   새로운 리뷰 11800개 수집 중...
#   새로운 리뷰 11900개 수집 중...
#   새로운 리뷰 12000개 수집 중...
#   새로운 리뷰 12100개 수집 중...
#   새로운 리뷰 12200개 수집 중...
#   새로운 리뷰 12300개 수집 중...
#   새로운 리뷰 12400개 수집 중...
#   새로운 리뷰 12500개 수집 중...
#   새로운 리뷰 12600개 수집 중...
#   새로운 리뷰 12700개 수집 중...
#   새로운 리뷰 12800개 수집 중...
#   새로운 리뷰 12900개 수집 중...
#   새로운 리뷰 13000개 수집 중...
#   새로운 리뷰 13100개 수집 중...
#   새로운 리뷰 13200개 수집 중...
#   새로운 리뷰 13300개 수집 중...
#   새로운 리뷰 13400개 수집 중...
#   새로운 리뷰 13500개 수집 중...
#   새로운 리뷰 13600개 수집 중...
#   새로운 리뷰 13700개 수집 중...
#   새로운 리뷰 13800개 수집 중...
#   새로운 리뷰 13900개 수집 중...
#   새로운 리뷰 14000개 수집 중...
#   새로운 리뷰 14100개 수집 중...
#   새로운 리뷰 14200개 수집 중...
#   -> 새로운 리뷰 14299개 수집 및 추가 완료!
#
# [3/214] 처리 중: [오정규 PICK] 오버핏 포레스트 체크 셔츠 (총 리뷰 수: 11805개)
#   -> 신규 상품 저장 완료 (누적판매: 90503 | 조회수: 24947)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   새로운 리뷰 2600개 수집 중...
#   새로운 리뷰 2700개 수집 중...
#   새로운 리뷰 2800개 수집 중...
#   새로운 리뷰 2900개 수집 중...
#   새로운 리뷰 3000개 수집 중...
#   새로운 리뷰 3100개 수집 중...
#   새로운 리뷰 3200개 수집 중...
#   새로운 리뷰 3300개 수집 중...
#   새로운 리뷰 3400개 수집 중...
#   새로운 리뷰 3500개 수집 중...
#   새로운 리뷰 3600개 수집 중...
#   새로운 리뷰 3700개 수집 중...
#   새로운 리뷰 3800개 수집 중...
#   새로운 리뷰 3900개 수집 중...
#   새로운 리뷰 4000개 수집 중...
#   새로운 리뷰 4100개 수집 중...
#   새로운 리뷰 4200개 수집 중...
#   새로운 리뷰 4300개 수집 중...
#   새로운 리뷰 4400개 수집 중...
#   새로운 리뷰 4500개 수집 중...
#   새로운 리뷰 4600개 수집 중...
#   새로운 리뷰 4700개 수집 중...
#   새로운 리뷰 4800개 수집 중...
#   새로운 리뷰 4900개 수집 중...
#   새로운 리뷰 5000개 수집 중...
#   새로운 리뷰 5100개 수집 중...
#   새로운 리뷰 5200개 수집 중...
#   새로운 리뷰 5300개 수집 중...
#   새로운 리뷰 5400개 수집 중...
#   새로운 리뷰 5500개 수집 중...
#   새로운 리뷰 5600개 수집 중...
#   새로운 리뷰 5700개 수집 중...
#   새로운 리뷰 5800개 수집 중...
#   새로운 리뷰 5900개 수집 중...
#   새로운 리뷰 6000개 수집 중...
#   새로운 리뷰 6100개 수집 중...
#   새로운 리뷰 6200개 수집 중...
#   새로운 리뷰 6300개 수집 중...
#   새로운 리뷰 6400개 수집 중...
#   새로운 리뷰 6500개 수집 중...
#   새로운 리뷰 6600개 수집 중...
#   새로운 리뷰 6700개 수집 중...
#   새로운 리뷰 6800개 수집 중...
#   새로운 리뷰 6900개 수집 중...
#   새로운 리뷰 7000개 수집 중...
#   새로운 리뷰 7100개 수집 중...
#   새로운 리뷰 7200개 수집 중...
#   새로운 리뷰 7300개 수집 중...
#   새로운 리뷰 7400개 수집 중...
#   새로운 리뷰 7500개 수집 중...
#   새로운 리뷰 7600개 수집 중...
#   새로운 리뷰 7700개 수집 중...
#   새로운 리뷰 7800개 수집 중...
#   새로운 리뷰 7900개 수집 중...
#   새로운 리뷰 8000개 수집 중...
#   새로운 리뷰 8100개 수집 중...
#   새로운 리뷰 8200개 수집 중...
#   새로운 리뷰 8300개 수집 중...
#   새로운 리뷰 8400개 수집 중...
#   새로운 리뷰 8500개 수집 중...
#   새로운 리뷰 8600개 수집 중...
#   새로운 리뷰 8700개 수집 중...
#   새로운 리뷰 8800개 수집 중...
#   새로운 리뷰 8900개 수집 중...
#   새로운 리뷰 9000개 수집 중...
#   새로운 리뷰 9100개 수집 중...
#   새로운 리뷰 9200개 수집 중...
#   새로운 리뷰 9300개 수집 중...
#   새로운 리뷰 9400개 수집 중...
#   새로운 리뷰 9500개 수집 중...
#   새로운 리뷰 9600개 수집 중...
#   새로운 리뷰 9700개 수집 중...
#   새로운 리뷰 9800개 수집 중...
#   새로운 리뷰 9900개 수집 중...
#   새로운 리뷰 10000개 수집 중...
#   새로운 리뷰 10100개 수집 중...
#   새로운 리뷰 10200개 수집 중...
#   새로운 리뷰 10300개 수집 중...
#   새로운 리뷰 10400개 수집 중...
#   새로운 리뷰 10500개 수집 중...
#   새로운 리뷰 10600개 수집 중...
#   새로운 리뷰 10700개 수집 중...
#   새로운 리뷰 10800개 수집 중...
#   새로운 리뷰 10900개 수집 중...
#   새로운 리뷰 11000개 수집 중...
#   새로운 리뷰 11100개 수집 중...
#   새로운 리뷰 11200개 수집 중...
#   새로운 리뷰 11300개 수집 중...
#   새로운 리뷰 11400개 수집 중...
#   새로운 리뷰 11500개 수집 중...
#   새로운 리뷰 11600개 수집 중...
#   새로운 리뷰 11700개 수집 중...
#   새로운 리뷰 11800개 수집 중...
#   -> 새로운 리뷰 11805개 수집 및 추가 완료!
#
# [4/214] 처리 중: [블랙]B-스테디 하프 폴라넥-블랙 (총 리뷰 수: 9555개)
#   -> 신규 상품 저장 완료 (누적판매: 47033 | 조회수: 680)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   새로운 리뷰 2600개 수집 중...
#   새로운 리뷰 2700개 수집 중...
#   새로운 리뷰 2800개 수집 중...
#   새로운 리뷰 2900개 수집 중...
#   새로운 리뷰 3000개 수집 중...
#   새로운 리뷰 3100개 수집 중...
#   새로운 리뷰 3200개 수집 중...
#   새로운 리뷰 3300개 수집 중...
#   새로운 리뷰 3400개 수집 중...
#   새로운 리뷰 3500개 수집 중...
#   새로운 리뷰 3600개 수집 중...
#   새로운 리뷰 3700개 수집 중...
#   새로운 리뷰 3800개 수집 중...
#   새로운 리뷰 3900개 수집 중...
#   새로운 리뷰 4000개 수집 중...
#   새로운 리뷰 4100개 수집 중...
#   새로운 리뷰 4200개 수집 중...
#   새로운 리뷰 4300개 수집 중...
#   새로운 리뷰 4400개 수집 중...
#   새로운 리뷰 4500개 수집 중...
#   새로운 리뷰 4600개 수집 중...
#   새로운 리뷰 4700개 수집 중...
#   새로운 리뷰 4800개 수집 중...
#   새로운 리뷰 4900개 수집 중...
#   새로운 리뷰 5000개 수집 중...
#   새로운 리뷰 5100개 수집 중...
#   새로운 리뷰 5200개 수집 중...
#   새로운 리뷰 5300개 수집 중...
#   새로운 리뷰 5400개 수집 중...
#   새로운 리뷰 5500개 수집 중...
#   새로운 리뷰 5600개 수집 중...
#   새로운 리뷰 5700개 수집 중...
#   새로운 리뷰 5800개 수집 중...
#   새로운 리뷰 5900개 수집 중...
#   새로운 리뷰 6000개 수집 중...
#   새로운 리뷰 6100개 수집 중...
#   새로운 리뷰 6200개 수집 중...
#   새로운 리뷰 6300개 수집 중...
#   새로운 리뷰 6400개 수집 중...
#   새로운 리뷰 6500개 수집 중...
#   새로운 리뷰 6600개 수집 중...
#   새로운 리뷰 6700개 수집 중...
#   새로운 리뷰 6800개 수집 중...
#   새로운 리뷰 6900개 수집 중...
#   새로운 리뷰 7000개 수집 중...
#   새로운 리뷰 7100개 수집 중...
#   새로운 리뷰 7200개 수집 중...
#   새로운 리뷰 7300개 수집 중...
#   새로운 리뷰 7400개 수집 중...
#   새로운 리뷰 7500개 수집 중...
#   새로운 리뷰 7600개 수집 중...
#   새로운 리뷰 7700개 수집 중...
#   새로운 리뷰 7800개 수집 중...
#   새로운 리뷰 7900개 수집 중...
#   새로운 리뷰 8000개 수집 중...
#   새로운 리뷰 8100개 수집 중...
#   새로운 리뷰 8200개 수집 중...
#   새로운 리뷰 8300개 수집 중...
#   새로운 리뷰 8400개 수집 중...
#   새로운 리뷰 8500개 수집 중...
#   새로운 리뷰 8600개 수집 중...
#   새로운 리뷰 8700개 수집 중...
#   새로운 리뷰 8800개 수집 중...
#   새로운 리뷰 8900개 수집 중...
#   새로운 리뷰 9000개 수집 중...
#   새로운 리뷰 9100개 수집 중...
#   새로운 리뷰 9200개 수집 중...
#   새로운 리뷰 9300개 수집 중...
#   새로운 리뷰 9400개 수집 중...
#   새로운 리뷰 9500개 수집 중...
#   -> 새로운 리뷰 9555개 수집 및 추가 완료!
#
# [5/214] 처리 중: 오버핏 아치 로고 스웨트 셔츠-3Color (총 리뷰 수: 5260개)
#   -> 신규 상품 저장 완료 (누적판매: 27362 | 조회수: 1804)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   새로운 리뷰 2600개 수집 중...
#   새로운 리뷰 2700개 수집 중...
#   새로운 리뷰 2800개 수집 중...
#   새로운 리뷰 2900개 수집 중...
#   새로운 리뷰 3000개 수집 중...
#   새로운 리뷰 3100개 수집 중...
#   새로운 리뷰 3200개 수집 중...
#   새로운 리뷰 3300개 수집 중...
#   새로운 리뷰 3400개 수집 중...
#   새로운 리뷰 3500개 수집 중...
#   새로운 리뷰 3600개 수집 중...
#   새로운 리뷰 3700개 수집 중...
#   새로운 리뷰 3800개 수집 중...
#   새로운 리뷰 3900개 수집 중...
#   새로운 리뷰 4000개 수집 중...
#   새로운 리뷰 4100개 수집 중...
#   새로운 리뷰 4200개 수집 중...
#   새로운 리뷰 4300개 수집 중...
#   새로운 리뷰 4400개 수집 중...
#   새로운 리뷰 4500개 수집 중...
#   새로운 리뷰 4600개 수집 중...
#   새로운 리뷰 4700개 수집 중...
#   새로운 리뷰 4800개 수집 중...
#   새로운 리뷰 4900개 수집 중...
#   새로운 리뷰 5000개 수집 중...
#   새로운 리뷰 5100개 수집 중...
#   새로운 리뷰 5200개 수집 중...
#   -> 새로운 리뷰 5260개 수집 및 추가 완료!
#
# [6/214] 처리 중: 오버핏 그래피티 로고 후디-6Color (총 리뷰 수: 5135개)
#   -> 신규 상품 저장 완료 (누적판매: 40447 | 조회수: 8122)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   새로운 리뷰 2600개 수집 중...
#   새로운 리뷰 2700개 수집 중...
#   새로운 리뷰 2800개 수집 중...
#   새로운 리뷰 2900개 수집 중...
#   새로운 리뷰 3000개 수집 중...
#   새로운 리뷰 3100개 수집 중...
#   새로운 리뷰 3200개 수집 중...
#   새로운 리뷰 3300개 수집 중...
#   새로운 리뷰 3400개 수집 중...
#   새로운 리뷰 3500개 수집 중...
#   새로운 리뷰 3600개 수집 중...
#   새로운 리뷰 3700개 수집 중...
#   새로운 리뷰 3800개 수집 중...
#   새로운 리뷰 3900개 수집 중...
#   새로운 리뷰 4000개 수집 중...
#   새로운 리뷰 4100개 수집 중...
#   새로운 리뷰 4200개 수집 중...
#   새로운 리뷰 4300개 수집 중...
#   새로운 리뷰 4400개 수집 중...
#   새로운 리뷰 4500개 수집 중...
#   새로운 리뷰 4600개 수집 중...
#   새로운 리뷰 4700개 수집 중...
#   새로운 리뷰 4800개 수집 중...
#   새로운 리뷰 4900개 수집 중...
#   새로운 리뷰 5000개 수집 중...
#   새로운 리뷰 5100개 수집 중...
#   -> 새로운 리뷰 5135개 수집 및 추가 완료!
#
# [7/214] 처리 중: 오버핏 포레스트 체크 셔츠-핑크 (총 리뷰 수: 4949개)
#   -> 신규 상품 저장 완료 (누적판매: 25734 | 조회수: 8038)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   새로운 리뷰 2600개 수집 중...
#   새로운 리뷰 2700개 수집 중...
#   새로운 리뷰 2800개 수집 중...
#   새로운 리뷰 2900개 수집 중...
#   새로운 리뷰 3000개 수집 중...
#   새로운 리뷰 3100개 수집 중...
#   새로운 리뷰 3200개 수집 중...
#   새로운 리뷰 3300개 수집 중...
#   새로운 리뷰 3400개 수집 중...
#   새로운 리뷰 3500개 수집 중...
#   새로운 리뷰 3600개 수집 중...
#   새로운 리뷰 3700개 수집 중...
#   새로운 리뷰 3800개 수집 중...
#   새로운 리뷰 3900개 수집 중...
#   새로운 리뷰 4000개 수집 중...
#   새로운 리뷰 4100개 수집 중...
#   새로운 리뷰 4200개 수집 중...
#   새로운 리뷰 4300개 수집 중...
#   새로운 리뷰 4400개 수집 중...
#   새로운 리뷰 4500개 수집 중...
#   새로운 리뷰 4600개 수집 중...
#   새로운 리뷰 4700개 수집 중...
#   새로운 리뷰 4800개 수집 중...
#   새로운 리뷰 4900개 수집 중...
#   -> 새로운 리뷰 4949개 수집 및 추가 완료!
#
# [8/214] 처리 중: [블랙]B-스테디 하프 폴라넥-아이보리 (총 리뷰 수: 3685개)
#   -> 신규 상품 저장 완료 (누적판매: 16692 | 조회수: 463)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   새로운 리뷰 2600개 수집 중...
#   새로운 리뷰 2700개 수집 중...
#   새로운 리뷰 2800개 수집 중...
#   새로운 리뷰 2900개 수집 중...
#   새로운 리뷰 3000개 수집 중...
#   새로운 리뷰 3100개 수집 중...
#   새로운 리뷰 3200개 수집 중...
#   새로운 리뷰 3300개 수집 중...
#   새로운 리뷰 3400개 수집 중...
#   새로운 리뷰 3500개 수집 중...
#   새로운 리뷰 3600개 수집 중...
#   -> 새로운 리뷰 3685개 수집 및 추가 완료!
#
# [9/214] 처리 중: 오버핏 그래피티 로고 후디-오트밀 (총 리뷰 수: 3230개)
#   -> 신규 상품 저장 완료 (누적판매: 25748 | 조회수: 3657)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   새로운 리뷰 2600개 수집 중...
#   새로운 리뷰 2700개 수집 중...
#   새로운 리뷰 2800개 수집 중...
#   새로운 리뷰 2900개 수집 중...
#   새로운 리뷰 3000개 수집 중...
#   새로운 리뷰 3100개 수집 중...
#   새로운 리뷰 3200개 수집 중...
#   -> 새로운 리뷰 3230개 수집 및 추가 완료!
#
# [10/214] 처리 중: 오버핏 그래피티 로고 후디-블랙 (총 리뷰 수: 3009개)
#   -> 신규 상품 저장 완료 (누적판매: 22470 | 조회수: 3634)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   새로운 리뷰 2600개 수집 중...
#   새로운 리뷰 2700개 수집 중...
#   새로운 리뷰 2800개 수집 중...
#   새로운 리뷰 2900개 수집 중...
#   새로운 리뷰 3000개 수집 중...
#   -> 새로운 리뷰 3009개 수집 및 추가 완료!
#
# [11/214] 처리 중: 옵티멀 베이직 셔츠-네이비[린넨&옥스포드 선택 (총 리뷰 수: 2495개)
#   -> 신규 상품 저장 완료 (누적판매: 14619 | 조회수: 10423)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   -> 새로운 리뷰 2495개 수집 및 추가 완료!
#
# [12/214] 처리 중: 오버핏 1988 스웨트 셔츠-3Color (총 리뷰 수: 2488개)
#   -> 신규 상품 저장 완료 (누적판매: 15415 | 조회수: 1255)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   -> 새로운 리뷰 2488개 수집 및 추가 완료!
#
# [13/214] 처리 중: 오버핏 그래피티 로고 후디-네이비 (총 리뷰 수: 1873개)
#   -> 신규 상품 저장 완료 (누적판매: 13223 | 조회수: 616)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   -> 새로운 리뷰 1873개 수집 및 추가 완료!
#
# [14/214] 처리 중: 오버핏 포레스트 체크 셔츠-그린 (총 리뷰 수: 1577개)
#   -> 신규 상품 저장 완료 (누적판매: 9157 | 조회수: 3898)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   -> 새로운 리뷰 1577개 수집 및 추가 완료!
#
# [15/214] 처리 중: 오버핏 마드라스 체크 셔츠-핑크 (총 리뷰 수: 1357개)
#   -> 신규 상품 저장 완료 (누적판매: 6779 | 조회수: 1853)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   -> 새로운 리뷰 1357개 수집 및 추가 완료!
#
# [16/214] 처리 중: FLM 클럽 스포츠 저지 티셔츠-3Color (총 리뷰 수: 670개)
#   -> 신규 상품 저장 완료 (누적판매: 6820 | 조회수: 2318)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   -> 새로운 리뷰 670개 수집 및 추가 완료!
#
# [17/214] 처리 중: 오버핏 마드라스 체크 셔츠-블랙 (총 리뷰 수: 658개)
#   -> 신규 상품 저장 완료 (누적판매: 3261 | 조회수: 852)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   -> 새로운 리뷰 658개 수집 및 추가 완료!
#
# [18/214] 처리 중: [스토커즈 pick] 올 데이 린넨 라이크 하 (총 리뷰 수: 590개)
#   -> 신규 상품 저장 완료 (누적판매: 7904 | 조회수: 5606)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   -> 새로운 리뷰 590개 수집 및 추가 완료!
#
# [19/214] 처리 중: [SET]썸머 컬렉션 티셔츠 (총 리뷰 수: 501개)
#   -> 신규 상품 저장 완료 (누적판매: 5310 | 조회수: 4235)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   -> 새로운 리뷰 501개 수집 및 추가 완료!
#
# [20/214] 처리 중: 88 피그먼트 후디-오프화이트 (총 리뷰 수: 431개)
#   -> 신규 상품 저장 완료 (누적판매: 2498 | 조회수: 372)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   -> 새로운 리뷰 431개 수집 및 추가 완료!
#
# [21/214] 처리 중: [너드킹 pick] 올 데이 옥스포드 셔츠-7 (총 리뷰 수: 336개)
#   -> 신규 상품 저장 완료 (누적판매: 5875 | 조회수: 21227)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   -> 새로운 리뷰 336개 수집 및 추가 완료!
#
# [22/214] 처리 중: 올 데이 옥스포드 하프 셔츠-5Color (총 리뷰 수: 298개)
#   -> 신규 상품 저장 완료 (누적판매: 3948 | 조회수: 1201)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   -> 새로운 리뷰 298개 수집 및 추가 완료!
#
# [23/214] 처리 중: 오버핏 마드라스 체크 셔츠-카키 (총 리뷰 수: 293개)
#   -> 신규 상품 저장 완료 (누적판매: 1429 | 조회수: 727)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   -> 새로운 리뷰 293개 수집 및 추가 완료!
#
# [24/214] 처리 중: [스토커즈 pick] 올 데이 린넨 라이크 셔 (총 리뷰 수: 248개)
#   -> 신규 상품 저장 완료 (누적판매: 2985 | 조회수: 7161)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   -> 새로운 리뷰 248개 수집 및 추가 완료!
#
# [25/214] 처리 중: [해피가이정호 pick] 멀티 스트라이프 롱  (총 리뷰 수: 247개)
#   -> 신규 상품 저장 완료 (누적판매: 2581 | 조회수: 20131)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   -> 새로운 리뷰 247개 수집 및 추가 완료!
#
# [26/214] 처리 중: 시어서커 스트라이프 셔츠-네이비 (총 리뷰 수: 158개)
#   -> 신규 상품 저장 완료 (누적판매: 1337 | 조회수: 4283)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 158개 수집 및 추가 완료!
#
# [27/214] 처리 중: 모던 그래픽 래글런 티셔츠-2Color (총 리뷰 수: 152개)
#   -> 신규 상품 저장 완료 (누적판매: 1065 | 조회수: 327)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 152개 수집 및 추가 완료!
#
# [28/214] 처리 중: 88 스프레이 저지 티셔츠-블랙 (총 리뷰 수: 142개)
#   -> 신규 상품 저장 완료 (누적판매: 1477 | 조회수: 728)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 142개 수집 및 추가 완료!
#
# [29/214] 처리 중: FLM 스티치 로고 후디-스카이블루 (총 리뷰 수: 125개)
#   -> 신규 상품 저장 완료 (누적판매: 871 | 조회수: 610)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 125개 수집 및 추가 완료!
#
# [30/214] 처리 중: 버닝 하트 티셔츠-화이트 (총 리뷰 수: 113개)
#   -> 신규 상품 저장 완료 (누적판매: 2073 | 조회수: 633)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 113개 수집 및 추가 완료!
#
# [31/214] 처리 중: [2PACK]스몰 어센틱 로고 티셔츠 (총 리뷰 수: 105개)
#   -> 신규 상품 저장 완료 (누적판매: 1673 | 조회수: 1330)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 105개 수집 및 추가 완료!
#
# [32/214] 처리 중: [너드킹 pick] 멀티 스트라이프 롱 슬리브 (총 리뷰 수: 102개)
#   -> 신규 상품 저장 완료 (누적판매: 1031 | 조회수: 9808)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 102개 수집 및 추가 완료!
#
# [33/214] 처리 중: 88 스프레이 저지 티셔츠-화이트 (총 리뷰 수: 75개)
#   -> 신규 상품 저장 완료 (누적판매: 658 | 조회수: 1016)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 75개 수집 및 추가 완료!
#
# [34/214] 처리 중: 스몰 어센틱 로고 티셔츠-블랙 (총 리뷰 수: 68개)
#   -> 신규 상품 저장 완료 (누적판매: 856 | 조회수: 694)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 68개 수집 및 추가 완료!
#
# [35/214] 처리 중: 버닝 하트 티셔츠-블랙 (총 리뷰 수: 58개)
#   -> 신규 상품 저장 완료 (누적판매: 819 | 조회수: 1383)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 58개 수집 및 추가 완료!
#
# [36/214] 처리 중: 시그니처 어센틱 로고 후디-4Color (총 리뷰 수: 54개)
#   -> 신규 상품 저장 완료 (누적판매: 807 | 조회수: 1971)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 54개 수집 및 추가 완료!
#
# [37/214] 처리 중: 버닝 하트 티셔츠-브라운 (총 리뷰 수: 54개)
#   -> 신규 상품 저장 완료 (누적판매: 680 | 조회수: 703)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 54개 수집 및 추가 완료!
#
# [38/214] 처리 중: FLM 스티치 로고 후디-차콜 (총 리뷰 수: 40개)
#   -> 신규 상품 저장 완료 (누적판매: 292 | 조회수: 460)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 40개 수집 및 추가 완료!
#
# [39/214] 처리 중: [스토커즈 pick] 세미 크롭 톤온톤 스트라 (총 리뷰 수: 29개)
#   -> 신규 상품 저장 완료 (누적판매: 529 | 조회수: 10429)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 29개 수집 및 추가 완료!
#
# [40/214] 처리 중: [스토커즈 pick] 멀티 스트라이프 롱 슬리 (총 리뷰 수: 28개)
#   -> 신규 상품 저장 완료 (누적판매: 191 | 조회수: 3433)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 28개 수집 및 추가 완료!
#
# [41/214] 처리 중: 스몰 어센틱 로고 티셔츠-화이트 (총 리뷰 수: 26개)
#   -> 신규 상품 저장 완료 (누적판매: 353 | 조회수: 450)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 26개 수집 및 추가 완료!
#
# [42/214] 처리 중: 시그니처 어센틱 로고 티셔츠-화이트 (총 리뷰 수: 24개)
#   -> 신규 상품 저장 완료 (누적판매: 290 | 조회수: 474)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 24개 수집 및 추가 완료!
#
# [43/214] 처리 중: 코듀로이 포켓 셔츠-베이지 (총 리뷰 수: 21개)
#   -> 신규 상품 저장 완료 (누적판매: 165 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 21개 수집 및 추가 완료!
#
# [44/214] 처리 중: FLM 스티치 로고 후디-블랙 (총 리뷰 수: 20개)
#   -> 신규 상품 저장 완료 (누적판매: 130 | 조회수: 395)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 20개 수집 및 추가 완료!
#
# [45/214] 처리 중: 시그니처 어센틱 로고 후디-블랙 (총 리뷰 수: 19개)
#   -> 신규 상품 저장 완료 (누적판매: 176 | 조회수: 484)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 19개 수집 및 추가 완료!
#
# [46/214] 처리 중: 심볼 패널드 후디-블랙 (총 리뷰 수: 18개)
#   -> 신규 상품 저장 완료 (누적판매: 193 | 조회수: 533)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 18개 수집 및 추가 완료!
#
# [47/214] 처리 중: DFAO 아플리케 후디-다크그린 (총 리뷰 수: 18개)
#   -> 신규 상품 저장 완료 (누적판매: 162 | 조회수: 393)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 18개 수집 및 추가 완료!
#
# [48/214] 처리 중: FLM 스티치 로고 스웨트 셔츠-블랙 (총 리뷰 수: 16개)
#   -> 신규 상품 저장 완료 (누적판매: 123 | 조회수: 280)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 16개 수집 및 추가 완료!
#
# [49/214] 처리 중: 러스틱 빈티지 체크 셔츠-네이비 (총 리뷰 수: 14개)
#   -> 신규 상품 저장 완료 (누적판매: 113 | 조회수: 274)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 14개 수집 및 추가 완료!
#
# [50/214] 처리 중: 심볼 스트라이프 롱 슬리브-핑크 (총 리뷰 수: 14개)
#   -> 신규 상품 저장 완료 (누적판매: 147 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 14개 수집 및 추가 완료!
#
# [51/214] 처리 중: 시그니처 어센틱 로고 스웨트셔츠-오트밀 (총 리뷰 수: 14개)
#   -> 신규 상품 저장 완료 (누적판매: 92 | 조회수: 356)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 14개 수집 및 추가 완료!
#
# [52/214] 처리 중: 갤럭시 심볼 로고 티셔츠-화이트 (총 리뷰 수: 14개)
#   -> 신규 상품 저장 완료 (누적판매: 129 | 조회수: 475)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 14개 수집 및 추가 완료!
#
# [53/214] 처리 중: DFAO 아플리케 후디-블랙 (총 리뷰 수: 13개)
#   -> 신규 상품 저장 완료 (누적판매: 110 | 조회수: 354)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 13개 수집 및 추가 완료!
#
# [54/214] 처리 중: DFAO 아플리케 후디-브라운 (총 리뷰 수: 13개)
#   -> 신규 상품 저장 완료 (누적판매: 198 | 조회수: 365)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 13개 수집 및 추가 완료!
#
# [55/214] 처리 중: FLM 스티치 로고 후디-네이비 (총 리뷰 수: 13개)
#   -> 신규 상품 저장 완료 (누적판매: 101 | 조회수: 348)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 13개 수집 및 추가 완료!
#
# [56/214] 처리 중: 갤럭시 심볼 로고 티셔츠-블랙 (총 리뷰 수: 13개)
#   -> 신규 상품 저장 완료 (누적판매: 57 | 조회수: 420)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 13개 수집 및 추가 완료!
#
# [57/214] 처리 중: FLM 스티치 로고 후디-브라운 (총 리뷰 수: 13개)
#   -> 신규 상품 저장 완료 (누적판매: 129 | 조회수: 261)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 13개 수집 및 추가 완료!
#
# [58/214] 처리 중: 88 자가드 라운드 니트-블랙 (총 리뷰 수: 12개)
#   -> 신규 상품 저장 완료 (누적판매: 113 | 조회수: 278)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 12개 수집 및 추가 완료!
#
# [59/214] 처리 중: 시그니처 어센틱 로고 후디-차콜 (총 리뷰 수: 12개)
#   -> 신규 상품 저장 완료 (누적판매: 124 | 조회수: 470)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 12개 수집 및 추가 완료!
#
# [60/214] 처리 중: 시그니처 어센틱 로고 후디-브라운 (총 리뷰 수: 12개)
#   -> 신규 상품 저장 완료 (누적판매: 138 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 12개 수집 및 추가 완료!
#
# [61/214] 처리 중: 시어서커 스트라이프 셔츠-스카이블루 (총 리뷰 수: 12개)
#   -> 신규 상품 저장 완료 (누적판매: 152 | 조회수: 1094)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 12개 수집 및 추가 완료!
#
# [62/214] 처리 중: [스토커즈 pick] 세미 크롭 체크 하프 셔 (총 리뷰 수: 11개)
#   -> 신규 상품 저장 완료 (누적판매: 159 | 조회수: 4978)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 11개 수집 및 추가 완료!
#
# [63/214] 처리 중: 워시드 패널 롱 슬리브-오프화이트 (총 리뷰 수: 11개)
#   -> 신규 상품 저장 완료 (누적판매: 96 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 11개 수집 및 추가 완료!
#
# [64/214] 처리 중: 88 피그먼트 티셔츠-오프화이트 (총 리뷰 수: 11개)
#   -> 신규 상품 저장 완료 (누적판매: 79 | 조회수: 366)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 11개 수집 및 추가 완료!
#
# [65/214] 처리 중: 시그니처 어센틱 로고 티셔츠-라이트그레이 (총 리뷰 수: 11개)
#   -> 신규 상품 저장 완료 (누적판매: 71 | 조회수: 354)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 11개 수집 및 추가 완료!
#
# [66/214] 처리 중: 롤 업 체크 하프 셔츠-핑크 (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 2264)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [67/214] 처리 중: 쿨 코튼 서울 어센틱 티셔츠-2Color (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 125 | 조회수: 1535)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [68/214] 처리 중: 워시드 하찌 라운드 니트-차콜 (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 124 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [69/214] 처리 중: 올드 스쿨 플란넬 체크 셔츠-그린 (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 92 | 조회수: 562)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [70/214] 처리 중: 스트라이프 럭비 롱 슬리브-네이비 (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 138 | 조회수: 1030)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [71/214] 처리 중: (W) 워시드 패널 롱 슬리브-오프화이트 (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 122 | 조회수: 532)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [72/214] 처리 중: FLM 빈티지 하트 그래픽 티셔츠-화이트 (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 106 | 조회수: 299)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [73/214] 처리 중: 올드 스쿨 플란넬 체크 셔츠-레드 (총 리뷰 수: 9개)
#   -> 신규 상품 저장 완료 (누적판매: 116 | 조회수: 508)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 9개 수집 및 추가 완료!
#
# [74/214] 처리 중: 심볼 스트라이프 롱 슬리브-블랙 (총 리뷰 수: 9개)
#   -> 신규 상품 저장 완료 (누적판매: 117 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 9개 수집 및 추가 완료!
#
# [75/214] 처리 중: 심볼 스트라이프 롱 슬리브-블루 (총 리뷰 수: 9개)
#   -> 신규 상품 저장 완료 (누적판매: 107 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 9개 수집 및 추가 완료!
#
# [76/214] 처리 중: 시그니처 어센틱 로고 티셔츠-네이비 (총 리뷰 수: 9개)
#   -> 신규 상품 저장 완료 (누적판매: 97 | 조회수: 355)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 9개 수집 및 추가 완료!
#
# [77/214] 처리 중: 스몰 어센틱 로고 티셔츠-라이트그레이 (총 리뷰 수: 9개)
#   -> 신규 상품 저장 완료 (누적판매: 129 | 조회수: 381)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 9개 수집 및 추가 완료!
#
# [78/214] 처리 중: 올드 스쿨 플란넬 체크 셔츠-블랙 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 85 | 조회수: 537)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [79/214] 처리 중: 코듀로이 포켓 셔츠-브라운 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 127 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [80/214] 처리 중: 페이드 체크 셔츠-블랙 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 76 | 조회수: 412)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [81/214] 처리 중: 페이드 체크 셔츠-브라운 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 77 | 조회수: 399)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [82/214] 처리 중: DFAO 아플리케 후디-네이비 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 132 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [83/214] 처리 중: FLM 부클 로고 스웨트셔츠-네이비 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 135 | 조회수: 330)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [84/214] 처리 중: (W) 워시드 패널 롱 슬리브-차콜 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 50 | 조회수: 383)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [85/214] 처리 중: 시그니처 어센틱 로고 스웨트셔츠-멜란지그레이 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 86 | 조회수: 337)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [86/214] 처리 중: [스토커즈 pick] 세미 크롭 체크 하프 셔 (총 리뷰 수: 7개)
#   -> 신규 상품 저장 완료 (누적판매: 53 | 조회수: 2065)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 7개 수집 및 추가 완료!
#
# [87/214] 처리 중: (W) 리브드 버튼 롱슬리브-카키 (총 리뷰 수: 7개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 1199)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 7개 수집 및 추가 완료!
#
# [88/214] 처리 중: 브리즈 체크 셔츠-스카이블루 (총 리뷰 수: 7개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 138)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 7개 수집 및 추가 완료!
#
# [89/214] 처리 중: 브러쉬드 체크 오버 셔츠-핑크 (총 리뷰 수: 7개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 948)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 7개 수집 및 추가 완료!
#
# [90/214] 처리 중: 모노 스트라이프 스웨트셔츠-블랙 (총 리뷰 수: 7개)
#   -> 신규 상품 저장 완료 (누적판매: 150 | 조회수: 255)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 7개 수집 및 추가 완료!
#
# [91/214] 처리 중: 시그니처 어센틱 로고 티셔츠-핑크 (총 리뷰 수: 7개)
#   -> 신규 상품 저장 완료 (누적판매: 112 | 조회수: 443)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 7개 수집 및 추가 완료!
#
# [92/214] 처리 중: FLM 빈티지 하트 그래픽 티셔츠-블랙 (총 리뷰 수: 7개)
#   -> 신규 상품 저장 완료 (누적판매: 79 | 조회수: 301)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 7개 수집 및 추가 완료!
#
# [93/214] 처리 중: 키체인 그래픽 티셔츠-블랙 (총 리뷰 수: 6개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 1742)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 6개 수집 및 추가 완료!
#
# [94/214] 처리 중: 키체인 그래픽 티셔츠-멜란지그레이 (총 리뷰 수: 6개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 1051)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 6개 수집 및 추가 완료!
#
# [95/214] 처리 중: 세미 크롭 체크 하프 셔츠-스카이블루 (총 리뷰 수: 6개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 1611)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 6개 수집 및 추가 완료!
#
# [96/214] 처리 중: 오벌 1988 리그 후디-브라운 (총 리뷰 수: 6개)
#   -> 신규 상품 저장 완료 (누적판매: 84 | 조회수: 339)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 6개 수집 및 추가 완료!
#
# [97/214] 처리 중: FLM 부클 로고 스웨트셔츠-블랙 (총 리뷰 수: 6개)
#   -> 신규 상품 저장 완료 (누적판매: 73 | 조회수: 226)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 6개 수집 및 추가 완료!
#
# [98/214] 처리 중: 워시드 패널 롱 슬리브-차콜 (총 리뷰 수: 6개)
#   -> 신규 상품 저장 완료 (누적판매: 112 | 조회수: 706)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 6개 수집 및 추가 완료!
#
# [99/214] 처리 중: 시그니처 어센틱 로고 스웨트셔츠-블랙 (총 리뷰 수: 6개)
#   -> 신규 상품 저장 완료 (누적판매: 71 | 조회수: 410)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 6개 수집 및 추가 완료!
#
# [100/214] 처리 중: [스토커즈 pick] 파스텔 체크 링클 셔츠- (총 리뷰 수: 5개)
#   -> 신규 상품 저장 완료 (누적판매: 111 | 조회수: 2852)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 5개 수집 및 추가 완료!
#
# [101/214] 처리 중: 롤 업 체크 하프 셔츠-라이트그린 (총 리뷰 수: 5개)
#   -> 신규 상품 저장 완료 (누적판매: 93 | 조회수: 5997)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 5개 수집 및 추가 완료!
#
# [102/214] 처리 중: 키체인 그래픽 티셔츠-화이트 (총 리뷰 수: 5개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 1043)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 5개 수집 및 추가 완료!
#
# [103/214] 처리 중: FLM 부클 로고 스웨트셔츠-멜란지그레이 (총 리뷰 수: 5개)
#   -> 신규 상품 저장 완료 (누적판매: 65 | 조회수: 197)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 5개 수집 및 추가 완료!
#
# [104/214] 처리 중: 스몰 어센틱 스트라이프 후디-브라운 (총 리뷰 수: 5개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 253)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 5개 수집 및 추가 완료!
#
# [105/214] 처리 중: 시그니처 어센틱 로고 티셔츠-블랙 (총 리뷰 수: 5개)
#   -> 신규 상품 저장 완료 (누적판매: 123 | 조회수: 374)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 5개 수집 및 추가 완료!
#
# [106/214] 처리 중: 롤 업 체크 하프 셔츠-블랙 (총 리뷰 수: 4개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 3506)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 4개 수집 및 추가 완료!
#
# [107/214] 처리 중: (W) 리브드 버튼 롱슬리브-차콜 (총 리뷰 수: 4개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 441)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 4개 수집 및 추가 완료!
#
# [108/214] 처리 중: 아이덴티티 심볼 후디-멜란지그레이 (총 리뷰 수: 4개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 1154)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 4개 수집 및 추가 완료!
#
# [109/214] 처리 중: 브러쉬드 체크 오버 셔츠-스카이블루 (총 리뷰 수: 4개)
# ...
#   새로운 리뷰 7000개 수집 중...
#   새로운 리뷰 7100개 수집 중...
#   새로운 리뷰 7200개 수집 중...
#   새로운 리뷰 7300개 수집 중...
#   새로운 리뷰 7400개 수집 중...
#   새로운 리뷰 7500개 수집 중...
#   새로운 리뷰 7600개 수집 중...
#   새로운 리뷰 7700개 수집 중...
#   새로운 리뷰 7800개 수집 중...
#   새로운 리뷰 7900개 수집 중...
#   새로운 리뷰 8000개 수집 중...
#   새로운 리뷰 8100개 수집 중...
#   새로운 리뷰 8200개 수집 중...
#   새로운 리뷰 8300개 수집 중...
#   새로운 리뷰 8400개 수집 중...
#   새로운 리뷰 8500개 수집 중...
#   새로운 리뷰 8600개 수집 중...
#   새로운 리뷰 8700개 수집 중...
#   새로운 리뷰 8800개 수집 중...
#   새로운 리뷰 8900개 수집 중...
#   새로운 리뷰 9000개 수집 중...
#   새로운 리뷰 9100개 수집 중...
#   새로운 리뷰 9200개 수집 중...
#   새로운 리뷰 9300개 수집 중...
#   새로운 리뷰 9400개 수집 중...
#   새로운 리뷰 9500개 수집 중...
#   새로운 리뷰 9600개 수집 중...
#   새로운 리뷰 9700개 수집 중...
#   새로운 리뷰 9800개 수집 중...
#   새로운 리뷰 9900개 수집 중...
#   새로운 리뷰 10000개 수집 중...
#   새로운 리뷰 10100개 수집 중...
#   새로운 리뷰 10200개 수집 중...
#   새로운 리뷰 10300개 수집 중...
#   새로운 리뷰 10400개 수집 중...
#   새로운 리뷰 10500개 수집 중...
#   새로운 리뷰 10600개 수집 중...
#   새로운 리뷰 10700개 수집 중...
#   새로운 리뷰 10800개 수집 중...
#   새로운 리뷰 10900개 수집 중...
#   새로운 리뷰 11000개 수집 중...
#   새로운 리뷰 11100개 수집 중...
#   새로운 리뷰 11200개 수집 중...
#   새로운 리뷰 11300개 수집 중...
#   새로운 리뷰 11400개 수집 중...
#   새로운 리뷰 11500개 수집 중...
#   새로운 리뷰 11600개 수집 중...
#   새로운 리뷰 11700개 수집 중...
#   새로운 리뷰 11800개 수집 중...
#   새로운 리뷰 11900개 수집 중...
#   새로운 리뷰 12000개 수집 중...
#   새로운 리뷰 12100개 수집 중...
#   새로운 리뷰 12200개 수집 중...
#   새로운 리뷰 12300개 수집 중...
#   새로운 리뷰 12400개 수집 중...
#   새로운 리뷰 12500개 수집 중...
#   새로운 리뷰 12600개 수집 중...
#   새로운 리뷰 12700개 수집 중...
#   새로운 리뷰 12800개 수집 중...
#   새로운 리뷰 12900개 수집 중...
#   새로운 리뷰 13000개 수집 중...
#   새로운 리뷰 13100개 수집 중...
#   새로운 리뷰 13200개 수집 중...
#   새로운 리뷰 13300개 수집 중...
#   새로운 리뷰 13400개 수집 중...
#   새로운 리뷰 13500개 수집 중...
#   새로운 리뷰 13600개 수집 중...
#   새로운 리뷰 13700개 수집 중...
#   새로운 리뷰 13800개 수집 중...
#   새로운 리뷰 13900개 수집 중...
#   새로운 리뷰 14000개 수집 중...
#   새로운 리뷰 14100개 수집 중...
#   새로운 리뷰 14200개 수집 중...
#   새로운 리뷰 14300개 수집 중...
#   새로운 리뷰 14400개 수집 중...
#   새로운 리뷰 14500개 수집 중...
#   새로운 리뷰 14600개 수집 중...
#   새로운 리뷰 14700개 수집 중...
#   새로운 리뷰 14800개 수집 중...
#   새로운 리뷰 14900개 수집 중...
#   새로운 리뷰 15000개 수집 중...
#   새로운 리뷰 15100개 수집 중...
#   새로운 리뷰 15200개 수집 중...
#   새로운 리뷰 15300개 수집 중...
#   새로운 리뷰 15400개 수집 중...
#   새로운 리뷰 15500개 수집 중...
#   새로운 리뷰 15600개 수집 중...
#   새로운 리뷰 15700개 수집 중...
#   새로운 리뷰 15800개 수집 중...
#   새로운 리뷰 15900개 수집 중...
#   새로운 리뷰 16000개 수집 중...
#   새로운 리뷰 16100개 수집 중...
#   새로운 리뷰 16200개 수집 중...
#   -> 새로운 리뷰 16218개 수집 및 추가 완료!
#
# [2/85] 처리 중: 나일론 투 턱 테이핑 팬츠-블랙 (총 리뷰 수: 4455개)
#   -> 신규 상품 저장 완료 (누적판매: 33712 | 조회수: 9382)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   새로운 리뷰 2600개 수집 중...
#   새로운 리뷰 2700개 수집 중...
#   새로운 리뷰 2800개 수집 중...
#   새로운 리뷰 2900개 수집 중...
#   새로운 리뷰 3000개 수집 중...
#   새로운 리뷰 3100개 수집 중...
#   새로운 리뷰 3200개 수집 중...
#   새로운 리뷰 3300개 수집 중...
#   새로운 리뷰 3400개 수집 중...
#   새로운 리뷰 3500개 수집 중...
#   새로운 리뷰 3600개 수집 중...
#   새로운 리뷰 3700개 수집 중...
#   새로운 리뷰 3800개 수집 중...
#   새로운 리뷰 3900개 수집 중...
#   새로운 리뷰 4000개 수집 중...
#   새로운 리뷰 4100개 수집 중...
#   새로운 리뷰 4200개 수집 중...
#   새로운 리뷰 4300개 수집 중...
#   새로운 리뷰 4400개 수집 중...
#   -> 새로운 리뷰 4455개 수집 및 추가 완료!
#
# [3/85] 처리 중: [해피가이정호 pick] 데미지 워시드 데님  (총 리뷰 수: 2778개)
#   -> 신규 상품 저장 완료 (누적판매: 25153 | 조회수: 9125)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   새로운 리뷰 1700개 수집 중...
#   새로운 리뷰 1800개 수집 중...
#   새로운 리뷰 1900개 수집 중...
#   새로운 리뷰 2000개 수집 중...
#   새로운 리뷰 2100개 수집 중...
#   새로운 리뷰 2200개 수집 중...
#   새로운 리뷰 2300개 수집 중...
#   새로운 리뷰 2400개 수집 중...
#   새로운 리뷰 2500개 수집 중...
#   새로운 리뷰 2600개 수집 중...
#   새로운 리뷰 2700개 수집 중...
#   -> 새로운 리뷰 2778개 수집 및 추가 완료!
#
# [4/85] 처리 중: 데미지 워시드 데님 팬츠-스카이블루 (총 리뷰 수: 1644개)
#   -> 신규 상품 저장 완료 (누적판매: 13112 | 조회수: 6122)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   새로운 리뷰 1500개 수집 중...
#   새로운 리뷰 1600개 수집 중...
#   -> 새로운 리뷰 1644개 수집 및 추가 완료!
#
# [5/85] 처리 중: [스토커즈 pick] 올 데이 린넨 라이크 밴 (총 리뷰 수: 1403개)
#   -> 신규 상품 저장 완료 (누적판매: 15597 | 조회수: 12734)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   새로운 리뷰 1300개 수집 중...
#   새로운 리뷰 1400개 수집 중...
#   -> 새로운 리뷰 1403개 수집 및 추가 완료!
#
# [6/85] 처리 중: 데미지 워시드 데님 팬츠-블루 (총 리뷰 수: 1297개)
#   -> 신규 상품 저장 완료 (누적판매: 10574 | 조회수: 7503)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   새로운 리뷰 800개 수집 중...
#   새로운 리뷰 900개 수집 중...
#   새로운 리뷰 1000개 수집 중...
#   새로운 리뷰 1100개 수집 중...
#   새로운 리뷰 1200개 수집 중...
#   -> 새로운 리뷰 1297개 수집 및 추가 완료!
#
# [7/85] 처리 중: 오버랩 스웨트 팬츠-멜란지그레이 (총 리뷰 수: 749개)
#   -> 신규 상품 저장 완료 (누적판매: 6274 | 조회수: 760)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   새로운 리뷰 600개 수집 중...
#   새로운 리뷰 700개 수집 중...
#   -> 새로운 리뷰 749개 수집 및 추가 완료!
#
# [8/85] 처리 중: [패션플래닛×필루미네이트] 에센셜 와이드 스웨 (총 리뷰 수: 536개)
#   -> 신규 상품 저장 완료 (누적판매: 6792 | 조회수: 16183)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   -> 새로운 리뷰 536개 수집 및 추가 완료!
#
# [9/85] 처리 중: 오버랩 스웨트 팬츠-블랙 (총 리뷰 수: 534개)
#   -> 신규 상품 저장 완료 (누적판매: 4566 | 조회수: 619)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   새로운 리뷰 500개 수집 중...
#   -> 새로운 리뷰 534개 수집 및 추가 완료!
#
# [10/85] 처리 중: 밀리터리 카고 팬츠-블랙 (총 리뷰 수: 402개)
#   -> 신규 상품 저장 완료 (누적판매: 3447 | 조회수: 5307)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   새로운 리뷰 400개 수집 중...
#   -> 새로운 리뷰 402개 수집 및 추가 완료!
#
# [11/85] 처리 중: [2PACK]올 데이 린넨 라이크 밴딩 팬츠 (총 리뷰 수: 337개)
#   -> 신규 상품 저장 완료 (누적판매: 4533 | 조회수: 2511)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   새로운 리뷰 200개 수집 중...
#   새로운 리뷰 300개 수집 중...
#   -> 새로운 리뷰 337개 수집 및 추가 완료!
#
# [12/85] 처리 중: [해피가이정호 pick] 데미지 워시드 데님  (총 리뷰 수: 152개)
#   -> 신규 상품 저장 완료 (누적판매: 2058 | 조회수: 17745)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 152개 수집 및 추가 완료!
#
# [13/85] 처리 중: 데미지 워시드 데님 팬츠-아이스블루 (총 리뷰 수: 138개)
#   -> 신규 상품 저장 완료 (누적판매: 1690 | 조회수: 4939)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 138개 수집 및 추가 완료!
#
# [14/85] 처리 중: 올 데이 코튼 밴딩 팬츠-3Color (총 리뷰 수: 133개)
#   -> 신규 상품 저장 완료 (누적판매: 1666 | 조회수: 6304)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 133개 수집 및 추가 완료!
#
# [15/85] 처리 중: 데미지 워시드 데님 팬츠-그레이 (총 리뷰 수: 129개)
#   -> 신규 상품 저장 완료 (누적판매: 1603 | 조회수: 4938)
#   새로운 리뷰 수집 확인 중...
#   새로운 리뷰 100개 수집 중...
#   -> 새로운 리뷰 129개 수집 및 추가 완료!
#
# [16/85] 처리 중: [해피가이정호 pick] 데미지 워시드 데님  (총 리뷰 수: 91개)
#   -> 신규 상품 저장 완료 (누적판매: 1415 | 조회수: 7889)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 91개 수집 및 추가 완료!
#
# [17/85] 처리 중: 데미지 워시드 데님 밴딩 팬츠-미디엄블루 (총 리뷰 수: 55개)
#   -> 신규 상품 저장 완료 (누적판매: 801 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 55개 수집 및 추가 완료!
#
# [18/85] 처리 중: 핀 턱 테이핑 트레이닝 팬츠-멜란지그레이 (총 리뷰 수: 50개)
#   -> 신규 상품 저장 완료 (누적판매: 491 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 50개 수집 및 추가 완료!
#
# [19/85] 처리 중: [해피가이정호 pick] 데미지 워시드 데님  (총 리뷰 수: 49개)
#   -> 신규 상품 저장 완료 (누적판매: 696 | 조회수: 14705)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 49개 수집 및 추가 완료!
#
# [20/85] 처리 중: 헤링본 와이드 스트링 팬츠-3Color (총 리뷰 수: 33개)
#   -> 신규 상품 저장 완료 (누적판매: 156 | 조회수: 681)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 33개 수집 및 추가 완료!
#
# [21/85] 처리 중: 밀리터리 카고 팬츠-카키 (총 리뷰 수: 31개)
#   -> 신규 상품 저장 완료 (누적판매: 246 | 조회수: 1798)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 31개 수집 및 추가 완료!
#
# [22/85] 처리 중: 트윌 코튼 밴딩 팬츠-3Color (총 리뷰 수: 30개)
#   -> 신규 상품 저장 완료 (누적판매: 202 | 조회수: 1719)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 30개 수집 및 추가 완료!
#
# [23/85] 처리 중: 데미지 워시드 데님 밴딩 팬츠-블랙 (총 리뷰 수: 30개)
#   -> 신규 상품 저장 완료 (누적판매: 317 | 조회수: 106)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 30개 수집 및 추가 완료!
#
# [24/85] 처리 중: 레귤러 테이퍼드 데님 팬츠-미디엄블루 (총 리뷰 수: 29개)
#   -> 신규 상품 저장 완료 (누적판매: 324 | 조회수: 6066)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 29개 수집 및 추가 완료!
#
# [25/85] 처리 중: 더블 니 코듀로이 팬츠-브라운 (총 리뷰 수: 25개)
#   -> 신규 상품 저장 완료 (누적판매: 234 | 조회수: 364)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 25개 수집 및 추가 완료!
#
# [26/85] 처리 중: [스토커즈 pick] 레귤러 테이퍼드 데님 팬 (총 리뷰 수: 16개)
#   -> 신규 상품 저장 완료 (누적판매: 117 | 조회수: 1319)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 16개 수집 및 추가 완료!
#
# [27/85] 처리 중: 데미지 워시드 데님 밴딩 팬츠-스카이블루 (총 리뷰 수: 16개)
#   -> 신규 상품 저장 완료 (누적판매: 165 | 조회수: 734)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 16개 수집 및 추가 완료!
#
# [28/85] 처리 중: [스토커즈 pick] 레귤러 테이퍼드 데님 팬 (총 리뷰 수: 15개)
#   -> 신규 상품 저장 완료 (누적판매: 91 | 조회수: 1482)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 15개 수집 및 추가 완료!
#
# [29/85] 처리 중: 더블 니 코듀로이 팬츠-블랙 (총 리뷰 수: 14개)
#   -> 신규 상품 저장 완료 (누적판매: 237 | 조회수: 129)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 14개 수집 및 추가 완료!
#
# [30/85] 처리 중: 벌룬 와이드 스웨트 팬츠-멜란지그레이 (총 리뷰 수: 13개)
#   -> 신규 상품 저장 완료 (누적판매: 141 | 조회수: 624)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 13개 수집 및 추가 완료!
#
# [31/85] 처리 중: 볼드 더블 니 스웨트 팬츠-블랙 (총 리뷰 수: 12개)
#   -> 신규 상품 저장 완료 (누적판매: 125 | 조회수: 334)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 12개 수집 및 추가 완료!
#
# [32/85] 처리 중: 벌룬 와이드 스웨트 팬츠-브라운 (총 리뷰 수: 12개)
#   -> 신규 상품 저장 완료 (누적판매: 138 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 12개 수집 및 추가 완료!
#
# [33/85] 처리 중: 더블 니 코듀로이 팬츠-베이지 (총 리뷰 수: 11개)
#   -> 신규 상품 저장 완료 (누적판매: 137 | 조회수: 513)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 11개 수집 및 추가 완료!
#
# [34/85] 처리 중: 벌룬 와이드 코튼 팬츠-블랙 (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 103 | 조회수: 343)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [35/85] 처리 중: 벌룬 와이드 코튼 팬츠-베이지 (총 리뷰 수: 10개)
#   -> 신규 상품 저장 완료 (누적판매: 73 | 조회수: 374)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 10개 수집 및 추가 완료!
#
# [36/85] 처리 중: 와이드 테이퍼드 데님 팬츠-블루 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 392)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [37/85] 처리 중: 타이 라인 데님 팬츠-인디고 (총 리뷰 수: 8개)
#   -> 신규 상품 저장 완료 (누적판매: 75 | 조회수: 455)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 8개 수집 및 추가 완료!
#
# [38/85] 처리 중: 와이드 테이퍼드 데님 팬츠-블랙 (총 리뷰 수: 7개)
#   -> 신규 상품 저장 완료 (누적판매: 89 | 조회수: 391)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 7개 수집 및 추가 완료!
#
# [39/85] 처리 중: 브러쉬드 스트레이트 데님 팬츠-인디고 (총 리뷰 수: 6개)
#   -> 신규 상품 저장 완료 (누적판매: 151 | 조회수: 589)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 6개 수집 및 추가 완료!
#
# [40/85] 처리 중: 코튼 사이드 턱 벌룬 팬츠-블랙 (총 리뷰 수: 5개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 796)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 5개 수집 및 추가 완료!
#
# [41/85] 처리 중: 빈티지 워시드 코듀로이 팬츠-블랙 (총 리뷰 수: 5개)
#   -> 신규 상품 저장 완료 (누적판매: 72 | 조회수: 281)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 5개 수집 및 추가 완료!
#
# [42/85] 처리 중: 브러쉬드 스트레이트 데님 팬츠-블랙 (총 리뷰 수: 5개)
#   -> 신규 상품 저장 완료 (누적판매: 141 | 조회수: 502)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 5개 수집 및 추가 완료!
#
# [43/85] 처리 중: 워시드 플레어 데님 팬츠-다크인디고 (총 리뷰 수: 5개)
#   -> 신규 상품 저장 완료 (누적판매: 57 | 조회수: 498)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 5개 수집 및 추가 완료!
#
# [44/85] 처리 중: 헤이지 워시드 데님 팬츠-블랙 (총 리뷰 수: 5개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 339)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 5개 수집 및 추가 완료!
#
# [45/85] 처리 중: 헤이지 워시드 데님 팬츠-그레이 (총 리뷰 수: 5개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 523)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 5개 수집 및 추가 완료!
#
# [46/85] 처리 중: (W) 슬럽 턴업 세미 와이드 데님 팬츠-블루 (총 리뷰 수: 4개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 2011)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 4개 수집 및 추가 완료!
#
# [47/85] 처리 중: [스토커즈 pick] 원턱 레귤러 데님 팬츠- (총 리뷰 수: 4개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 664)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 4개 수집 및 추가 완료!
#
# [48/85] 처리 중: 빈티지 워시드 코듀로이 팬츠-카키 (총 리뷰 수: 4개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 204)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 4개 수집 및 추가 완료!
#
# [49/85] 처리 중: (W) 레이어드 스커트 팬츠-라이트그레이 (총 리뷰 수: 3개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 1472)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 3개 수집 및 추가 완료!
#
# [50/85] 처리 중: [스토커즈 pick] 원턱 레귤러 데님 팬츠- (총 리뷰 수: 3개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 850)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 3개 수집 및 추가 완료!
#
# [51/85] 처리 중: 벌룬 와이드 스웨트 팬츠-블랙 (총 리뷰 수: 3개)
#   -> 신규 상품 저장 완료 (누적판매: 72 | 조회수: 206)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 3개 수집 및 추가 완료!
#
# [52/85] 처리 중: 택티컬 더블 니 워크 팬츠-블랙 (총 리뷰 수: 3개)
#   -> 신규 상품 저장 완료 (누적판매: 58 | 조회수: 297)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 3개 수집 및 추가 완료!
#
# [53/85] 처리 중: (W) 에센셜 나일론 쇼츠-블랙 (총 리뷰 수: 2개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 501)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 2개 수집 및 추가 완료!
#
# [54/85] 처리 중: 볼드 더블 니 스웨트 팬츠-멜란지그레이 (총 리뷰 수: 2개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 382)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 2개 수집 및 추가 완료!
#
# [55/85] 처리 중: 와이드 테이퍼드 데님 팬츠-그레이 (총 리뷰 수: 2개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 372)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 2개 수집 및 추가 완료!
#
# [56/85] 처리 중: 타이 라인 데님 팬츠-블루 (총 리뷰 수: 2개)
#   -> 신규 상품 저장 완료 (누적판매: 52 | 조회수: 494)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 2개 수집 및 추가 완료!
#
# [57/85] 처리 중: 택티컬 더블 니 워크 팬츠-그레이 (총 리뷰 수: 2개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 309)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 2개 수집 및 추가 완료!
#
# [58/85] 처리 중: 카고 버뮤다 스웨트 쇼츠-멜란지그레이 (총 리뷰 수: 1개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 790)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [59/85] 처리 중: (W) 코튼 스트링 쇼츠-카키 (총 리뷰 수: 1개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 251)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [60/85] 처리 중: (W) 슬럽 턴업 세미 와이드 데님 팬츠-인디 (총 리뷰 수: 1개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 992)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [61/85] 처리 중: (W) 레이어드 스커트 팬츠-블랙 (총 리뷰 수: 1개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 1496)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [62/85] 처리 중: 택티컬 더블 니 워크 팬츠-브라운 (총 리뷰 수: 1개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 305)
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [63/85] 처리 중: 원턱 커브드 린넨 팬츠-블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 203)
#   [스킵] 리뷰 없음
#
# [64/85] 처리 중: 원턱 커브드 린넨 팬츠-베이지 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 202)
#   [스킵] 리뷰 없음
#
# [65/85] 처리 중: 원턱 커브드 린넨 팬츠-내추럴 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 118)
#   [스킵] 리뷰 없음
#
# [66/85] 처리 중: 카고 버뮤다 스웨트 쇼츠-블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 703)
#   [스킵] 리뷰 없음
#
# [67/85] 처리 중: (W) 밀리터리 스트링 팬츠-카키 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 850)
#   [스킵] 리뷰 없음
#
# [68/85] 처리 중: (W) 밀리터리 스트링 팬츠-그레이 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 621)
#   [스킵] 리뷰 없음
#
# [69/85] 처리 중: (W) 투 턱 와이드 팬츠-블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 414)
#   [스킵] 리뷰 없음
#
# [70/85] 처리 중: (W) 투 턱 와이드 팬츠-크림 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 167)
#   [스킵] 리뷰 없음
#
# [71/85] 처리 중: (W) 코튼 스트링 쇼츠-블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 188)
#   [스킵] 리뷰 없음
#
# [72/85] 처리 중: (W) 코튼 스트링 쇼츠-베이지 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 143)
#   [스킵] 리뷰 없음
#
# [73/85] 처리 중: (W)  데미지 데님 쇼츠-인디고 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# [74/85] 처리 중: (W)  데미지 데님 쇼츠-라이트블루 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# [75/85] 처리 중: (W) 에센셜 나일론 쇼츠-와인 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# [76/85] 처리 중: (W) 에센셜 나일론 쇼츠-그레이 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 138)
#   [스킵] 리뷰 없음
#
# [77/85] 처리 중: 시어서커 체크 쇼츠-네이비 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 302)
#   [스킵] 리뷰 없음
#
# [78/85] 처리 중: 시어서커 체크 쇼츠-그린 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 284)
#   [스킵] 리뷰 없음
#
# [79/85] 처리 중: 코튼 사이드 턱 벌룬 팬츠-다크그린 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 505)
#   [스킵] 리뷰 없음
#
# [80/85] 처리 중: 코튼 사이드 턱 벌룬 팬츠-베이지 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 708)
#   [스킵] 리뷰 없음
#
# [81/85] 처리 중: 피드 체크 트랙 팬츠-차콜 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 521)
#   [스킵] 리뷰 없음
#
# [82/85] 처리 중: 피드 체크 트랙 팬츠-그레이 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 421)
#   [스킵] 리뷰 없음
#
# [83/85] 처리 중: 워시드 플레어 데님 팬츠-블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 305)
#   [스킵] 리뷰 없음
#
# [84/85] 처리 중: (W) 심볼 베이직 스웨트 팬츠-블랙 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# [85/85] 처리 중: (W) 심볼 베이직 스웨트 팬츠-오트밀 (총 리뷰 수: 0개)
#   -> 신규 상품 저장 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# 모든 상품 정보 최신화 및 CSV 저장 완료!
