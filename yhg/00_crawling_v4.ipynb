# %%
import requests
import pandas as pd
import time
import os

os.makedirs("data", exist_ok=True)

# ==========================================
# 만족도 파싱 함수
# ==========================================
def parse_satisfaction(survey):
    if not survey:
        return ""
    questions = survey.get("questions", [])
    parts = []
    for q in questions:
        attribute = q.get("attribute", "")
        answers = q.get("answers", [])
        answer_text = ", ".join([a.get("answerShortText", "") for a in answers])
        parts.append(f"{attribute}: {answer_text}")
    return " / ".join(parts)
# ==========================================
# 리뷰 수집 함수 (새로운 리뷰만 수집)
# ==========================================
def get_reviews(goods_no, target_count, collected_ids, max_pages=9999):
    reviews = []
    stop_crawling = False # 크롤링 중단 플래그
    for page in range(max_pages):
        if len(reviews) >= target_count or stop_crawling:
            break
        
        # 리뷰 요청 보내기
        url = "https://goods.musinsa.com/api2/review/v1/view/list"
        params = {
            "page":              page,
            "pageSize":          10,
            "goodsNo":           goods_no,
            "sort":              "new", # 최신순 정렬
            "selectedSimilarNo": goods_no,
            "myFilter":          "false",
            "hasPhoto":          "false",
            "isExperience":      "false",
        }
        try:
            json_data, status_code = request_json(url, params=params, timeout=10, retry=3)
            if not json_data:
                print(f"  상태코드 {status_code} -> 중단")
                break
                
            data = json_data.get("data", {})
            review_list = data.get("list", [])
            
            if not review_list:
                break
                
            for review in review_list:
                review_no = str(review.get("no", ""))
                
                # 핵심 로직: 이미 수집된 리뷰 번호를 만나면 더 이상 과거 리뷰를 탐색할 필요가 없음
                if review_no in collected_ids:
                    stop_crawling = True
                    break 
                
                profile = review.get("userProfileInfo") or {}
                images  = review.get("images") or []
                reviews.append({
                    "goodsNo":  str(goods_no),
                    "리뷰번호": review_no, # 이 값이 중복 체크의 기준이 됩니다
                    "리뷰타입": review.get("type", ""),
                    "작성자":   profile.get("userNickName", ""),
                    "리뷰내용": review.get("content", ""),
                    "평점":     int(review.get("grade", 0)),
                    "체험단":   review.get("type") == "experience",
                    "구매옵션": review.get("goodsOption", ""),
                    "키":       profile.get("userHeight", ""),
                    "몸무게":   profile.get("userWeight", ""),
                    "성별":     profile.get("reviewSex", ""),
                    "작성일":   review.get("createDate", ""),
                    "만족도":   parse_satisfaction(review.get("reviewSurveySatisfaction")),
                    "사진유무": len(images) > 0,
                    "도움돼요": review.get("likeCount", 0),
                })
                
                if len(reviews) >= target_count:
                    break
                    
            total_pages = data.get("page", {}).get("totalPages", 0)
            if page >= total_pages - 1:
                break
                
            if len(reviews) % 100 == 0 and len(reviews) > 0:
                print(f"  새로운 리뷰 {len(reviews)}개 수집 중...")
            time.sleep(2)
            
        except Exception as e:
            print(f"  리뷰 수집 오류: {e}")
            time.sleep(2)
            break
            
    return reviews
# ==========================================
# 상품 통계(조회수, 판매량) 수집 함수
# ==========================================
def get_goods_stats(goods_no):
    url = f"https://goods-detail.musinsa.com/api2/goods/{goods_no}/stat"
    try:
        json_data, status_code = request_json(url, timeout=10, retry=3)
        if json_data:
            sales_count = json_data.get("data", {}).get("purchaseTotal", 0)
            views_count = json_data.get("data", {}).get("pageViewTotal", 0)
            return sales_count, views_count
        else:
            print(f"  통계 수집 실패 ({goods_no}): {status_code}")
    except Exception as e:
        print(f"  통계 수집 오류 ({goods_no}): {e}")
    return 0, 0
# ==========================================
# escape_excel 함수 추가
# ==========================================
def escape_excel(text):
    if isinstance(text, str) and text.startswith(('-', '=', '+', '@', '#')):
        return "'" + text
    return text
# ==========================================
# 중간 저장 함수
# ==========================================
#def save_product(row_dict):
    df_row = pd.DataFrame([row_dict])
    if os.path.exists(PRODUCTS_CSV):
        df_row.to_csv(PRODUCTS_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_row.to_csv(PRODUCTS_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
def save_reviews(reviews):
    if not reviews:
        return
    df_r = pd.DataFrame(reviews)
    
    # 줄바꿈 문자 제거 (CSV 깨짐 방지)
    df_r["리뷰내용"] = df_r["리뷰내용"].astype(str).str.replace(r'[\n\r\t]', ' ', regex=True)
    # 엑셀 오류 방지 처리
    for col in ['리뷰내용', '작성자']:
        if col in df_r.columns:
            df_r[col] = df_r[col].apply(escape_excel)
    
    if os.path.exists(REVIEWS_CSV):
        df_r.to_csv(REVIEWS_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_r.to_csv(REVIEWS_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
def save_error(goods_no, error_type, message):
    df_e = pd.DataFrame([{
        "goodsNo":    goods_no,
        "error_type": error_type,
        "message":    message,
        "time":       pd.Timestamp.now().strftime("%Y-%m-%d %H:%M:%S"),
    }])
    if os.path.exists(ERRORS_CSV):
        df_e.to_csv(ERRORS_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_e.to_csv(ERRORS_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
        
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36",
    "Referer": "https://www.musinsa.com/",
    "Origin": "https://www.musinsa.com",
}
BRAND         = "jemut"
CATEGORIES = {
    #"001": "상의",
    "002": "아우터",
    "003": "하의",
}
PAGE_SIZE     = 30 # 추측 최대 상한선이 100
#001 : 상의, 002 : 아우터, 003 : 하의
session = requests.Session()
session.headers.update(headers)
session.headers["Referer"] = f"https://www.musinsa.com/brand/{BRAND}"
def request_json(url, params=None, timeout=10, retry=3):
    last_status = None
    last_error = None
    for attempt in range(1, retry + 1):
        try:
            response = session.get(url, params=params, timeout=timeout)
            last_status = response.status_code
            if response.status_code == 200:
                return response.json(), response.status_code
            print(f"요청 실패 ({response.status_code}) -> 재시도 {attempt}/{retry}")
        except Exception as e:
            last_error = e
            print(f"요청 오류 -> 재시도 {attempt}/{retry}: {e}")
        time.sleep(2 * attempt)
    if last_error is not None:
        print(f"최종 요청 오류: {last_error}")
    return None, last_status
for CATEGORY, CATEGORY_NAME in CATEGORIES.items():
    # CSV 경로를 카테고리마다 새로 설정
    PRODUCTS_CSV = f"data/{BRAND}_products_{CATEGORY}.csv"
    REVIEWS_CSV  = f"data/{BRAND}_reviews_{CATEGORY}.csv"
    ERRORS_CSV   = f"data/{BRAND}_errors_{CATEGORY}.csv"
    print(f"\n{'='*50}")
    print(f"▶ 카테고리 [{CATEGORY}] {CATEGORY_NAME} 수집 시작")
    print(f"{'='*50}")
    
    # ==========================================
    # 브랜드 전체 상품 수집
    # ==========================================
    all_data = []
    page = 1
    next_page_url = None  # 다음 페이지 URL (hmacId 포함)
    while True:
        try:
            if next_page_url:
                # 2페이지부터: nextPageUrl을 그대로 사용 (hmacId 포함)
                json_data, status_code = request_json(next_page_url, timeout=10, retry=3)
            else:
                # 1페이지: 기존 방식으로 요청
                url = "https://api.musinsa.com/api2/dp/v2/plp/goods"
                params = {
                    "gf":       "A",
                    "isSoldOut": "true", # 추가
                    "sortCode": "REVIEW",
                    "category": CATEGORY,
                    "brand":    BRAND,
                    "size":     PAGE_SIZE,
                    "caller":   "FLAGSHIP",
                    "page":     page,
                }
                json_data, status_code = request_json(url, params=params, timeout=10, retry=3)
            
            if not json_data: # 데이터가 비어있다면 무한루프 탈출
                print(f"상품 수집 실패 (page {page}): {status_code}")
                break
            
            data = json_data.get("data", {})
            goods_list = data.get("list", [])
            if not goods_list:# 상품 리스트가 비어있다면 더 이상 수집할 데이터가 없다고 판단하여 반복 종료
                break
            
            for item in goods_list:
                is_sold_out = item.get("isSoldOut", False)
                all_data.append({
                    "플랫폼":    "무신사",
                    "카테고리":  CATEGORY_NAME,
                    "브랜드":    item.get("brandName", ""),
                    "goodsNo":  str(item.get("goodsNo", "")),
                    "상품명":    item.get("goodsName", ""),
                    "정가":      item.get("normalPrice", 0),
                    "판매가":    item.get("price", 0),
                    "할인율": item.get("saleRate", 0),
                    "리뷰수":    item.get("reviewCount", 0),
                    "리뷰점수":  item.get("reviewScore", 0),
                    "판매상태":  "SOLD_OUT" if is_sold_out else "SALE",
                })
            pagination = data.get("pagination", {})
            total_pages = pagination.get("totalPages", 1)
            print(f"상품 수집 중... {page}/{total_pages} 페이지 (누적 {len(all_data)}개)")
            
            # 다음 페이지 URL 추출 (hmacId 포함)
            next_page_url = pagination.get("nextPageUrl")
            
            if not pagination.get("hasNext", False) or page >= total_pages:
                break
            page += 1
            time.sleep(2)
        except Exception as e:
            print(f"상품 수집 오류 (page {page}): {e}")
            time.sleep(2)
            break
    # 리뷰 많은 순으로 정렬 (전체)
    df = pd.DataFrame(all_data)
    df = df.sort_values("리뷰수", ascending=False).reset_index(drop=True)
    df["조회수"] = 0
    df["누적판매수"] = 0
    print(f"\n상품 총 {len(df)}개 수집 완료 (리뷰 많은 순)")
    print(df[["카테고리", "브랜드", "상품명", "리뷰수"]].to_string(index=False))
    # ==========================================
    # 재시작 로직 - 이미 수집된 goodsNo 및 리뷰번호 확인
    # ==========================================
    collected_review_ids = set()
    if os.path.exists(PRODUCTS_CSV): # products csv 파일 존재시
        df_existing = pd.read_csv(PRODUCTS_CSV)
        df_existing["goodsNo"] = df_existing["goodsNo"].astype(str)
        df_existing.set_index("goodsNo", inplace=True)
        print(f"\n기존 수집된 상품 {len(df_existing)}개 확인 -> 기존 정보 최신화 및 신규 리뷰 수집 예정")
    else:
        df_existing = pd.DataFrame() # 빈 데이터프레임 생성
        print("\n기존 수집 상품 파일 없음 -> 처음부터 수집 시작")
    if os.path.exists(REVIEWS_CSV): # reviews csv 파일 존재시
        df_existing_reviews = pd.read_csv(REVIEWS_CSV)
        collected_review_ids = set(df_existing_reviews["리뷰번호"].astype(str).tolist())
        print(f"기존 수집된 개별 리뷰 {len(collected_review_ids)}개 확인 -> 중복 리뷰 스킵 예정")
    # ==========================================
    # 전체 상품 리뷰 및 통계 수집
    # ==========================================
    total_items = len(df)
    for idx, row in df.iterrows():
        goods_no     = row["goodsNo"]
        target_count = int(row["리뷰수"])
        current_item = idx + 1
        
        is_new_product = df_existing.empty or goods_no not in df_existing.index # 상품번호가 기존에 없는 번호라면 True(신규 상품)
        print(f"\n[{current_item}/{total_items}] 처리 중: {str(row['상품명'])[:25]} (총 리뷰 수: {target_count}개)")
        # 1. 통계 수집 (기존/신규 상관없이 무조건 수집하여 최신화)
        try:
            sales, views = get_goods_stats(goods_no)
        except Exception as e:
            print(f"  통계 수집 실패: {e}")
            save_error(goods_no, "stats", str(e))
            # API 오류 시 기존 데이터가 있다면 유지, 없다면 0으로 처리
            if not is_new_product:
                sales = df_existing.at[goods_no, "누적판매수"]
                views = df_existing.at[goods_no, "조회수"]
            else:
                sales, views = 0, 0
        time.sleep(2)
        # # 2. Survey 수집 (신규 상품일 경우에만 진행하도록 권장. 필요시 무조건 수집으로 변경 가능)
        # # 신규 상품인 경우만 진행하도록 설계되어 있음.
        # if is_new_product:
        #     try:
        #         survey_rows = get_survey(goods_no)
        #         save_survey(survey_rows)
        #         print(f"  survey {len(survey_rows)}행 저장 완료 (신규)")
        #     except Exception as e:
        #         print(f"  survey 수집 실패: {e}")
        #         save_error(goods_no, "survey", str(e))
        #     time.sleep(2)
        # 3. 데이터프레임(df_existing)에 최신 정보 업데이트 또는 추가
        updated_info = {
            "플랫폼":    row["플랫폼"],
            "카테고리":  row["카테고리"],
            "브랜드":    row["브랜드"],
            "상품명":    row["상품명"],
            "정가":      row["정가"],
            "판매가":    row["판매가"],
            "할인율": row["할인율"],
            "조회수":    views,
            "누적판매수": sales,
            "리뷰수":    row["리뷰수"],
            "리뷰점수":  row["리뷰점수"],
            "판매상태":  row["판매상태"],
        }
        
        # Pandas를 이용해 해당 goods_no 행을 최신 정보로 덮어쓰기 (없으면 새로 생성됨)
        for key, value in updated_info.items():
            df_existing.at[goods_no, key] = value
            
        if is_new_product:
            print(f"  -> 신규 상품 저장 완료 (누적판매: {sales} | 조회수: {views})")
        else:
            print(f"  -> 기존 상품 정보 최신화 완료 (누적판매: {sales} | 조회수: {views})")
        # 4. 리뷰 수집 로직 (기존 코드와 동일)
        if not goods_no or target_count == 0:
            print(f"  [스킵] 리뷰 없음")
        else:
            print(f"  새로운 리뷰 수집 확인 중...")
            try:
                reviews = get_reviews(goods_no, target_count=target_count, collected_ids=collected_review_ids)
                if len(reviews) > 0:
                    save_reviews(reviews)
                    collected_review_ids.update([str(r["리뷰번호"]) for r in reviews])
                    print(f"  -> 새로운 리뷰 {len(reviews)}개 수집 및 추가 완료!")
                else:
                    print(f"  -> 추가된 새로운 리뷰가 없습니다.")
            except Exception as e:
                print(f"  리뷰 수집 실패: {e}")
                save_error(goods_no, "review", str(e))
                
        time.sleep(2)
    # ==========================================
    # 최종 최신화된 상품 데이터를 CSV에 덮어쓰기
    # ==========================================
    df_existing.reset_index(inplace=True)
    if 'index' in df_existing.columns:
        df_existing.rename(columns={'index': 'goodsNo'}, inplace=True)
    df_existing.to_csv(PRODUCTS_CSV, index=False, encoding="utf-8-sig")
    print("\n모든 상품 정보 최신화 및 CSV 저장 완료!")
# Out:
# ==================================================
# ▶ 카테고리 [002] 아우터 수집 시작
# ==================================================
# 상품 수집 중... 1/9 페이지 (누적 30개)
# 상품 수집 중... 2/9 페이지 (누적 60개)
# 상품 수집 중... 3/9 페이지 (누적 90개)
# 상품 수집 중... 4/9 페이지 (누적 120개)
# 상품 수집 중... 5/9 페이지 (누적 150개)
# 상품 수집 중... 6/9 페이지 (누적 180개)
# 상품 수집 중... 7/9 페이지 (누적 210개)
# 상품 수집 중... 8/9 페이지 (누적 240개)
# 상품 수집 중... 9/9 페이지 (누적 270개)
#
# 상품 총 270개 수집 완료 (리뷰 많은 순)
# 카테고리 브랜드                                                       상품명   리뷰수
#  아우터  제멋                             아워 루즈핏 모헤어 가디건 4종 블랙 SOKN2604     2
#  아우터  제멋                          아워 루즈핏 모헤어 가디건 4종 샌드베이지 SOKN2604     2
#  아우터  제멋                             트랩 헤비 윈드쉴드 자켓 5종 베이지 SOJK2525     2
#  아우터  제멋                                  크리스 워크 헌팅 자켓 그린 KJJK2581     2
#  아우터  제멋                                 크리스 워크 헌팅 자켓 베이지 KJJK2581     1
#  아우터  제멋                              노바 오버핏 레글런 후드집업 브라운 SOHD2608     1
#  아우터  제멋                                 러쉬 하이넥 크롭 블루종 블랙 NSOT2609     1
#  아우터  제멋                           피트 보아 플리스 집업 자켓 5종 베이지 OYOT2381     1
#  아우터  제멋                             로우 리버시블 양털 후드집업 아이보리 YHHD2174     1
#  아우터  제멋                                   테넌 라이트 블루종 네이비 JUOT2696     0
#  아우터  제멋                                      온오프 트랙자켓 블랙 JJOT2694     0
#  아우터  제멋                                     온오프 트랙자켓 브라운 JJOT2694     0
#  아우터  제멋                                     온오프 트랙자켓 네이비 JJOT2694     0
#  아우터  제멋                                     온오프 트랙자켓 그레이 JJOT2694     0
#  아우터  제멋                                    테넌 라이트 블루종 카키 JUOT2696     0
#  아우터  제멋                               루나 레글런 벌룬 후드집업 오트밀 KJHD2613     0
#  아우터  제멋                             노바 오버핏 레글런 후드집업 딥그레이 SOHD2608     0
#  아우터  제멋                              노바 오버핏 레글런 후드집업 네이비 SOHD2608     0
#  아우터  제멋                            티드 오버핏 투웨이 후드집업 다크그레이 YHHD2310     0
#  아우터  제멋                             로우 리버시블 양털 후드집업 바이올렛 YHHD2174     0
#
# 기존 수집된 상품 270개 확인 -> 기존 정보 최신화 및 신규 리뷰 수집 예정
# 기존 수집된 개별 리뷰 45594개 확인 -> 중복 리뷰 스킵 예정
#
# [1/270] 처리 중: 리치 오버 MA-1 자켓 블랙 YHJK2269 (총 리뷰 수: 17293개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 87999 | 조회수: 18409)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [2/270] 처리 중: 하이 양기모 후드 집업 그레이(HJHD2082 (총 리뷰 수: 2934개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 14589 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [3/270] 처리 중: 리치 오버 MA-1 자켓 카키 YHJK2269 (총 리뷰 수: 2718개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 10320 | 조회수: 4403)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [4/270] 처리 중: 카디 오버핏 MA-1 자켓 블랙 YHJK231 (총 리뷰 수: 1909개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 8271 | 조회수: 446)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [5/270] 처리 중: 카디 오버핏 MA-1 자켓 딥그레이 YHJK2 (총 리뷰 수: 1613개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 5795 | 조회수: 273)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [6/270] 처리 중: 노블 투웨이 오버핏 MA-1 자켓 블랙 HJJ (총 리뷰 수: 1586개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 4093 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [7/270] 처리 중: 엔트 투웨이 후드집업 그레이 KJHD2272 (총 리뷰 수: 1560개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 5520 | 조회수: 338)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [8/270] 처리 중: 하이 양기모 후드 집업 블랙(HJHD2082) (총 리뷰 수: 1341개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 8309 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [9/270] 처리 중: 헤븐 투웨이 테리 후드집업 8종 그레이 KJH (총 리뷰 수: 1056개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 7550 | 조회수: 5806)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [10/270] 처리 중: 레더 레글런 바시티 자켓 4종 다크그린 YHO (총 리뷰 수: 972개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 4086 | 조회수: 1052)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [11/270] 처리 중: 리치 오버 MA-1 자켓 그레이 YHJK226 (총 리뷰 수: 944개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 3364 | 조회수: 740)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [12/270] 처리 중: 로그 오버핏 투웨이 기모 후드집업 6종 그레이 (총 리뷰 수: 689개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 5246 | 조회수: 2164)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [13/270] 처리 중: 헤븐 투웨이 테리 후드집업 8종 버건디 KJH (총 리뷰 수: 618개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 3860 | 조회수: 3294)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [14/270] 처리 중: 카디 오버핏 MA-1 자켓 세이지 YHJK23 (총 리뷰 수: 533개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1958 | 조회수: 172)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [15/270] 처리 중: 파일 오버핏 투웨이 후드집업 6종 그레이 KJ (총 리뷰 수: 441개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1897 | 조회수: 297)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [16/270] 처리 중: 엔트 투웨이 후드집업 블랙 KJHD2272 (총 리뷰 수: 429개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1980 | 조회수: 200)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [17/270] 처리 중: 노블 투웨이 오버핏 MA-1 자켓 카키 HJJ (총 리뷰 수: 404개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 982 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [18/270] 처리 중: 레더 레글런 바시티 자켓 4종 네이비 YHOT (총 리뷰 수: 389개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1909 | 조회수: 873)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [19/270] 처리 중: 헤븐 투웨이 테리 후드집업 8종 블랙 KJHD (총 리뷰 수: 301개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1996 | 조회수: 1159)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [20/270] 처리 중: [2PACK] 헤븐 투웨이 테리 후드집업 8종 (총 리뷰 수: 292개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1578 | 조회수: 586)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [21/270] 처리 중: 프라임 오버핏 스타디움 자켓 2종 네이비 OY (총 리뷰 수: 250개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 907 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [22/270] 처리 중: 레더 레글런 바시티 자켓 4종 퍼플 YHOT2 (총 리뷰 수: 230개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 920 | 조회수: 267)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [23/270] 처리 중: 하이 양기모 후드 집업 다크그레이 HJHD20 (총 리뷰 수: 216개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 917 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [24/270] 처리 중: 로그 오버핏 투웨이 기모 후드집업 6종 블랙  (총 리뷰 수: 216개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1667 | 조회수: 711)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [25/270] 처리 중: 레더 레글런 바시티 자켓 4종 블랙 YHOT2 (총 리뷰 수: 213개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1116 | 조회수: 527)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [26/270] 처리 중: 덤블 기모후드집업 그레이(HJHD2038) (총 리뷰 수: 212개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 2381 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [27/270] 처리 중: 엔트 투웨이 후드집업 차콜 KJHD2272 (총 리뷰 수: 184개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 858 | 조회수: 127)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [28/270] 처리 중: 파일 오버핏 투웨이 후드집업 6종 블랙 KJH (총 리뷰 수: 179개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 945 | 조회수: 214)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [29/270] 처리 중: 헤븐 투웨이 테리 후드집업 8종 네이비 KJH (총 리뷰 수: 170개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 1562 | 조회수: 2536)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [30/270] 처리 중: [2PACK] 엔트 투웨이 후드집업  KJHD (총 리뷰 수: 166개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 586 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [31/270] 처리 중: 샤인 벌룬핏 기모 후드집업 그레이 KJHD23 (총 리뷰 수: 160개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 485 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [32/270] 처리 중: [2PACK] 파일 오버핏 투웨이 후드집업 6 (총 리뷰 수: 158개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 585 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [33/270] 처리 중: [19FW] 에픽 리버시블 구스다운 베스트 블 (총 리뷰 수: 154개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 787 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [34/270] 처리 중: [2PACK] 로그 오버핏 투웨이 기모 후드집 (총 리뷰 수: 147개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 837 | 조회수: 212)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [35/270] 처리 중: 하이 양기모 후드 집업 크림 HJHD2082 (총 리뷰 수: 137개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 699 | 조회수: 140)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [36/270] 처리 중: 로그 오버핏 투웨이 기모 후드집업 6종 다크네 (총 리뷰 수: 136개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 891 | 조회수: 867)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [37/270] 처리 중: 파일 오버핏 투웨이 후드집업 6종 딥그레이 K (총 리뷰 수: 135개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 569 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [38/270] 처리 중: 샤인 벌룬핏 기모 후드집업 블랙 KJHD237 (총 리뷰 수: 117개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 427 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [39/270] 처리 중: 파일 오버핏 투웨이 후드집업 6종 다크네이비  (총 리뷰 수: 112개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 438 | 조회수: 291)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [40/270] 처리 중: [SET] 하디 오버핏 벌룬 후드집업 세트 S (총 리뷰 수: 108개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 390 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [41/270] 처리 중: 헤븐 투웨이 테리 후드집업 8종 차콜 KJHD (총 리뷰 수: 107개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 583 | 조회수: 587)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [42/270] 처리 중: 파일 오버핏 투웨이 후드집업 6종 백오트밀 K (총 리뷰 수: 104개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 654 | 조회수: 748)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [43/270] 처리 중: 헤븐 피그먼트 투웨이 후드집업 차콜 KJHD2 (총 리뷰 수: 94개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 701 | 조회수: 977)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [44/270] 처리 중: 이터널 플리스 집업 자켓 7종 블랙 KJJK2 (총 리뷰 수: 93개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 363 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [45/270] 처리 중: 덤블 기모후드집업 블랙(HJHD2038) (총 리뷰 수: 89개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 548 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [46/270] 처리 중: 베라 윈드 집업 자켓 2종 블랙 KHJK255 (총 리뷰 수: 84개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 440 | 조회수: 1758)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [47/270] 처리 중: 하디 오버핏 벌룬 후드집업 그레이 SOHD23 (총 리뷰 수: 83개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 307 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [48/270] 처리 중: 윈드 퍼 후드집업 2종 아이보리 HJHD216 (총 리뷰 수: 82개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 438 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [49/270] 처리 중: 덤보 기모 스웨트 집업 그레이 YHOT2376 (총 리뷰 수: 72개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 243 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [50/270] 처리 중: 네버마인드 리버시블 구스다운 패딩 블랙 YHO (총 리뷰 수: 71개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 253 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [51/270] 처리 중: 헤븐 투웨이 테리 후드집업 8종 다크그린 KJ (총 리뷰 수: 67개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 578 | 조회수: 653)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [52/270] 처리 중: 헤븐 투웨이 테리 후드집업 8종 올리브 KJH (총 리뷰 수: 65개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 255 | 조회수: 366)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [53/270] 처리 중: 샤인 벌룬핏 기모 후드집업 차콜 KJHD237 (총 리뷰 수: 65개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 211 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [54/270] 처리 중: 헤븐 투웨이 테리 후드집업 8종 아이보리 KJ (총 리뷰 수: 62개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 591 | 조회수: 1839)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [55/270] 처리 중: 와이즈 오버핏 투웨이 후드집업 그레이 KJHD (총 리뷰 수: 61개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 371 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [56/270] 처리 중: 인리드 트윌 자켓 크림 YHJK2268 (총 리뷰 수: 60개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 200 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [57/270] 처리 중: 로프 오버핏 기모 후드집업 차콜 KJHD232 (총 리뷰 수: 59개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 205 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [58/270] 처리 중: 로프 오버핏 기모 후드집업 그레이 KJHD23 (총 리뷰 수: 58개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 224 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [59/270] 처리 중: 웜스 양털 자켓 3종 아이보리 HJJK2166 (총 리뷰 수: 58개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 299 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [60/270] 처리 중: 로그 오버핏 투웨이 기모 후드집업 6종 크림  (총 리뷰 수: 57개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 412 | 조회수: 513)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [61/270] 처리 중: 사이드 트랙 후드집업 버건디 OYHD2546 (총 리뷰 수: 56개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 268 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [62/270] 처리 중: 로벤 코튼 스타디움 자켓 3종 네이비 KJJK (총 리뷰 수: 53개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 115 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [63/270] 처리 중: [19FW] 라이프타임 후리스 자켓 딥그린 Y (총 리뷰 수: 53개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 161 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [64/270] 처리 중: [2PACK] 헤븐 피그먼트 투웨이 후드집업  (총 리뷰 수: 53개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 191 | 조회수: 180)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [65/270] 처리 중: 프라임 오버핏 스타디움 자켓 2종 블랙 OYO (총 리뷰 수: 52개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 376 | 조회수: 184)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [66/270] 처리 중: 라이프타임 후리스 자켓 블랙 YHJK2173 (총 리뷰 수: 51개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 165 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [67/270] 처리 중: 파일 오버핏 투웨이 후드집업 6종 라벤더 KJ (총 리뷰 수: 49개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 188 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [68/270] 처리 중: 스톤 헤비웨이트 투웨이 후드집업 6종 그레이  (총 리뷰 수: 48개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 342 | 조회수: 378)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [69/270] 처리 중: 프라이멀 스탠다드 MA-1 자켓 블랙 SOJK (총 리뷰 수: 48개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 130 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [70/270] 처리 중: 덤보 기모 스웨트 집업 블랙 YHOT2376 (총 리뷰 수: 47개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 143 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [71/270] 처리 중: 샤인 벌룬핏 기모 후드집업 오트밀 KJHD23 (총 리뷰 수: 46개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 161 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [72/270] 처리 중: 라이트 투웨이 퀼팅 자켓 블랙 KJJK2314 (총 리뷰 수: 46개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 179 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [73/270] 처리 중: 로프 오버핏 기모 후드집업 블랙 KJHD232 (총 리뷰 수: 46개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 206 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [74/270] 처리 중: 이터널 플리스 집업 자켓 7종 차콜 KJJK2 (총 리뷰 수: 45개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 153 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [75/270] 처리 중: 하디 오버핏 벌룬 후드집업 블랙 SOHD237 (총 리뷰 수: 44개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 188 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [76/270] 처리 중: 로프 오버핏 기모 후드집업 모카 KJHD232 (총 리뷰 수: 44개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 134 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [77/270] 처리 중: 사이드 트랙 후드집업 네이비 OYHD2546 (총 리뷰 수: 41개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 280 | 조회수: 155)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [78/270] 처리 중: 레인지 투웨이 푸퍼 그레이 YHOT2363 (총 리뷰 수: 41개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 183 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [79/270] 처리 중: 샤인 벌룬핏 기모 후드집업 네이비 KJHD23 (총 리뷰 수: 41개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 148 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [80/270] 처리 중: 피트 보아 플리스 집업 자켓 5종 블랙 OYO (총 리뷰 수: 40개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 124 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [81/270] 처리 중: 사이드 트랙 후드집업 그레이 OYHD2546 (총 리뷰 수: 40개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 292 | 조회수: 131)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [82/270] 처리 중: 레인지 투웨이 푸퍼 블랙 YHOT2363 (총 리뷰 수: 40개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 183 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [83/270] 처리 중: 헤븐 피그먼트 투웨이 후드집업 브라운 KJHD (총 리뷰 수: 39개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 228 | 조회수: 325)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [84/270] 처리 중: 네버마인드 리버시블 구스다운 패딩 그레이 YH (총 리뷰 수: 39개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 179 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [85/270] 처리 중: [20FW] 모스트 양털 후드 자켓 카키 JM (총 리뷰 수: 39개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 142 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [86/270] 처리 중: 프라이멀 스탠다드 MA-1 자켓 건메탈 SOJ (총 리뷰 수: 39개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 78 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [87/270] 처리 중: 스프레드 기모 후드집업 5종 틸블루 OYHD2 (총 리뷰 수: 38개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 122 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [88/270] 처리 중: [2PACK] 와이즈 오버핏 투웨이 후드집업  (총 리뷰 수: 38개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 216 | 조회수: 153)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [89/270] 처리 중: [19FW] 라이프타임 후리스 자켓 네이비 Y (총 리뷰 수: 36개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 136 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
#
| 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [248/270] 처리 중: 루나 레글런 벌룬 후드집업 브라운 KJHD26 (총 리뷰 수: 2개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 59 | 조회수: 276)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [249/270] 처리 중: 루나 레글런 벌룬 후드집업 네이비 KJHD26 (총 리뷰 수: 2개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 54 | 조회수: 513)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [250/270] 처리 중: 루나 레글런 벌룬 후드집업 블랙 KJHD261 (총 리뷰 수: 2개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 62 | 조회수: 550)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [251/270] 처리 중: 아워 루즈핏 모헤어 가디건 4종 블랙 SOKN (총 리뷰 수: 2개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 50 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [252/270] 처리 중: 아워 루즈핏 모헤어 가디건 4종 샌드베이지 S (총 리뷰 수: 2개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 182)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [253/270] 처리 중: 트랩 헤비 윈드쉴드 자켓 5종 베이지 SOJK (총 리뷰 수: 2개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [254/270] 처리 중: 크리스 워크 헌팅 자켓 그린 KJJK2581 (총 리뷰 수: 2개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 188)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [255/270] 처리 중: 크리스 워크 헌팅 자켓 베이지 KJJK2581 (총 리뷰 수: 1개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 293)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [256/270] 처리 중: 노바 오버핏 레글런 후드집업 브라운 SOHD2 (총 리뷰 수: 1개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [257/270] 처리 중: 러쉬 하이넥 크롭 블루종 블랙 NSOT2609 (총 리뷰 수: 1개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [258/270] 처리 중: 피트 보아 플리스 집업 자켓 5종 베이지 OY (총 리뷰 수: 1개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [259/270] 처리 중: 로우 리버시블 양털 후드집업 아이보리 YHHD (총 리뷰 수: 1개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 0)
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [260/270] 처리 중: 테넌 라이트 블루종 네이비 JUOT2696 (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 267)
#   [스킵] 리뷰 없음
#
# [261/270] 처리 중: 온오프 트랙자켓 블랙 JJOT2694 (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 269)
#   [스킵] 리뷰 없음
#
# [262/270] 처리 중: 온오프 트랙자켓 브라운 JJOT2694 (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# [263/270] 처리 중: 온오프 트랙자켓 네이비 JJOT2694 (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 133)
#   [스킵] 리뷰 없음
#
# [264/270] 처리 중: 온오프 트랙자켓 그레이 JJOT2694 (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 102)
#   [스킵] 리뷰 없음
#
# [265/270] 처리 중: 테넌 라이트 블루종 카키 JUOT2696 (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 542)
#   [스킵] 리뷰 없음
#
# [266/270] 처리 중: 루나 레글런 벌룬 후드집업 오트밀 KJHD26 (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 171)
#   [스킵] 리뷰 없음
#
# [267/270] 처리 중: 노바 오버핏 레글런 후드집업 딥그레이 SOHD (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# [268/270] 처리 중: 노바 오버핏 레글런 후드집업 네이비 SOHD2 (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# [269/270] 처리 중: 티드 오버핏 투웨이 후드집업 다크그레이 YHH (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
#
# [270/270] 처리 중: 로우 리버시블 양털 후드집업 바이올렛 YHHD (총 리뷰 수: 0개)
#   -> 기존 상품 정보 최신화 완료 (누적판매: 0 | 조회수: 0)
#   [스킵] 리뷰 없음
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 374
#     370     # ==========================================
#     371     df_existing.reset_index(inplace=True)
#     372     if 'index' in df_existing.columns:
#     373         df_existing.rename(columns={'index': 'goodsNo'}, inplace=True)
# --> 374     df_existing.to_csv(PRODUCTS_CSV, index=False, encoding="utf-8-sig")
#     375     print("\n모든 상품 정보 최신화 및 CSV 저장 완료!")
#
# File c:\Users\hkhk3\Desktop\sparta\project\tp4\review_analysis_filluminate\.venv\Lib\site-packages\pandas\core\generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3977 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3979 formatter = DataFrameFormatter(
#    3980     frame=df,
#    3981     header=header,
#    (...)   3985     decimal=decimal,
#    3986 )
# -> 3988 return DataFrameRenderer(formatter).to_csv(
#    3989     path_or_buf,
#    3990     lineterminator=lineterminator,
#    3991     sep=sep,
#    3992     encoding=encoding,
#    3993     errors=errors,
#    3994     compression=compression,
#    3995     quoting=quoting,
#    3996     columns=columns,
#    3997     index_label=index_label,
#    3998     mode=mode,
#    3999     chunksize=chunksize,
#    4000     quotechar=quotechar,
#    4001     date_format=date_format,
#    4002     doublequote=doublequote,
#    4003     escapechar=escapechar,
#    4004     storage_options=storage_options,
#    4005 )
#
# File c:\Users\hkhk3\Desktop\sparta\project\tp4\review_analysis_filluminate\.venv\Lib\site-packages\pandas\io\formats\format.py:1025, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1004     created_buffer = False
#    1006 csv_formatter = CSVFormatter(
#    1007     path_or_buf=path_or_buf,
#    1008     lineterminator=lineterminator,
#    (...)   1023     formatter=self.fmt,
#    1024 )
# -> 1025 csv_formatter.save()
#    1027 if created_buffer:
#    1028     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\hkhk3\Desktop\sparta\project\tp4\review_analysis_filluminate\.venv\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     # error: Argument "quoting" to "writer" has incompatible type "int";
#     261     # expected "Literal[0, 1, 2, 3]"
#     262     self.writer = csvlib.writer(
#     263         handles.handle,
#     264         lineterminator=self.lineterminator,
#    (...)    269         quotechar=self.quotechar,
#     270     )
#     272     self._save()
#
# File c:\Users\hkhk3\Desktop\sparta\project\tp4\review_analysis_filluminate\.venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'data/jemut_products_002.csv'
