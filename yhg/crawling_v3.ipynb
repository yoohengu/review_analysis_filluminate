# %%
import requests
import pandas as pd
import time
import os

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/146.0.0.0 Safari/537.36",
    "Referer": "https://www.musinsa.com/",
    "Origin": "https://www.musinsa.com",
    "Accept": "application/json, text/plain, */*",
    "Accept-Language": "ko-KR,ko;q=0.9",
}

BRAND         = "filluminate"
CATEGORY      = "003"
CATEGORY_NAME = "바지"
PAGE_SIZE     = 100

# CSV 파일 경로
PRODUCTS_CSV = f"products_{CATEGORY}.csv"
REVIEWS_CSV  = f"reviews_{CATEGORY}.csv"
SURVEY_CSV   = f"survey_{CATEGORY}.csv"
ERRORS_CSV   = f"errors_{CATEGORY}.csv"

session = requests.Session()
session.headers.update(headers)
session.headers["Referer"] = f"https://www.musinsa.com/brand/{BRAND}"

def request_json(url, params=None, timeout=10, retry=3):
    last_status = None
    last_error = None
    for attempt in range(1, retry + 1):
        try:
            response = session.get(url, params=params, timeout=timeout)
            last_status = response.status_code
            if response.status_code == 200:
                return response.json(), response.status_code
            print(f"요청 실패 ({response.status_code}) -> 재시도 {attempt}/{retry}")
        except Exception as e:
            last_error = e
            print(f"요청 오류 -> 재시도 {attempt}/{retry}: {e}")
        time.sleep(2 * attempt)
    if last_error is not None:
        print(f"최종 요청 오류: {last_error}")
    return None, last_status
# ==========================================
# Step 1: 브랜드 전체 상품 수집
# ==========================================
all_data = []
page = 1
while True:
    try:
        url = "https://api.musinsa.com/api2/dp/v2/plp/goods"
        params = {
            "gf":       "A",
            "sortCode": "REVIEW",
            "category": CATEGORY,
            "brand":    BRAND,
            "size":     PAGE_SIZE,
            "caller":   "FLAGSHIP",
            "page":     page,
        }
        json_data, status_code = request_json(url, params=params, timeout=10, retry=3)
        if not json_data:
            print(f"상품 수집 실패 (page {page}): {status_code}")
            break
        data = json_data.get("data", {})
        goods_list = data.get("list", [])
        if not goods_list:
            break
        for item in goods_list:
            all_data.append({
                "플랫폼":    "무신사",
                "카테고리":  CATEGORY_NAME,
                "브랜드":    item.get("brandName", ""),
                "goodsNo":  str(item.get("goodsNo", "")),
                "상품명":    item.get("goodsName", ""),
                "정가":      item.get("normalPrice", 0),
                "판매가":    item.get("price", 0),
                "할인율": item.get("saleRate", 0),
                "리뷰수":    item.get("reviewCount", 0),
                "리뷰점수":  item.get("reviewScore", 0),
            })
        total_pages = data.get("pagination", {}).get("totalPages", 1)
        print(f"상품 수집 중... {page}/{total_pages} 페이지 (누적 {len(all_data)}개)")
        if page >= total_pages:
            break
        page += 1
        time.sleep(2)
    except Exception as e:
        print(f"상품 수집 오류 (page {page}): {e}")
        time.sleep(2)
        break
# 리뷰 많은 순으로 정렬 (전체)
df = pd.DataFrame(all_data)
df = df.sort_values("리뷰수", ascending=False).reset_index(drop=True)
df["조회수"]    = 0
df["누적판매수"] = 0
print(f"\n상품 총 {len(df)}개 수집 완료 (리뷰 많은 순)")
print(df[["카테고리", "브랜드", "상품명", "리뷰수"]].to_string(index=False))
# ==========================================
# Step 2: 재시작 로직 - 이미 수집된 goodsNo 및 리뷰번호 확인
# ==========================================
collected_goods   = set()
collected_review_ids = set() # 상품 단위가 아닌 '리뷰 번호'를 추적하기 위한 set

if os.path.exists(PRODUCTS_CSV):
    df_existing = pd.read_csv(PRODUCTS_CSV)
    collected_goods = set(df_existing["goodsNo"].astype(str).tolist())
    print(f"\n기존 수집된 상품 {len(collected_goods)}개 확인 -> 정보 업데이트 스킵 예정")
else:
    print("\n기존 수집 상품 파일 없음 -> 처음부터 수집 시작")

if os.path.exists(REVIEWS_CSV):
    df_existing_reviews = pd.read_csv(REVIEWS_CSV)
    # 기존 코드: collected_reviews = set(df_existing_reviews["goodsNo"].astype(str).tolist())
    # 변경 코드: 리뷰의 고유 번호를 저장합니다.
    collected_review_ids = set(df_existing_reviews["리뷰번호"].astype(str).tolist())
    print(f"기존 수집된 개별 리뷰 {len(collected_review_ids)}개 확인 -> 중복 리뷰 스킵 예정")
# ==========================================
# Step 3: 만족도 파싱 함수
# ==========================================
def parse_satisfaction(survey):
    if not survey:
        return ""
    questions = survey.get("questions", [])
    parts = []
    for q in questions:
        attribute = q.get("attribute", "")
        answers = q.get("answers", [])
        answer_text = ", ".join([a.get("answerShortText", "") for a in answers])
        parts.append(f"{attribute}: {answer_text}")
    return " / ".join(parts)
# ==========================================
# Step 4: 리뷰 수집 함수 (새로운 리뷰만 수집)
# ==========================================
def get_reviews(goods_no, target_count, collected_ids, max_pages=9999):
    reviews = []
    stop_crawling = False # 크롤링 중단 플래그

    for page in range(max_pages):
        if len(reviews) >= target_count or stop_crawling:
            break
        
        url = "https://goods.musinsa.com/api2/review/v1/view/list"
        params = {
            "page":              page,
            "pageSize":          10,
            "goodsNo":           goods_no,
            "sort":              "new", # 최신순 정렬 (중요)
            "selectedSimilarNo": goods_no,
            "myFilter":          "false",
            "hasPhoto":          "false",
            "isExperience":      "false",
        }
        try:
            json_data, status_code = request_json(url, params=params, timeout=10, retry=3)
            if not json_data:
                print(f"  상태코드 {status_code} -> 중단")
                break
                
            data        = json_data.get("data", {})
            review_list = data.get("list", [])
            
            if not review_list:
                break
                
            for review in review_list:
                review_no = str(review.get("no", ""))
                
                # 핵심 로직: 이미 수집된 리뷰 번호를 만나면 더 이상 과거 리뷰를 탐색할 필요가 없음
                if review_no in collected_ids:
                    stop_crawling = True
                    break 
                
                profile = review.get("userProfileInfo") or {}
                images  = review.get("images") or []
                reviews.append({
                    "goodsNo":  str(goods_no),
                    "리뷰번호": review_no, # 이 값이 중복 체크의 기준이 됩니다
                    "작성자":   profile.get("userNickName", ""),
                    "리뷰내용": review.get("content", ""),
                    "평점":     int(review.get("grade", 0)),
                    "체험단":   review.get("type") == "experience",
                    "구매옵션": review.get("goodsOption", ""),
                    "키":       profile.get("userHeight", ""),
                    "몸무게":   profile.get("userWeight", ""),
                    "성별":     profile.get("reviewSex", ""),
                    "작성일":   review.get("createDate", ""),
                    "만족도":   parse_satisfaction(review.get("reviewSurveySatisfaction")),
                    "사진유무": len(images) > 0,
                    "도움돼요": review.get("likeCount", 0),
                })
                
                if len(reviews) >= target_count:
                    break
                    
            total_pages = data.get("page", {}).get("totalPages", 0)
            if page >= total_pages - 1:
                break
                
            if len(reviews) % 100 == 0 and len(reviews) > 0:
                print(f"  새로운 리뷰 {len(reviews)}개 수집 중...")
            time.sleep(2)
            
        except Exception as e:
            print(f"  리뷰 수집 오류: {e}")
            time.sleep(2)
            break
            
    return reviews
# ==========================================
# Step 5: 상품 통계(조회수, 판매량) 수집 함수
# ==========================================
def get_goods_stats(goods_no):
    url = f"https://goods-detail.musinsa.com/api2/goods/{goods_no}/stat"
    try:
        json_data, status_code = request_json(url, timeout=10, retry=3)
        if json_data:
            sales_count = json_data.get("data", {}).get("purchaseTotal", 0)
            views_count = json_data.get("data", {}).get("pageViewTotal", 0)
            return sales_count, views_count
        else:
            print(f"  통계 수집 실패 ({goods_no}): {status_code}")
    except Exception as e:
        print(f"  통계 수집 오류 ({goods_no}): {e}")
    return 0, 0
# ==========================================
# Step 6: survey 수집 함수
# ==========================================
def get_survey(goods_no):
    url = f"https://goods.musinsa.com/api2/review/v1/view/survey/{goods_no}/summary"
    try:
        json_data, status_code = request_json(url, timeout=10, retry=3)
        if json_data:
            questions = json_data.get("data", {}).get("questions", [])
            rows = []
            for q in questions:
                attribute = q.get("attribute", "")
                for answer in q.get("answers", []):
                    rows.append({
                        "goodsNo": str(goods_no),
                        "항목":    attribute,
                        "답변":    answer.get("answerShortText", ""),
                        "비율": answer.get("percentage", 0),
                        "응답수":  answer.get("count", 0),
                    })
            return rows
        else:
            print(f"  survey 수집 실패 ({goods_no}): {status_code}")
    except Exception as e:
        print(f"  survey 수집 오류 ({goods_no}): {e}")
    return []
# ==========================================
# Step 7: 중간 저장 함수
# ==========================================
def save_product(row_dict):
    df_row = pd.DataFrame([row_dict])
    if os.path.exists(PRODUCTS_CSV):
        df_row.to_csv(PRODUCTS_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_row.to_csv(PRODUCTS_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
def save_reviews(reviews):
    if not reviews:
        return
    df_r = pd.DataFrame(reviews)
    if os.path.exists(REVIEWS_CSV):
        df_r.to_csv(REVIEWS_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_r.to_csv(REVIEWS_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
def save_survey(survey_rows):
    if not survey_rows:
        return
    df_s = pd.DataFrame(survey_rows)
    if os.path.exists(SURVEY_CSV):
        df_s.to_csv(SURVEY_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_s.to_csv(SURVEY_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
def save_error(goods_no, error_type, message):
    df_e = pd.DataFrame([{
        "goodsNo":    goods_no,
        "error_type": error_type,
        "message":    message,
        "time":       pd.Timestamp.now().strftime("%Y-%m-%d %H:%M:%S"),
    }])
    if os.path.exists(ERRORS_CSV):
        df_e.to_csv(ERRORS_CSV, mode="a", header=False, index=False, encoding="utf-8-sig")
    else:
        df_e.to_csv(ERRORS_CSV, mode="w", header=True, index=False, encoding="utf-8-sig")
# ==========================================
# Step 8: 전체 상품 리뷰 및 통계 수집
# ==========================================
total_items = len(df)
for idx, row in df.iterrows():
    goods_no     = row["goodsNo"]
    target_count = int(row["리뷰수"])
    current_item = idx + 1
    product_saved = goods_no in collected_goods

    print(f"\n[{current_item}/{total_items}] 처리 중: {str(row['상품명'])[:25]} (총 리뷰 수: {target_count}개)")

    sales, views = 0, 0

    if not product_saved:
        # 통계 수집
        try:
            sales, views = get_goods_stats(goods_no)
        except Exception as e:
            print(f"  통계 수집 실패: {e}")
            save_error(goods_no, "stats", str(e))
            sales, views = 0, 0
        time.sleep(2)

        # survey 수집
        try:
            survey_rows = get_survey(goods_no)
            save_survey(survey_rows)
            print(f"  survey {len(survey_rows)}행 저장 완료")
        except Exception as e:
            print(f"  survey 수집 실패: {e}")
            save_error(goods_no, "survey", str(e))
        time.sleep(2)

        # 상품 정보 저장
        save_product({
            "플랫폼":    row["플랫폼"],
            "카테고리":  row["카테고리"],
            "브랜드":    row["브랜드"],
            "goodsNo":  goods_no,
            "상품명":    row["상품명"],
            "정가":      row["정가"],
            "판매가":    row["판매가"],
            "할인율": row["할인율"],
            "조회수":    views,
            "누적판매수": sales,
            "리뷰수":    row["리뷰수"],
            "리뷰점수":  row["리뷰점수"],
        })
        collected_goods.add(goods_no)
        print(f"  -> 상품 저장 완료 (누적판매: {sales} | 조회수: {views})")
    else:
        print("  [스킵] 상품 기본 정보는 이미 저장됨")

    time.sleep(2)

    # 리뷰 수집 (무조건 체크)
    if not goods_no or target_count == 0:
        print(f"  [스킵] 리뷰 없음")
    else:
        print(f"  새로운 리뷰 수집 확인 중...")
        try:
            # collected_review_ids를 넘겨주어 중복을 체크하게 합니다.
            reviews = get_reviews(goods_no, target_count=target_count, collected_ids=collected_review_ids)
            
            if len(reviews) > 0:
                save_reviews(reviews)
                # 새로 수집된 리뷰 번호들을 기존 set에 업데이트
                collected_review_ids.update([r["리뷰번호"] for r in reviews])
                print(f"  -> 새로운 리뷰 {len(reviews)}개 수집 및 추가 완료!")
            else:
                print(f"  -> 추가된 새로운 리뷰가 없습니다.")
                
        except Exception as e:
            print(f"  리뷰 수집 실패: {e}")
            save_error(goods_no, "review", str(e))
            
    time.sleep(2)
# Out:
# 상품 수집 중... 1/1 페이지 (누적 73개)
#
# 상품 총 73개 수집 완료 (리뷰 많은 순)
# 카테고리    브랜드                                    상품명   리뷰수
#   바지 필루미네이트     [해피가이정호 pick] 데미지 워시드 데님 팬츠-미디엄 블루 16191
#   바지 필루미네이트                      나일론 투 턱 테이핑 팬츠-블랙  4449
#   바지 필루미네이트         [해피가이정호 pick] 데미지 워시드 데님 팬츠-블랙  2774
#   바지 필루미네이트                    데미지 워시드 데님 팬츠-스카이블루  1642
#   바지 필루미네이트 [해피가이정호 pick] 올 데이 린넨 라이크 밴딩 팬츠-5Color  1396
#   바지 필루미네이트                       데미지 워시드 데님 팬츠-블루  1295
#   바지 필루미네이트                      오버랩 스웨트 팬츠-멜란지그레이   749
#   바지 필루미네이트   [패션플래닛×필루미네이트] 에센셜 와이드 스웨트 팬츠-3Color   524
#   바지 필루미네이트                          밀리터리 카고 팬츠-블랙   402
#   바지 필루미네이트               [2PACK]올 데이 린넨 라이크 밴딩 팬츠   334
#   바지 필루미네이트     [해피가이정호 pick] 데미지 워시드 데님 팬츠-3Color   141
#   바지 필루미네이트                    데미지 워시드 데님 팬츠-아이스블루   136
#   바지 필루미네이트                   올 데이 코튼 밴딩 팬츠-3Color   133
#   바지 필루미네이트                      데미지 워시드 데님 팬츠-그레이   128
#   바지 필루미네이트        [해피가이정호 pick] 데미지 워시드 데님 팬츠-인디고    90
#   바지 필루미네이트      [해피가이정호 pick] 데미지 워시드 데님 팬츠-로우 블랙    48
#   바지 필루미네이트                  헤링본 와이드 스트링 팬츠-3Color    33
#   바지 필루미네이트                          밀리터리 카고 팬츠-카키    31
#   바지 필루미네이트                     트윌 코튼 밴딩 팬츠-3Color    30
#   바지 필루미네이트                   레귤러 테이퍼드 데님 팬츠-미디엄블루    29
#   바지 필루미네이트                       더블 니 코듀로이 팬츠-브라운    25
#   바지 필루미네이트         [스토커즈 pick] 레귤러 테이퍼드 데님 팬츠-인디고    16
#   바지 필루미네이트                        더블 니 코듀로이 팬츠-블랙    14
#   바지 필루미네이트          [스토커즈 pick] 레귤러 테이퍼드 데님 팬츠-블랙    14
#   바지 필루미네이트                 데미지 워시드 데님 밴딩 팬츠-스카이블루    14
#   바지 필루미네이트                   벌룬 와이드 스웨트 팬츠-멜란지그레이    13
#   바지 필루미네이트                      볼드 더블 니 스웨트 팬츠-블랙    12
#   바지 필루미네이트                       더블 니 코듀로이 팬츠-베이지    11
#   바지 필루미네이트                        벌룬 와이드 코튼 팬츠-블랙    10
#   바지 필루미네이트                       벌룬 와이드 코튼 팬츠-베이지    10
#   바지 필루미네이트                      와이드 테이퍼드 데님 팬츠-블루     8
#   바지 필루미네이트                        타이 라인 데님 팬츠-인디고     8
#   바지 필루미네이트                      와이드 테이퍼드 데님 팬츠-블랙     7
#   바지 필루미네이트                   브러쉬드 스트레이트 데님 팬츠-인디고     6
#   바지 필루미네이트                      코튼 사이드 턱 벌룬 팬츠-블랙     5
#   바지 필루미네이트                    브러쉬드 스트레이트 데님 팬츠-블랙     5
#   바지 필루미네이트                    워시드 플레어 데님 팬츠-다크인디고     5
#   바지 필루미네이트                       헤이지 워시드 데님 팬츠-블랙     5
#   바지 필루미네이트                      헤이지 워시드 데님 팬츠-그레이     5
#   바지 필루미네이트              (W) 슬럽 턴업 세미 와이드 데님 팬츠-블루     4
#   바지 필루미네이트           [스토커즈 pick] 원턱 레귤러 데님 팬츠-인디고     4
#   바지 필루미네이트                     빈티지 워시드 코듀로이 팬츠-블랙     4
#   바지 필루미네이트                     빈티지 워시드 코듀로이 팬츠-카키     4
#   바지 필루미네이트            [스토커즈 pick] 원턱 레귤러 데님 팬츠-블랙     3
#   바지 필루미네이트                      택티컬 더블 니 워크 팬츠-블랙     3
#   바지 필루미네이트                 (W) 레이어드 스커트 팬츠-라이트그레이     3
#   바지 필루미네이트                  볼드 더블 니 스웨트 팬츠-멜란지그레이     2
#   바지 필루미네이트                     와이드 테이퍼드 데님 팬츠-그레이     2
#   바지 필루미네이트                         타이 라인 데님 팬츠-블루     2
#   바지 필루미네이트                     택티컬 더블 니 워크 팬츠-그레이     2
#   바지 필루미네이트                   카고 버뮤다 스웨트 쇼츠-멜란지그레이     1
#   바지 필루미네이트                       (W) 코튼 스트링 쇼츠-카키     1
#   바지 필루미네이트             (W) 슬럽 턴업 세미 와이드 데님 팬츠-인디고     1
#   바지 필루미네이트                     (W) 레이어드 스커트 팬츠-블랙     1
#   바지 필루미네이트                     택티컬 더블 니 워크 팬츠-브라운     1
#   바지 필루미네이트                       카고 버뮤다 스웨트 쇼츠-블랙     0
#   바지 필루미네이트                     (W) 밀리터리 스트링 팬츠-카키     0
#   바지 필루미네이트                    (W) 밀리터리 스트링 팬츠-그레이     0
#   바지 필루미네이트                      (W) 투 턱 와이드 팬츠-블랙     0
#   바지 필루미네이트                      (W) 투 턱 와이드 팬츠-크림     0
#   바지 필루미네이트                       (W) 코튼 스트링 쇼츠-블랙     0
#   바지 필루미네이트                      (W) 코튼 스트링 쇼츠-베이지     0
#   바지 필루미네이트                     (W)  데미지 데님 쇼츠-인디고     0
#   바지 필루미네이트                   (W)  데미지 데님 쇼츠-라이트블루     0
#   바지 필루미네이트                      (W) 에센셜 나일론 쇼츠-블랙     0
#   바지 필루미네이트                      (W) 에센셜 나일론 쇼츠-와인     0
#   바지 필루미네이트                     (W) 에센셜 나일론 쇼츠-그레이     0
#   바지 필루미네이트                         시어서커 체크 쇼츠-네이비     0
#   바지 필루미네이트                          시어서커 체크 쇼츠-그린     0
#   바지 필루미네이트                     코튼 사이드 턱 벌룬 팬츠-베이지     0
#   바지 필루미네이트                         피드 체크 트랙 팬츠-차콜     0
#   바지 필루미네이트                        피드 체크 트랙 팬츠-그레이     0
#   바지 필루미네이트                       워시드 플레어 데님 팬츠-블랙     0
#
# 기존 수집된 상품 73개 확인 -> 정보 업데이트 스킵 예정
# 기존 수집된 개별 리뷰 30767개 확인 -> 중복 리뷰 스킵 예정
#
# [1/73] 처리 중: [해피가이정호 pick] 데미지 워시드 데님  (총 리뷰 수: 16191개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [2/73] 처리 중: 나일론 투 턱 테이핑 팬츠-블랙 (총 리뷰 수: 4449개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [3/73] 처리 중: [해피가이정호 pick] 데미지 워시드 데님  (총 리뷰 수: 2774개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [4/73] 처리 중: 데미지 워시드 데님 팬츠-스카이블루 (총 리뷰 수: 1642개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [5/73] 처리 중: [해피가이정호 pick] 올 데이 린넨 라이크 (총 리뷰 수: 1396개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 3개 수집 및 추가 완료!
#
# [6/73] 처리 중: 데미지 워시드 데님 팬츠-블루 (총 리뷰 수: 1295개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [7/73] 처리 중: 오버랩 스웨트 팬츠-멜란지그레이 (총 리뷰 수: 749개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [8/73] 처리 중: [패션플래닛×필루미네이트] 에센셜 와이드 스웨 (총 리뷰 수: 524개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 3개 수집 및 추가 완료!
#
# [9/73] 처리 중: 밀리터리 카고 팬츠-블랙 (총 리뷰 수: 402개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 2개 수집 및 추가 완료!
#
# [10/73] 처리 중: [2PACK]올 데이 린넨 라이크 밴딩 팬츠 (총 리뷰 수: 334개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [11/73] 처리 중: [해피가이정호 pick] 데미지 워시드 데님  (총 리뷰 수: 141개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 2개 수집 및 추가 완료!
#
# [12/73] 처리 중: 데미지 워시드 데님 팬츠-아이스블루 (총 리뷰 수: 136개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [13/73] 처리 중: 올 데이 코튼 밴딩 팬츠-3Color (총 리뷰 수: 133개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [14/73] 처리 중: 데미지 워시드 데님 팬츠-그레이 (총 리뷰 수: 128개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [15/73] 처리 중: [해피가이정호 pick] 데미지 워시드 데님  (총 리뷰 수: 90개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [16/73] 처리 중: [해피가이정호 pick] 데미지 워시드 데님  (총 리뷰 수: 48개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [17/73] 처리 중: 헤링본 와이드 스트링 팬츠-3Color (총 리뷰 수: 33개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [18/73] 처리 중: 밀리터리 카고 팬츠-카키 (총 리뷰 수: 31개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [19/73] 처리 중: 트윌 코튼 밴딩 팬츠-3Color (총 리뷰 수: 30개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [20/73] 처리 중: 레귤러 테이퍼드 데님 팬츠-미디엄블루 (총 리뷰 수: 29개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [21/73] 처리 중: 더블 니 코듀로이 팬츠-브라운 (총 리뷰 수: 25개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [22/73] 처리 중: [스토커즈 pick] 레귤러 테이퍼드 데님 팬 (총 리뷰 수: 16개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [23/73] 처리 중: 더블 니 코듀로이 팬츠-블랙 (총 리뷰 수: 14개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [24/73] 처리 중: [스토커즈 pick] 레귤러 테이퍼드 데님 팬 (총 리뷰 수: 14개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [25/73] 처리 중: 데미지 워시드 데님 밴딩 팬츠-스카이블루 (총 리뷰 수: 14개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [26/73] 처리 중: 벌룬 와이드 스웨트 팬츠-멜란지그레이 (총 리뷰 수: 13개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [27/73] 처리 중: 볼드 더블 니 스웨트 팬츠-블랙 (총 리뷰 수: 12개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [28/73] 처리 중: 더블 니 코듀로이 팬츠-베이지 (총 리뷰 수: 11개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [29/73] 처리 중: 벌룬 와이드 코튼 팬츠-블랙 (총 리뷰 수: 10개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [30/73] 처리 중: 벌룬 와이드 코튼 팬츠-베이지 (총 리뷰 수: 10개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [31/73] 처리 중: 와이드 테이퍼드 데님 팬츠-블루 (총 리뷰 수: 8개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [32/73] 처리 중: 타이 라인 데님 팬츠-인디고 (총 리뷰 수: 8개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [33/73] 처리 중: 와이드 테이퍼드 데님 팬츠-블랙 (총 리뷰 수: 7개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [34/73] 처리 중: 브러쉬드 스트레이트 데님 팬츠-인디고 (총 리뷰 수: 6개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [35/73] 처리 중: 코튼 사이드 턱 벌룬 팬츠-블랙 (총 리뷰 수: 5개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [36/73] 처리 중: 브러쉬드 스트레이트 데님 팬츠-블랙 (총 리뷰 수: 5개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [37/73] 처리 중: 워시드 플레어 데님 팬츠-다크인디고 (총 리뷰 수: 5개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [38/73] 처리 중: 헤이지 워시드 데님 팬츠-블랙 (총 리뷰 수: 5개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 새로운 리뷰 1개 수집 및 추가 완료!
#
# [39/73] 처리 중: 헤이지 워시드 데님 팬츠-그레이 (총 리뷰 수: 5개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [40/73] 처리 중: (W) 슬럽 턴업 세미 와이드 데님 팬츠-블루 (총 리뷰 수: 4개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [41/73] 처리 중: [스토커즈 pick] 원턱 레귤러 데님 팬츠- (총 리뷰 수: 4개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [42/73] 처리 중: 빈티지 워시드 코듀로이 팬츠-블랙 (총 리뷰 수: 4개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [43/73] 처리 중: 빈티지 워시드 코듀로이 팬츠-카키 (총 리뷰 수: 4개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [44/73] 처리 중: [스토커즈 pick] 원턱 레귤러 데님 팬츠- (총 리뷰 수: 3개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [45/73] 처리 중: 택티컬 더블 니 워크 팬츠-블랙 (총 리뷰 수: 3개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [46/73] 처리 중: (W) 레이어드 스커트 팬츠-라이트그레이 (총 리뷰 수: 3개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [47/73] 처리 중: 볼드 더블 니 스웨트 팬츠-멜란지그레이 (총 리뷰 수: 2개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [48/73] 처리 중: 와이드 테이퍼드 데님 팬츠-그레이 (총 리뷰 수: 2개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [49/73] 처리 중: 타이 라인 데님 팬츠-블루 (총 리뷰 수: 2개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [50/73] 처리 중: 택티컬 더블 니 워크 팬츠-그레이 (총 리뷰 수: 2개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [51/73] 처리 중: 카고 버뮤다 스웨트 쇼츠-멜란지그레이 (총 리뷰 수: 1개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [52/73] 처리 중: (W) 코튼 스트링 쇼츠-카키 (총 리뷰 수: 1개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [53/73] 처리 중: (W) 슬럽 턴업 세미 와이드 데님 팬츠-인디 (총 리뷰 수: 1개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [54/73] 처리 중: (W) 레이어드 스커트 팬츠-블랙 (총 리뷰 수: 1개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [55/73] 처리 중: 택티컬 더블 니 워크 팬츠-브라운 (총 리뷰 수: 1개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   새로운 리뷰 수집 확인 중...
#   -> 추가된 새로운 리뷰가 없습니다.
#
# [56/73] 처리 중: 카고 버뮤다 스웨트 쇼츠-블랙 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [57/73] 처리 중: (W) 밀리터리 스트링 팬츠-카키 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [58/73] 처리 중: (W) 밀리터리 스트링 팬츠-그레이 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [59/73] 처리 중: (W) 투 턱 와이드 팬츠-블랙 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [60/73] 처리 중: (W) 투 턱 와이드 팬츠-크림 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [61/73] 처리 중: (W) 코튼 스트링 쇼츠-블랙 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [62/73] 처리 중: (W) 코튼 스트링 쇼츠-베이지 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [63/73] 처리 중: (W)  데미지 데님 쇼츠-인디고 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [64/73] 처리 중: (W)  데미지 데님 쇼츠-라이트블루 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [65/73] 처리 중: (W) 에센셜 나일론 쇼츠-블랙 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [66/73] 처리 중: (W) 에센셜 나일론 쇼츠-와인 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [67/73] 처리 중: (W) 에센셜 나일론 쇼츠-그레이 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [68/73] 처리 중: 시어서커 체크 쇼츠-네이비 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [69/73] 처리 중: 시어서커 체크 쇼츠-그린 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [70/73] 처리 중: 코튼 사이드 턱 벌룬 팬츠-베이지 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [71/73] 처리 중: 피드 체크 트랙 팬츠-차콜 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [72/73] 처리 중: 피드 체크 트랙 팬츠-그레이 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
#
# [73/73] 처리 중: 워시드 플레어 데님 팬츠-블랙 (총 리뷰 수: 0개)
#   [스킵] 상품 기본 정보는 이미 저장됨
#   [스킵] 리뷰 없음
