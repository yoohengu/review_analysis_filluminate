# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:비밀번호@localhost/review_analysis?charset=utf8mb4')

query = """
SELECT * FROM products_reviews_all
WHERE STR_TO_DATE(작성일, '%%Y-%%m-%%d') <= '2026-03-31'
"""

df = pd.read_sql(query, engine)

print(df.shape)
print(df.head())
# Out:
# (134045, 25)
#    goodsNo  플랫폼 카테고리     브랜드                   상품명     정가    판매가  할인율  조회수  \
# 0   876284  무신사   상의  필루미네이트  [블랙]SET B-스테디 하프 폴라넥  52000  29900   43  886
# 1   876284  무신사   상의  필루미네이트  [블랙]SET B-스테디 하프 폴라넥  52000  29900   43  886
# 2   876284  무신사   상의  필루미네이트  [블랙]SET B-스테디 하프 폴라넥  52000  29900   43  886
# 3   876284  무신사   상의  필루미네이트  [블랙]SET B-스테디 하프 폴라넥  52000  29900   43  886
# 4   876284  무신사   상의  필루미네이트  [블랙]SET B-스테디 하프 폴라넥  52000  29900   43  886
#
#    누적판매수  ...  평점    체험단        구매옵션  키 몸무게   성별  \
# 0  67962  ...   5  FALSE   M · Beige  0   0  NaN
# 1  67962  ...   5  FALSE   M · Black  0   0  NaN
# 2  67962  ...   5  FALSE   M · Black  0   0  NaN
# 3  67962  ...   5  FALSE   M · Black  0   0  NaN
# 4  67962  ...   5  FALSE  XL · Black  0   0  NaN
#
#                              작성일  만족도   사진유무  도움돼요
# 0  2018-10-16T11:58:00.000+09:00  NaN  FALSE     0
# 1  2018-10-16T14:57:45.000+09:00  NaN   TRUE     0
# ...
